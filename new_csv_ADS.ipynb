# %%
done_urls = [
"www.bookyogaretreats.com/all/c/short/d/europe",
"www.bookyogaretreats.com/all/d/asia-and-oceania/philippines",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india/goa",
"www.bookyogaretreats.com/all/c|/budget-retreats/d/asia-and-oceania",
"www.bookyogaretreats.com/all/d/europe/croatia",
"www.bookyogaretreats.com/all/c/budget-retreats/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/c/budget-retreats/d/europe/united-kingdom",
"www.bookyogateachertraining.com/all/s/yoga-vinyasa",
"www.bookyogaretreats.com/all/c/holidays/d/europe",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/hawaii",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/florida",
"www.bookyogaretreats.com/all/s/vinyasa-yoga",
"www.bookyogaretreats.com/all/c/yoga-detox-retreats",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/mexico",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean/usa/california",
"www.bookyogateachertraining.com/all/d/europe",
"www.bookyogaretreats.com/all/c/budget-retreats/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/?arrival_date=2017-02-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/indonesia",
"www.bookyogaretreats.com/all/c/yoga-meditation-retreats",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india",
"www.bookyogaretreats.com/?arrival_date=2017-03-15&flexible=15",
"www.bookyogaretreats.com/all/c/yoga-meditation-retreats/d/the-americas-and-caribbean/usa/florida",
"www.bookyogaretreats.com/all/c/budget-retreats/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/yoga-surf/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/?arrival_date=2016-05-15&flexible=15",
"www.bookyogateachertraining.com/all/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/c/short",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/s/bikram-hot-yoga",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india",
"www.bookyogaretreats.com/?arrival_date=2016-12-15&flexible=15",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india/goa",
"www.bookyogaretreats.com/all/c/budget-retreats/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/c/beach-retreats/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/yoga-surf",
"www.bookyogaretreats.com/all/c/budget-retreats",
"www.bookyogaretreats.com/all/d/asia-and-oceania/vietnam",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/holidays/d/europe/united-kingdom",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/usa/hawaii",
"www.bookyogaretreats.com/?arrival_date=2016-06-15&flexible=15",
"www.bookyogaretreats.com/all/d/europe/united-kingdom/england",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/d/europe/france",
"www.bookyogaretreats.com/all/c/holidays/d/europe/greece",
"www.bookyogaretreats.com/all/d/europe/greece",
"www.bookyogaretreats.com/?arrival_date=2016-07-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2016-10-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2016-09-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/africa-and-the-middle-east/morocco",
"www.bookyogaretreats.com/?arrival_date=2016-11-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2017-01-15&flexible=15",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/asia-and-oceania/nepal",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/california",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india/kerala",
"www.bookyogaretreats.com/?arrival_date=2016-08-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/d/asia-and-oceania/cambodia",
"www.bookyogaretreats.com/all/d/europe/spain/ibiza",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/europe/spain/mallorca",
"www.bookyogaretreats.com/all/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain/canary-islands",
"www.bookyogaretreats.com/all/c/yoga-surf/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/d/europe/spain",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain",
"www.bookyogaretreats.com/all/c/holidays/d/europe/portugal",
"www.bookyogaretreats.com/all/s/ashtanga-yoga",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india/kerala",
"www.bookyogaretreats.com/all/d/europe/italy",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/vietnam",
"www.bookyogaretreats.com/all/d/asia-and-oceania/new-zealand",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/d/europe",
"www.bookyogaretreats.com/all/d/europe/spain/canary-islands",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain/ibiza",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/sri-lanka",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/costa-rica",
"www.bookyogateachertraining.com/",
"www.bookyogaretreats.com/all/d/asia-and-oceania/australia",
"www.bookyogaretreats.com/?arrival_date=2016-04-15&flexible=15",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/USA",
"www.bookyogaretreats.com/all/d/europe/portugal",
"www.bookyogaretreats.com/all/d/asia-and-oceania/sri-lanka",
"www.bookyogaretreats.com",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/cambodia",
"www.bookyogateachertraining.com/all/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/africa-and-the-middle-east/morocco",
"www.bookyogaretreats.com/all/d/africa-and-the-middle-east",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/australia",
"www.bookyogaretreats.com/all/d/asia-and-oceania/indonesia",
"www.bookyogateachertraining.com/all/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/all/d/europe/united-kingdom",
"www.bookyogaretreats.com/all/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/d/asia-and-oceania"
]

import csv
import codecs

file_name = '20160712.csv'

basic_dict = {} 
ready_dict = {}
ready_dict_names = {}
state_country = {}

names = []
ready_names = []
ready_urls = []
ready_ids = []

#setup basic_dict (everything)
#ready_urls (only ones without adgroups)
#ready_ids (only ones without adgroups)

with codecs.open(file_name, 'r', encoding = 'utf-8', errors = 'ignore') as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        names.append(row['name'])
        basic_dict[int(row['destination_id'])] = row['name']
        if row['concat'] not in done_urls: #only for urls that do not have adgroups yet
            ready_urls.append(row['concat']) #add all urls
            ready_ids.append(int(row['destination_id']))
            ready_names.append(row['name'])

#setup ready_dict 
#['key'] = destination_id
#ready_dict['key'][0] = destination name
#ready_dict['key'][1] = destination type
#ready_dict['key'][2] = number of listings
#ready_dict['key'][3] = URL (landing page)
#ready_dict['key'][4] = country name
#ready_dict['key'][5] = destination slug
#ready_dict['key'][6] = parent slug

with codecs.open(file_name, 'r', encoding = 'utf-8', errors = 'ignore') as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        if row['concat'] not in done_urls:
            ready_dict[int(row['destination_id'])] = [row['name'], row['type1'], row['nr_listings'], row['concat'], basic_dict[int(row['parent_id1'])], row['slug1'], row['slug2'], row['name2']]
            ready_dict_names[row['slug1']] = [row['name'], row['type1']]
            #state_country[row['']]

# %%
ready_dict_names['malta']
# Out:
# ['Malta', 'country']

# %%
#prepare text ads

headline1 = []
headline2 = []

desc11 = []
desc12 = []

desc21 = []
desc22 = []

display_url = []
final_url = []

campaign = []
ad_group = []

#ad_state
#device_preference
#ad_type

for i in range(len(ready_ids)):
    headline1.append('Book Yoga Retreats Online')
    headline2.append('Best Yoga Retreats 2016')
    
    desc11.append('%s Deals in %s!' %(ready_dict[ready_ids[i]][2], ready_dict[ready_ids[i]][0]))
    desc12.append('Top Rated & Best Price Guarantee')
    
    desc21.append('%s Deals in %s!' %(ready_dict[ready_ids[i]][2], ready_dict[ready_ids[i]][0]))
    desc22.append('Compare and Book from Top Packages')
    
    display_url.append('www.BookYogaRetreats.com/%s' %ready_dict[ready_ids[i]][5].title())
    final_url.append(ready_dict[ready_ids[i]][3])

    ad_group.append('Longtail Retreats %s' %ready_dict[ready_ids[i]][0])

for i in range(len(ready_ids)):
    if ready_dict[ready_ids[i]][1] == 'country':
        campaign.append("Longtail %s" %ready_dict[ready_ids[i]][0])
    if ready_dict[ready_ids[i]][1] == 'state':
        campaign.append("Longtail %s - %s" %(ready_dict[ready_ids[i]][4], ready_dict[ready_ids[i]][0]))
    
for i in range(len(ad_group)):
    ad_group[i] = ad_group[i].replace("  ", " ")
    campaign[i] = campaign[i].replace("  ", " ")

# %%
for i in range(len(display_url)):
    display_url[i] = display_url[i].replace('-', '')
    if len(display_url[i]) > 35:
        display_url[i] = 'www.BookYogaRetreats.com'

# %%
for item in headline1:
    if len(item) > 25:
        print(item)
        
for item in headline2:
    if len(item) > 25:
        print(item)

for i in range(len(desc11)):
    if len(desc11[i]) > 38:
        desc11[i] = ''.join([i for i in desc11[i] if not i.isdigit()])
        desc11[i] = desc11[i].replace(' Deals', 'Deals')
        if len(desc11[i]) > 38:
            desc11[i] = desc11[i].replace("Deals in ", '')

for i in range(len(desc11)):
    if len(desc11[i]) > 38:
        print(desc11[i], len(desc11[i]))
    
for i in range(len(desc21)):
    if len(desc21[i]) > 38:
        desc21[i] = ''.join(i for i in desc21[i] if not i.isdigit())
        desc21[i] = desc21[i].replace(' Deals', 'Deals')
        if len(desc21[i]) > 38:
            desc21[i] = desc21[i].replace('Deals in ', '')
            
for i in range(len(desc21)):
    if len(desc21[i]) > 38:
        print(desc21[i], len(desc21[i]))
        
if (len(headline1) == len(headline2) == len(desc11) == len(desc12) == len(desc21) == len(desc22)) == True:
    print('all lists have the same length (thats a good thing)')
# Out:
# all lists have the same length (thats a good thing)

# %%
headlines = (headline1 + headline2) * 2
d1 = (desc11 + desc21) * 2
d2 = (desc12 + desc22) * 2

display_url = display_url * 4
final_url = final_url * 4
campaign = campaign * 4
ad_group = ad_group * 4

how_many_ads = len(headlines)

ad_state = ['enabled'] * how_many_ads
ad_type = ['Text ad'] * how_many_ads

dev_all = ['All'] * int(how_many_ads/2)
dev_mobile = ['Mobile'] * int(how_many_ads/2)
dev_pref = dev_all + dev_mobile

# %%
len(headlines) == len(d1) == len(d2) == len(display_url) == len(final_url) == len(campaign) == len(ad_group) == len(ad_state) == len(ad_type) == len(dev_pref)
# Out:
# True

# %%
ad_column_titles = ["Ad state",
                    "Ad",
                    "Description line 1",
                    "Description line 2",
                    "Display URL",
                    "Final URL",
                    "Device preference type",
                    "Campaign",
                    "Ad group",
                    "Ad type"]

# %%
ad_rows = []

for i in range(how_many_ads):
    ad_rows.append(
        [ad_state[i],
        headlines[i],
        d1[i],
        d2[i],
        display_url[i],
        final_url[i],
        dev_pref[i],
        campaign[i],
        ad_group[i],
        ad_type[i]])

# %%
export_name = 'SQL Ads.csv'
new_export = open(export_name, 'w')
export_object = csv.writer(new_export)

export_object.writerow(ad_column_titles)
export_object.writerows(ad_rows)

new_export.close()

print('%i ads for %i destinations have been created (4 ads per destination: 2 for mobile, 2 for desktop) please check your current directory for the csv output' %(len(d1), len(ready_urls)))
# Out:
# 3708 ads for 927 destinations have been created (4 ads per destination: 2 for mobile, 2 for desktop) please check your current directory for the csv output

# %%
yoga = ['yoga']

holiday_word1 = [
'retreat',  
'retreats', 
'vacation',
'vacations',
'resort',
'resorts',
'camp',
'camps',
'package',
'packages',
'center',
'centers',
'centre',
'centres',
'deal',
'deals',
'training',
'trainings'
]

holiday_word2 = [
'retreat',  
'retreats', 
'vacation',
'vacations',
'resort',
'resorts',
'camp',
'camps',
'package',
'packages',
'center',
'centers',
'centre',
'centres',
'deal',
'deals',
'training',
'trainings',
'']

# %%
destination_front = []
destination_back= []
dest_camp = []

for item in ready_ids:
    destination_front.append(ready_dict[item][0])
    destination_back.append('in ' + ready_dict[item][0])
    destination_back.append(ready_dict[item][0])
    
a1 = [yoga, holiday_word1, holiday_word2, destination_back]
a2 = [destination_front, yoga, holiday_word1, holiday_word2]

import itertools

comb = list(itertools.product(*a1))
comb2 = list(itertools.product(*a2))

#remove adjacent duplicates
#e.g. holidays holidays
#e.g. holiday holidays
#e.g. holidays holiday
i = 0
for i in range(len(comb)):
    if comb[i][1] == comb[i][2]:
        comb[i] = (comb[i][0], comb[i][1], comb[i][3])
    elif comb[i][1]+'s' == comb[i][2]:
        comb[i] = (comb[i][0], comb[i][1], comb[i][3])
    elif comb[i][1] == comb[i][2]+'s':
        comb[i] = (comb[i][0], comb[i][1], comb[i][3])
    i = i+1

i = 0
for i in range(len(comb2)):
    if comb2[i][2] == comb2[i][3]:
        comb2[i] = (comb2[i][0], comb2[i][1], comb2[i][2])
    elif comb2[i][2]+'s' == comb2[i][3]:
        comb2[i] = (comb2[i][0], comb2[i][1], comb2[i][2])
    elif comb2[i][2] == comb2[i][3]+'s':
        comb2[i] = (comb2[i][0], comb2[i][1], comb2[i][2])
    i = i+1

#remove duplicates
comb = list(set(comb)) 
comb2 = list(set(comb2))

#join the 2 lists
all_comb = comb + comb2

for i in range(len(all_comb)):
    all_comb[i] = tuple(x for x in all_comb[i] if x != '')
    
all_comb = sorted(set(all_comb))

# %%
all_comb
# Out:
# [(' Matale District', 'yoga', 'camp'),
#  (' Matale District', 'yoga', 'camp', 'center'),
#  (' Matale District', 'yoga', 'camp', 'centers'),
#  (' Matale District', 'yoga', 'camp', 'centre'),
#  (' Matale District', 'yoga', 'camp', 'centres'),
#  (' Matale District', 'yoga', 'camp', 'deal'),
#  (' Matale District', 'yoga', 'camp', 'deals'),
#  (' Matale District', 'yoga', 'camp', 'package'),
#  (' Matale District', 'yoga', 'camp', 'packages'),
#  (' Matale District', 'yoga', 'camp', 'resort'),
#  (' Matale District', 'yoga', 'camp', 'resorts'),
#  (' Matale District', 'yoga', 'camp', 'retreat'),
#  (' Matale District', 'yoga', 'camp', 'retreats'),
#  (' Matale District', 'yoga', 'camp', 'training'),
#  (' Matale District', 'yoga', 'camp', 'trainings'),
#  (' Matale District', 'yoga', 'camp', 'vacation'),
#  (' Matale District', 'yoga', 'camp', 'vacations'),
#  (' Matale District', 'yoga', 'camps'),
#  (' Matale District', 'yoga', 'camps', 'center'),
#  (' Matale District', 'yoga', 'camps', 'centers'),
#  (' Matale District', 'yoga', 'camps', 'centre'),
#  (' Matale District', 'yoga', 'camps', 'centres'),
#  (' Matale District', 'yoga', 'camps', 'deal'),
#  (' Matale District', 'yoga', 'camps', 'deals'),
#  (' Matale District', 'yoga', 'camps', 'package'),
#  (' Matale District', 'yoga', 'camps', 'packages'),
#  (' Matale District', 'yoga', 'camps', 'resort'),
#  (' Matale District', 'yoga', 'camps', 'resorts'),
#  (' Matale District', 'yoga', 'camps', 'retreat'),
#  (' Matale District', 'yoga', 'camps', 'retreats'),
#  (' Matale District', 'yoga', 'camps', 'training'),
#  (' Matale District', 'yoga', 'camps', 'trainings'),
#  (' Matale District', 'yoga', 'camps', 'vacation'),
#  (' Matale District', 'yoga', 'camps', 'vacations'),
#  (' Matale District', 'yoga', 'center'),
#  (' Matale District', 'yoga', 'center', 'camp'),
#  (' Matale District', 'yoga', 'center', 'camps'),
#  (' Matale District', 'yoga', 'center', 'centre'),
#  (' Matale District', 'yoga', 'center', 'centres'),
#  (' Matale District', 'yoga', 'center', 'deal'),
#  (' Matale District', 'yoga', 'center', 'deals'),
#  (' Matale District', 'yoga', 'center', 'package'),
#  (' Matale District', 'yoga', 'center', 'packages'),
#  (' Matale District', 'yoga', 'center', 'resort'),
#  (' Matale District', 'yoga', 'center', 'resorts'),
#  (' Matale District', 'yoga', 'center', 'retreat'),
#  (' Matale District', 'yoga', 'center', 'retreats'),
#  (' Matale District', 'yoga', 'center', 'training'),
#  (' Matale District', 'yoga', 'center', 'trainings'),
#  (' Matale District', 'yoga', 'center', 'vacation'),
#  (' Matale District', 'yoga', 'center', 'vacations'),
#  (' Matale District', 'yoga', 'centers'),
#  (' Matale District', 'yoga', 'centers', 'camp'),
#  (' Matale District', 'yoga', 'centers', 'camps'),
#  (' Matale District', 'yoga', 'centers', 'centre'),
#  (' Matale District', 'yoga', 'centers', 'centres'),
#  (' Matale District', 'yoga', 'centers', 'deal'),
#  (' Matale District', 'yoga', 'centers', 'deals'),
#  (' Matale District', 'yoga', 'centers', 'package'),
#  (' Matale District', 'yoga', 'centers', 'packages'),
#  (' Matale District', 'yoga', 'centers', 'resort'),
#  (' Matale District', 'yoga', 'centers', 'resorts'),
#  (' Matale District', 'yoga', 'centers', 'retreat'),
#  (' Matale District', 'yoga', 'centers', 'retreats'),
#  (' Matale District', 'yoga', 'centers', 'training'),
#  (' Matale District', 'yoga', 'centers', 'trainings'),
#  (' Matale District', 'yoga', 'centers', 'vacation'),
#  (' Matale District', 'yoga', 'centers', 'vacations'),
#  (' Matale District', 'yoga', 'centre'),
#  (' Matale District', 'yoga', 'centre', 'camp'),
#  (' Matale District', 'yoga', 'centre', 'camps'),
#  (' Matale District', 'yoga', 'centre', 'center'),
#  (' Matale District', 'yoga', 'centre', 'centers'),
#  (' Matale District', 'yoga', 'centre', 'deal'),
#  (' Matale District', 'yoga', 'centre', 'deals'),
#  (' Matale District', 'yoga', 'centre', 'package'),
#  (' Matale District', 'yoga', 'centre', 'packages'),
#  (' Matale District', 'yoga', 'centre', 'resort'),
#  (' Matale District', 'yoga', 'centre', 'resorts'),
#  (' Matale District', 'yoga', 'centre', 'retreat'),
#  (' Matale District', 'yoga', 'centre', 'retreats'),
#  (' Matale District', 'yoga', 'centre', 'training'),
#  (' Matale District', 'yoga', 'centre', 'trainings'),
#  (' Matale District', 'yoga', 'centre', 'vacation'),
#  (' Matale District', 'yoga', 'centre', 'vacations'),
#  (' Matale District', 'yoga', 'centres'),
#  (' Matale District', 'yoga', 'centres', 'camp'),
#  (' Matale District', 'yoga', 'centres', 'camps'),
#  (' Matale District', 'yoga', 'centres', 'center'),
#  (' Matale District', 'yoga', 'centres', 'centers'),
#  (' Matale District', 'yoga', 'centres', 'deal'),
#  (' Matale District', 'yoga', 'centres', 'deals'),
#  (' Matale District', 'yoga', 'centres', 'package'),
#  (' Matale District', 'yoga', 'centres', 'packages'),
#  (' Matale District', 'yoga', 'centres', 'resort'),
#  (' Matale District', 'yoga', 'centres', 'resorts'),
#  (' Matale District', 'yoga', 'centres', 'retreat'),
#  (' Matale District', 'yoga', 'centres', 'retreats'),
#  (' Matale District', 'yoga', 'centres', 'training'),
#  (' Matale District', 'yoga', 'centres', 'trainings'),
#  (' Matale District', 'yoga', 'centres', 'vacation'),
#  (' Matale District', 'yoga', 'centres', 'vacations'),
#  (' Matale District', 'yoga', 'deal'),
#  (' Matale District', 'yoga', 'deal', 'camp'),
#  (' Matale District', 'yoga', 'deal', 'camps'),
#  (' Matale District', 'yoga', 'deal', 'center'),
#  (' Matale District', 'yoga', 'deal', 'centers'),
#  (' Matale District', 'yoga', 'deal', 'centre'),
#  (' Matale District', 'yoga', 'deal', 'centres'),
#  (' Matale District', 'yoga', 'deal', 'package'),
#  (' Matale District', 'yoga', 'deal', 'packages'),
#  (' Matale District', 'yoga', 'deal', 'resort'),
#  (' Matale District', 'yoga', 'deal', 'resorts'),
#  (' Matale District', 'yoga', 'deal', 'retreat'),
#  (' Matale District', 'yoga', 'deal', 'retreats'),
#  (' Matale District', 'yoga', 'deal', 'training'),
#  (' Matale District', 'yoga', 'deal', 'trainings'),
#  (' Matale District', 'yoga', 'deal', 'vacation'),
#  (' Matale District', 'yoga', 'deal', 'vacations'),
#  (' Matale District', 'yoga', 'deals'),
#  (' Matale District', 'yoga', 'deals', 'camp'),
#  (' Matale District', 'yoga', 'deals', 'camps'),
#  (' Matale District', 'yoga', 'deals', 'center'),
#  (' Matale District', 'yoga', 'deals', 'centers'),
#  (' Matale District', 'yoga', 'deals', 'centre'),
#  (' Matale District', 'yoga', 'deals', 'centres'),
#  (' Matale District', 'yoga', 'deals', 'package'),
#  (' Matale District', 'yoga', 'deals', 'packages'),
#  (' Matale District', 'yoga', 'deals', 'resort'),
#  (' Matale District', 'yoga', 'deals', 'resorts'),
#  (' Matale District', 'yoga', 'deals', 'retreat'),
#  (' Matale District', 'yoga', 'deals', 'retreats'),
#  (' Matale District', 'yoga', 'deals', 'training'),
#  (' Matale District', 'yoga', 'deals', 'trainings'),
#  (' Matale District', 'yoga', 'deals', 'vacation'),
#  (' Matale District', 'yoga', 'deals', 'vacations'),
#  (' Matale District', 'yoga', 'package'),
#  (' Matale District', 'yoga', 'package', 'camp'),
#  (' Matale District', 'yoga', 'package', 'camps'),
#  (' Matale District', 'yoga', 'package', 'center'),
#  (' Matale District', 'yoga', 'package', 'centers'),
#  (' Matale District', 'yoga', 'package', 'centre'),
#  (' Matale District', 'yoga', 'package', 'centres'),
#  (' Matale District', 'yoga', 'package', 'deal'),
#  (' Matale District', 'yoga', 'package', 'deals'),
#  (' Matale District', 'yoga', 'package', 'resort'),
#  (' Matale District', 'yoga', 'package', 'resorts'),
#  (' Matale District', 'yoga', 'package', 'retreat'),
#  (' Matale District', 'yoga', 'package', 'retreats'),
#  (' Matale District', 'yoga', 'package', 'training'),
#  (' Matale District', 'yoga', 'package', 'trainings'),
#  (' Matale District', 'yoga', 'package', 'vacation'),
#  (' Matale District', 'yoga', 'package', 'vacations'),
#  (' Matale District', 'yoga', 'packages'),
#  (' Matale District', 'yoga', 'packages', 'camp'),
#  (' Matale District', 'yoga', 'packages', 'camps'),
#  (' Matale District', 'yoga', 'packages', 'center'),
#  (' Matale District', 'yoga', 'packages', 'centers'),
#  (' Matale District', 'yoga', 'packages', 'centre'),
#  (' Matale District', 'yoga', 'packages', 'centres'),
#  (' Matale District', 'yoga', 'packages', 'deal'),
#  (' Matale District', 'yoga', 'packages', 'deals'),
#  (' Matale District', 'yoga', 'packages', 'resort'),
#  (' Matale District', 'yoga', 'packages', 'resorts'),
#  (' Matale District', 'yoga', 'packages', 'retreat'),
#  (' Matale District', 'yoga', 'packages', 'retreats'),
#  (' Matale District', 'yoga', 'packages', 'training'),
#  (' Matale District', 'yoga', 'packages', 'trainings'),
#  (' Matale District', 'yoga', 'packages', 'vacation'),
#  (' Matale District', 'yoga', 'packages', 'vacations'),
#  (' Matale District', 'yoga', 'resort'),
#  (' Matale District', 'yoga', 'resort', 'camp'),
#  (' Matale District', 'yoga', 'resort', 'camps'),
#  (' Matale District', 'yoga', 'resort', 'center'),
#  (' Matale District', 'yoga', 'resort', 'centers'),
#  (' Matale District', 'yoga', 'resort', 'centre'),
#  (' Matale District', 'yoga', 'resort', 'centres'),
#  (' Matale District', 'yoga', 'resort', 'deal'),
#  (' Matale District', 'yoga', 'resort', 'deals'),
#  (' Matale District', 'yoga', 'resort', 'package'),
#  (' Matale District', 'yoga', 'resort', 'packages'),
#  (' Matale District', 'yoga', 'resort', 'retreat'),
#  (' Matale District', 'yoga', 'resort', 'retreats'),
#  (' Matale District', 'yoga', 'resort', 'training'),
#  (' Matale District', 'yoga', 'resort', 'trainings'),
#  (' Matale District', 'yoga', 'resort', 'vacation'),
#  (' Matale District', 'yoga', 'resort', 'vacations'),
#  (' Matale District', 'yoga', 'resorts'),
#  (' Matale District', 'yoga', 'resorts', 'camp'),
#  (' Matale District', 'yoga', 'resorts', 'camps'),
#  (' Matale District', 'yoga', 'resorts', 'center'),
#  (' Matale District', 'yoga', 'resorts', 'centers'),
#  (' Matale District', 'yoga', 'resorts', 'centre'),
#  (' Matale District', 'yoga', 'resorts', 'centres'),
#  (' Matale District', 'yoga', 'resorts', 'deal'),
#  (' Matale District', 'yoga', 'resorts', 'deals'),
#  (' Matale District', 'yoga', 'resorts', 'package'),
#  (' Matale District', 'yoga', 'resorts', 'packages'),
#  (' Matale District', 'yoga', 'resorts', 'retreat'),
#  (' Matale District', 'yoga', 'resorts', 'retreats'),
#  (' Matale District', 'yoga', 'resorts', 'training'),
#  (' Matale District', 'yoga', 'resorts', 'trainings'),
#  (' Matale District', 'yoga', 'resorts', 'vacation'),
#  (' Matale District', 'yoga', 'resorts', 'vacations'),
#  (' Matale District', 'yoga', 'retreat'),
#  (' Matale District', 'yoga', 'retreat', 'camp'),
#  (' Matale District', 'yoga', 'retreat', 'camps'),
#  (' Matale District', 'yoga', 'retreat', 'center'),
#  (' Matale District', 'yoga', 'retreat', 'centers'),
#  (' Matale District', 'yoga', 'retreat', 'centre'),
#  (' Matale District', 'yoga', 'retreat', 'centres'),
#  (' Matale District', 'yoga', 'retreat', 'deal'),
#  (' Matale District', 'yoga', 'retreat', 'deals'),
#  (' Matale District', 'yoga', 'retreat', 'package'),
#  (' Matale District', 'yoga', 'retreat', 'packages'),
#  (' Matale District', 'yoga', 'retreat', 'resort'),
#  (' Matale District', 'yoga', 'retreat', 'resorts'),
#  (' Matale District', 'yoga', 'retreat', 'training'),
#  (' Matale District', 'yoga', 'retreat', 'trainings'),
#  (' Matale District', 'yoga', 'retreat', 'vacation'),
#  (' Matale District', 'yoga', 'retreat', 'vacations'),
#  (' Matale District', 'yoga', 'retreats'),
#  (' Matale District', 'yoga', 'retreats', 'camp'),
#  (' Matale District', 'yoga', 'retreats', 'camps'),
#  (' Matale District', 'yoga', 'retreats', 'center'),
#  (' Matale District', 'yoga', 'retreats', 'centers'),
#  (' Matale District', 'yoga', 'retreats', 'centre'),
#  (' Matale District', 'yoga', 'retreats', 'centres'),
#  (' Matale District', 'yoga', 'retreats', 'deal'),
#  (' Matale District', 'yoga', 'retreats', 'deals'),
#  (' Matale District', 'yoga', 'retreats', 'package'),
#  (' Matale District', 'yoga', 'retreats', 'packages'),
#  (' Matale District', 'yoga', 'retreats', 'resort'),
#  (' Matale District', 'yoga', 'retreats', 'resorts'),
#  (' Matale District', 'yoga', 'retreats', 'training'),
#  (' Matale District', 'yoga', 'retreats', 'trainings'),
#  (' Matale District', 'yoga', 'retreats', 'vacation'),
#  (' Matale District', 'yoga', 'retreats', 'vacations'),
#  (' Matale District', 'yoga', 'training'),
#  (' Matale District', 'yoga', 'training', 'camp'),
#  (' Matale District', 'yoga', 'training', 'camps'),
#  (' Matale District', 'yoga', 'training', 'center'),
#  (' Matale District', 'yoga', 'training', 'centers'),
#  (' Matale District', 'yoga', 'training', 'centre'),
#  (' Matale District', 'yoga', 'training', 'centres'),
#  (' Matale District', 'yoga', 'training', 'deal'),
#  (' Matale District', 'yoga', 'training', 'deals'),
#  (' Matale District', 'yoga', 'training', 'package'),
#  (' Matale District', 'yoga', 'training', 'packages'),
#  (' Matale District', 'yoga', 'training', 'resort'),
#  (' Matale District', 'yoga', 'training', 'resorts'),
#  (' Matale District', 'yoga', 'training', 'retreat'),
#  (' Matale District', 'yoga', 'training', 'retreats'),
#  (' Matale District', 'yoga', 'training', 'vacation'),
#  (' Matale District', 'yoga', 'training', 'vacations'),
#  (' Matale District', 'yoga', 'trainings'),
#  (' Matale District', 'yoga', 'trainings', 'camp'),
#  (' Matale District', 'yoga', 'trainings', 'camps'),
#  (' Matale District', 'yoga', 'trainings', 'center'),
#  (' Matale District', 'yoga', 'trainings', 'centers'),
#  (' Matale District', 'yoga', 'trainings', 'centre'),
#  (' Matale District', 'yoga', 'trainings', 'centres'),
#  (' Matale District', 'yoga', 'trainings', 'deal'),
#  (' Matale District', 'yoga', 'trainings', 'deals'),
#  (' Matale District', 'yoga', 'trainings', 'package'),
#  (' Matale District', 'yoga', 'trainings', 'packages'),
#  (' Matale District', 'yoga', 'trainings', 'resort'),
#  (' Matale District', 'yoga', 'trainings', 'resorts'),
#  (' Matale District', 'yoga', 'trainings', 'retreat'),
#  (' Matale District', 'yoga', 'trainings', 'retreats'),
#  (' Matale District', 'yoga', 'trainings', 'vacation'),
#  (' Matale District', 'yoga', 'trainings', 'vacations'),
#  (' Matale District', 'yoga', 'vacation'),
#  (' Matale District', 'yoga', 'vacation', 'camp'),
#  (' Matale District', 'yoga', 'vacation', 'camps'),
#  (' Matale District', 'yoga', 'vacation', 'center'),
#  (' Matale District', 'yoga', 'vacation', 'centers'),
#  (' Matale District', 'yoga', 'vacation', 'centre'),
#  (' Matale District', 'yoga', 'vacation', 'centres'),
#  (' Matale District', 'yoga', 'vacation', 'deal'),
#  (' Matale District', 'yoga', 'vacation', 'deals'),
#  (' Matale District', 'yoga', 'vacation', 'package'),
#  (' Matale District', 'yoga', 'vacation', 'packages'),
#  (' Matale District', 'yoga', 'vacation', 'resort'),
#  (' Matale District', 'yoga', 'vacation', 'resorts'),
#  (' Matale District', 'yoga', 'vacation', 'retreat'),
#  (' Matale District', 'yoga', 'vacation', 'retreats'),
#  (' Matale District', 'yoga', 'vacation', 'training'),
#  (' Matale District', 'yoga', 'vacation', 'trainings'),
#  (' Matale District', 'yoga', 'vacations'),
#  (' Matale District', 'yoga', 'vacations', 'camp'),
#  (' Matale District', 'yoga', 'vacations', 'camps'),
#  (' Matale District', 'yoga', 'vacations', 'center'),
#  (' Matale District', 'yoga', 'vacations', 'centers'),
#  (' Matale District', 'yoga', 'vacations', 'centre'),
#  (' Matale District', 'yoga', 'vacations', 'centres'),
#  (' Matale District', 'yoga', 'vacations', 'deal'),
#  (' Matale District', 'yoga', 'vacations', 'deals'),
#  (' Matale District', 'yoga', 'vacations', 'package'),
#  (' Matale District', 'yoga', 'vacations', 'packages'),
#  (' Matale District', 'yoga', 'vacations', 'resort'),
#  (' Matale District', 'yoga', 'vacations', 'resorts'),
#  (' Matale District', 'yoga', 'vacations', 'retreat'),
#  (' Matale District', 'yoga', 'vacations', 'retreats'),
#  (' Matale District', 'yoga', 'vacations', 'training'),
#  (' Matale District', 'yoga', 'vacations', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'camp', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'camps', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'center', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'centers', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'centre', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'centres', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'deal', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'deals', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'package', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'packages', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'resort', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'resorts', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'retreat', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'retreats', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'training', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'trainings', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'vacation'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'vacation', 'trainings'),
#  ('Abel Tasman National Park', 'yoga', 'vacations'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'camp'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'camps'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'center'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'centers'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'centre'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'centres'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'deal'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'deals'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'package'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'packages'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'resort'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'resorts'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'retreat'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'retreats'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'training'),
#  ('Abel Tasman National Park', 'yoga', 'vacations', 'trainings'),
#  ('Abruzzo', 'yoga', 'camp'),
#  ('Abruzzo', 'yoga', 'camp', 'center'),
#  ('Abruzzo', 'yoga', 'camp', 'centers'),
#  ('Abruzzo', 'yoga', 'camp', 'centre'),
#  ('Abruzzo', 'yoga', 'camp', 'centres'),
#  ('Abruzzo', 'yoga', 'camp', 'deal'),
#  ('Abruzzo', 'yoga', 'camp', 'deals'),
#  ('Abruzzo', 'yoga', 'camp', 'package'),
#  ('Abruzzo', 'yoga', 'camp', 'packages'),
#  ('Abruzzo', 'yoga', 'camp', 'resort'),
#  ('Abruzzo', 'yoga', 'camp', 'resorts'),
#  ('Abruzzo', 'yoga', 'camp', 'retreat'),
#  ('Abruzzo', 'yoga', 'camp', 'retreats'),
#  ('Abruzzo', 'yoga', 'camp', 'training'),
#  ('Abruzzo', 'yoga', 'camp', 'trainings'),
#  ('Abruzzo', 'yoga', 'camp', 'vacation'),
#  ('Abruzzo', 'yoga', 'camp', 'vacations'),
#  ('Abruzzo', 'yoga', 'camps'),
#  ('Abruzzo', 'yoga', 'camps', 'center'),
#  ('Abruzzo', 'yoga', 'camps', 'centers'),
#  ('Abruzzo', 'yoga', 'camps', 'centre'),
#  ('Abruzzo', 'yoga', 'camps', 'centres'),
#  ('Abruzzo', 'yoga', 'camps', 'deal'),
#  ('Abruzzo', 'yoga', 'camps', 'deals'),
#  ('Abruzzo', 'yoga', 'camps', 'package'),
#  ('Abruzzo', 'yoga', 'camps', 'packages'),
#  ('Abruzzo', 'yoga', 'camps', 'resort'),
#  ('Abruzzo', 'yoga', 'camps', 'resorts'),
#  ('Abruzzo', 'yoga', 'camps', 'retreat'),
#  ('Abruzzo', 'yoga', 'camps', 'retreats'),
#  ('Abruzzo', 'yoga', 'camps', 'training'),
#  ('Abruzzo', 'yoga', 'camps', 'trainings'),
#  ('Abruzzo', 'yoga', 'camps', 'vacation'),
#  ('Abruzzo', 'yoga', 'camps', 'vacations'),
#  ('Abruzzo', 'yoga', 'center'),
#  ('Abruzzo', 'yoga', 'center', 'camp'),
#  ('Abruzzo', 'yoga', 'center', 'camps'),
#  ('Abruzzo', 'yoga', 'center', 'centre'),
#  ('Abruzzo', 'yoga', 'center', 'centres'),
#  ('Abruzzo', 'yoga', 'center', 'deal'),
#  ('Abruzzo', 'yoga', 'center', 'deals'),
#  ('Abruzzo', 'yoga', 'center', 'package'),
#  ('Abruzzo', 'yoga', 'center', 'packages'),
#  ('Abruzzo', 'yoga', 'center', 'resort'),
#  ('Abruzzo', 'yoga', 'center', 'resorts'),
#  ('Abruzzo', 'yoga', 'center', 'retreat'),
#  ('Abruzzo', 'yoga', 'center', 'retreats'),
#  ('Abruzzo', 'yoga', 'center', 'training'),
#  ('Abruzzo', 'yoga', 'center', 'trainings'),
#  ('Abruzzo', 'yoga', 'center', 'vacation'),
#  ('Abruzzo', 'yoga', 'center', 'vacations'),
#  ('Abruzzo', 'yoga', 'centers'),
#  ('Abruzzo', 'yoga', 'centers', 'camp'),
#  ('Abruzzo', 'yoga', 'centers', 'camps'),
#  ('Abruzzo', 'yoga', 'centers', 'centre'),
#  ('Abruzzo', 'yoga', 'centers', 'centres'),
#  ('Abruzzo', 'yoga', 'centers', 'deal'),
#  ('Abruzzo', 'yoga', 'centers', 'deals'),
#  ('Abruzzo', 'yoga', 'centers', 'package'),
#  ('Abruzzo', 'yoga', 'centers', 'packages'),
#  ('Abruzzo', 'yoga', 'centers', 'resort'),
#  ('Abruzzo', 'yoga', 'centers', 'resorts'),
#  ('Abruzzo', 'yoga', 'centers', 'retreat'),
#  ('Abruzzo', 'yoga', 'centers', 'retreats'),
#  ('Abruzzo', 'yoga', 'centers', 'training'),
#  ('Abruzzo', 'yoga', 'centers', 'trainings'),
#  ('Abruzzo', 'yoga', 'centers', 'vacation'),
#  ('Abruzzo', 'yoga', 'centers', 'vacations'),
#  ('Abruzzo', 'yoga', 'centre'),
#  ('Abruzzo', 'yoga', 'centre', 'camp'),
#  ('Abruzzo', 'yoga', 'centre', 'camps'),
#  ('Abruzzo', 'yoga', 'centre', 'center'),
#  ('Abruzzo', 'yoga', 'centre', 'centers'),
#  ('Abruzzo', 'yoga', 'centre', 'deal'),
#  ('Abruzzo', 'yoga', 'centre', 'deals'),
#  ('Abruzzo', 'yoga', 'centre', 'package'),
#  ('Abruzzo', 'yoga', 'centre', 'packages'),
#  ('Abruzzo', 'yoga', 'centre', 'resort'),
#  ('Abruzzo', 'yoga', 'centre', 'resorts'),
#  ('Abruzzo', 'yoga', 'centre', 'retreat'),
#  ('Abruzzo', 'yoga', 'centre', 'retreats'),
#  ('Abruzzo', 'yoga', 'centre', 'training'),
#  ('Abruzzo', 'yoga', 'centre', 'trainings'),
#  ('Abruzzo', 'yoga', 'centre', 'vacation'),
#  ('Abruzzo', 'yoga', 'centre', 'vacations'),
#  ('Abruzzo', 'yoga', 'centres'),
#  ('Abruzzo', 'yoga', 'centres', 'camp'),
#  ('Abruzzo', 'yoga', 'centres', 'camps'),
#  ('Abruzzo', 'yoga', 'centres', 'center'),
#  ('Abruzzo', 'yoga', 'centres', 'centers'),
#  ('Abruzzo', 'yoga', 'centres', 'deal'),
#  ('Abruzzo', 'yoga', 'centres', 'deals'),
#  ('Abruzzo', 'yoga', 'centres', 'package'),
#  ('Abruzzo', 'yoga', 'centres', 'packages'),
#  ('Abruzzo', 'yoga', 'centres', 'resort'),
#  ('Abruzzo', 'yoga', 'centres', 'resorts'),
#  ('Abruzzo', 'yoga', 'centres', 'retreat'),
#  ('Abruzzo', 'yoga', 'centres', 'retreats'),
#  ('Abruzzo', 'yoga', 'centres', 'training'),
#  ('Abruzzo', 'yoga', 'centres', 'trainings'),
#  ('Abruzzo', 'yoga', 'centres', 'vacation'),
#  ('Abruzzo', 'yoga', 'centres', 'vacations'),
#  ('Abruzzo', 'yoga', 'deal'),
#  ('Abruzzo', 'yoga', 'deal', 'camp'),
#  ('Abruzzo', 'yoga', 'deal', 'camps'),
#  ('Abruzzo', 'yoga', 'deal', 'center'),
#  ('Abruzzo', 'yoga', 'deal', 'centers'),
#  ('Abruzzo', 'yoga', 'deal', 'centre'),
#  ('Abruzzo', 'yoga', 'deal', 'centres'),
#  ('Abruzzo', 'yoga', 'deal', 'package'),
#  ('Abruzzo', 'yoga', 'deal', 'packages'),
#  ('Abruzzo', 'yoga', 'deal', 'resort'),
#  ('Abruzzo', 'yoga', 'deal', 'resorts'),
#  ('Abruzzo', 'yoga', 'deal', 'retreat'),
#  ('Abruzzo', 'yoga', 'deal', 'retreats'),
#  ('Abruzzo', 'yoga', 'deal', 'training'),
#  ('Abruzzo', 'yoga', 'deal', 'trainings'),
#  ('Abruzzo', 'yoga', 'deal', 'vacation'),
#  ('Abruzzo', 'yoga', 'deal', 'vacations'),
#  ('Abruzzo', 'yoga', 'deals'),
#  ('Abruzzo', 'yoga', 'deals', 'camp'),
#  ('Abruzzo', 'yoga', 'deals', 'camps'),
#  ('Abruzzo', 'yoga', 'deals', 'center'),
#  ('Abruzzo', 'yoga', 'deals', 'centers'),
#  ('Abruzzo', 'yoga', 'deals', 'centre'),
#  ('Abruzzo', 'yoga', 'deals', 'centres'),
#  ('Abruzzo', 'yoga', 'deals', 'package'),
#  ('Abruzzo', 'yoga', 'deals', 'packages'),
#  ('Abruzzo', 'yoga', 'deals', 'resort'),
#  ('Abruzzo', 'yoga', 'deals', 'resorts'),
#  ('Abruzzo', 'yoga', 'deals', 'retreat'),
#  ('Abruzzo', 'yoga', 'deals', 'retreats'),
#  ('Abruzzo', 'yoga', 'deals', 'training'),
#  ('Abruzzo', 'yoga', 'deals', 'trainings'),
#  ('Abruzzo', 'yoga', 'deals', 'vacation'),
#  ('Abruzzo', 'yoga', 'deals', 'vacations'),
#  ('Abruzzo', 'yoga', 'package'),
#  ('Abruzzo', 'yoga', 'package', 'camp'),
#  ('Abruzzo', 'yoga', 'package', 'camps'),
#  ('Abruzzo', 'yoga', 'package', 'center'),
#  ('Abruzzo', 'yoga', 'package', 'centers'),
#  ('Abruzzo', 'yoga', 'package', 'centre'),
#  ('Abruzzo', 'yoga', 'package', 'centres'),
#  ('Abruzzo', 'yoga', 'package', 'deal'),
#  ('Abruzzo', 'yoga', 'package', 'deals'),
#  ('Abruzzo', 'yoga', 'package', 'resort'),
#  ('Abruzzo', 'yoga', 'package', 'resorts'),
#  ('Abruzzo', 'yoga', 'package', 'retreat'),
#  ('Abruzzo', 'yoga', 'package', 'retreats'),
#  ('Abruzzo', 'yoga', 'package', 'training'),
#  ('Abruzzo', 'yoga', 'package', 'trainings'),
#  ('Abruzzo', 'yoga', 'package', 'vacation'),
#  ('Abruzzo', 'yoga', 'package', 'vacations'),
#  ('Abruzzo', 'yoga', 'packages'),
#  ('Abruzzo', 'yoga', 'packages', 'camp'),
#  ('Abruzzo', 'yoga', 'packages', 'camps'),
#  ('Abruzzo', 'yoga', 'packages', 'center'),
#  ('Abruzzo', 'yoga', 'packages', 'centers'),
#  ('Abruzzo', 'yoga', 'packages', 'centre'),
#  ('Abruzzo', 'yoga', 'packages', 'centres'),
#  ('Abruzzo', 'yoga', 'packages', 'deal'),
#  ('Abruzzo', 'yoga', 'packages', 'deals'),
#  ('Abruzzo', 'yoga', 'packages', 'resort'),
#  ('Abruzzo', 'yoga', 'packages', 'resorts'),
#  ('Abruzzo', 'yoga', 'packages', 'retreat'),
#  ('Abruzzo', 'yoga', 'packages', 'retreats'),
#  ('Abruzzo', 'yoga', 'packages', 'training'),
#  ('Abruzzo', 'yoga', 'packages', 'trainings'),
#  ('Abruzzo', 'yoga', 'packages', 'vacation'),
#  ('Abruzzo', 'yoga', 'packages', 'vacations'),
#  ('Abruzzo', 'yoga', 'resort'),
#  ('Abruzzo', 'yoga', 'resort', 'camp'),
#  ('Abruzzo', 'yoga', 'resort', 'camps'),
#  ('Abruzzo', 'yoga', 'resort', 'center'),
#  ('Abruzzo', 'yoga', 'resort', 'centers'),
#  ('Abruzzo', 'yoga', 'resort', 'centre'),
#  ('Abruzzo', 'yoga', 'resort', 'centres'),
#  ('Abruzzo', 'yoga', 'resort', 'deal'),
#  ('Abruzzo', 'yoga', 'resort', 'deals'),
#  ('Abruzzo', 'yoga', 'resort', 'package'),
#  ('Abruzzo', 'yoga', 'resort', 'packages'),
#  ('Abruzzo', 'yoga', 'resort', 'retreat'),
#  ('Abruzzo', 'yoga', 'resort', 'retreats'),
#  ('Abruzzo', 'yoga', 'resort', 'training'),
#  ('Abruzzo', 'yoga', 'resort', 'trainings'),
#  ('Abruzzo', 'yoga', 'resort', 'vacation'),
#  ('Abruzzo', 'yoga', 'resort', 'vacations'),
#  ('Abruzzo', 'yoga', 'resorts'),
#  ('Abruzzo', 'yoga', 'resorts', 'camp'),
#  ('Abruzzo', 'yoga', 'resorts', 'camps'),
#  ('Abruzzo', 'yoga', 'resorts', 'center'),
#  ('Abruzzo', 'yoga', 'resorts', 'centers'),
#  ('Abruzzo', 'yoga', 'resorts', 'centre'),
#  ('Abruzzo', 'yoga', 'resorts', 'centres'),
#  ('Abruzzo', 'yoga', 'resorts', 'deal'),
#  ('Abruzzo', 'yoga', 'resorts', 'deals'),
#  ('Abruzzo', 'yoga', 'resorts', 'package'),
#  ('Abruzzo', 'yoga', 'resorts', 'packages'),
#  ('Abruzzo', 'yoga', 'resorts', 'retreat'),
#  ('Abruzzo', 'yoga', 'resorts', 'retreats'),
#  ('Abruzzo', 'yoga', 'resorts', 'training'),
#  ('Abruzzo', 'yoga', 'resorts', 'trainings'),
#  ('Abruzzo', 'yoga', 'resorts', 'vacation'),
#  ('Abruzzo', 'yoga', 'resorts', 'vacations'),
#  ('Abruzzo', 'yoga', 'retreat'),
#  ('Abruzzo', 'yoga', 'retreat', 'camp'),
#  ('Abruzzo', 'yoga', 'retreat', 'camps'),
#  ('Abruzzo', 'yoga', 'retreat', 'center'),
#  ('Abruzzo', 'yoga', 'retreat', 'centers'),
#  ('Abruzzo', 'yoga', 'retreat', 'centre'),
#  ('Abruzzo', 'yoga', 'retreat', 'centres'),
#  ('Abruzzo', 'yoga', 'retreat', 'deal'),
#  ('Abruzzo', 'yoga', 'retreat', 'deals'),
#  ('Abruzzo', 'yoga', 'retreat', 'package'),
#  ('Abruzzo', 'yoga', 'retreat', 'packages'),
#  ('Abruzzo', 'yoga', 'retreat', 'resort'),
#  ('Abruzzo', 'yoga', 'retreat', 'resorts'),
#  ('Abruzzo', 'yoga', 'retreat', 'training'),
#  ('Abruzzo', 'yoga', 'retreat', 'trainings'),
#  ('Abruzzo', 'yoga', 'retreat', 'vacation'),
#  ('Abruzzo', 'yoga', 'retreat', 'vacations'),
#  ('Abruzzo', 'yoga', 'retreats'),
#  ('Abruzzo', 'yoga', 'retreats', 'camp'),
#  ('Abruzzo', 'yoga', 'retreats', 'camps'),
#  ('Abruzzo', 'yoga', 'retreats', 'center'),
#  ('Abruzzo', 'yoga', 'retreats', 'centers'),
#  ('Abruzzo', 'yoga', 'retreats', 'centre'),
#  ('Abruzzo', 'yoga', 'retreats', 'centres'),
#  ('Abruzzo', 'yoga', 'retreats', 'deal'),
#  ('Abruzzo', 'yoga', 'retreats', 'deals'),
#  ('Abruzzo', 'yoga', 'retreats', 'package'),
#  ('Abruzzo', 'yoga', 'retreats', 'packages'),
#  ('Abruzzo', 'yoga', 'retreats', 'resort'),
#  ('Abruzzo', 'yoga', 'retreats', 'resorts'),
#  ('Abruzzo', 'yoga', 'retreats', 'training'),
#  ('Abruzzo', 'yoga', 'retreats', 'trainings'),
#  ('Abruzzo', 'yoga', 'retreats', 'vacation'),
#  ('Abruzzo', 'yoga', 'retreats', 'vacations'),
#  ('Abruzzo', 'yoga', 'training'),
#  ('Abruzzo', 'yoga', 'training', 'camp'),
#  ('Abruzzo', 'yoga', 'training', 'camps'),
#  ('Abruzzo', 'yoga', 'training', 'center'),
#  ('Abruzzo', 'yoga', 'training', 'centers'),
#  ('Abruzzo', 'yoga', 'training', 'centre'),
#  ('Abruzzo', 'yoga', 'training', 'centres'),
#  ('Abruzzo', 'yoga', 'training', 'deal'),
#  ('Abruzzo', 'yoga', 'training', 'deals'),
#  ('Abruzzo', 'yoga', 'training', 'package'),
#  ('Abruzzo', 'yoga', 'training', 'packages'),
#  ('Abruzzo', 'yoga', 'training', 'resort'),
#  ('Abruzzo', 'yoga', 'training', 'resorts'),
#  ('Abruzzo', 'yoga', 'training', 'retreat'),
#  ('Abruzzo', 'yoga', 'training', 'retreats'),
#  ('Abruzzo', 'yoga', 'training', 'vacation'),
#  ('Abruzzo', 'yoga', 'training', 'vacations'),
#  ('Abruzzo', 'yoga', 'trainings'),
#  ('Abruzzo', 'yoga', 'trainings', 'camp'),
#  ('Abruzzo', 'yoga', 'trainings', 'camps'),
#  ('Abruzzo', 'yoga', 'trainings', 'center'),
#  ('Abruzzo', 'yoga', 'trainings', 'centers'),
#  ('Abruzzo', 'yoga', 'trainings', 'centre'),
#  ('Abruzzo', 'yoga', 'trainings', 'centres'),
#  ('Abruzzo', 'yoga', 'trainings', 'deal'),
#  ('Abruzzo', 'yoga', 'trainings', 'deals'),
#  ('Abruzzo', 'yoga', 'trainings', 'package'),
#  ('Abruzzo', 'yoga', 'trainings', 'packages'),
#  ('Abruzzo', 'yoga', 'trainings', 'resort'),
#  ('Abruzzo', 'yoga', 'trainings', 'resorts'),
#  ('Abruzzo', 'yoga', 'trainings', 'retreat'),
#  ('Abruzzo', 'yoga', 'trainings', 'retreats'),
#  ('Abruzzo', 'yoga', 'trainings', 'vacation'),
#  ('Abruzzo', 'yoga', 'trainings', 'vacations'),
#  ('Abruzzo', 'yoga', 'vacation'),
#  ('Abruzzo', 'yoga', 'vacation', 'camp'),
#  ('Abruzzo', 'yoga', 'vacation', 'camps'),
#  ('Abruzzo', 'yoga', 'vacation', 'center'),
#  ('Abruzzo', 'yoga', 'vacation', 'centers'),
#  ('Abruzzo', 'yoga', 'vacation', 'centre'),
#  ('Abruzzo', 'yoga', 'vacation', 'centres'),
#  ('Abruzzo', 'yoga', 'vacation', 'deal'),
#  ('Abruzzo', 'yoga', 'vacation', 'deals'),
#  ('Abruzzo', 'yoga', 'vacation', 'package'),
#  ('Abruzzo', 'yoga', 'vacation', 'packages'),
#  ('Abruzzo', 'yoga', 'vacation', 'resort'),
#  ('Abruzzo', 'yoga', 'vacation', 'resorts'),
#  ('Abruzzo', 'yoga', 'vacation', 'retreat'),
#  ('Abruzzo', 'yoga', 'vacation', 'retreats'),
#  ('Abruzzo', 'yoga', 'vacation', 'training'),
#  ('Abruzzo', 'yoga', 'vacation', 'trainings'),
#  ('Abruzzo', 'yoga', 'vacations'),
#  ('Abruzzo', 'yoga', 'vacations', 'camp'),
#  ('Abruzzo', 'yoga', 'vacations', 'camps'),
#  ('Abruzzo', 'yoga', 'vacations', 'center'),
#  ('Abruzzo', 'yoga', 'vacations', 'centers'),
#  ('Abruzzo', 'yoga', 'vacations', 'centre'),
#  ('Abruzzo', 'yoga', 'vacations', 'centres'),
#  ('Abruzzo', 'yoga', 'vacations', 'deal'),
#  ('Abruzzo', 'yoga', 'vacations', 'deals'),
#  ('Abruzzo', 'yoga', 'vacations', 'package'),
#  ('Abruzzo', 'yoga', 'vacations', 'packages'),
#  ('Abruzzo', 'yoga', 'vacations', 'resort'),
#  ('Abruzzo', 'yoga', 'vacations', 'resorts'),
#  ('Abruzzo', 'yoga', 'vacations', 'retreat'),
#  ('Abruzzo', 'yoga', 'vacations', 'retreats'),
#  ('Abruzzo', 'yoga', 'vacations', 'training'),
#  ('Abruzzo', 'yoga', 'vacations', 'trainings'),
#  ('Adriatic Sea', 'yoga', 'camp'),
#  ('Adriatic Sea', 'yoga', 'camp', 'center'),
#  ('Adriatic Sea', 'yoga', 'camp', 'centers'),
#  ('Adriatic Sea', 'yoga', 'camp', 'centre'),
#  ('Adriatic Sea', 'yoga', 'camp', 'centres'),
#  ('Adriatic Sea', 'yoga', 'camp', 'deal'),
#  ('Adriatic Sea', 'yoga', 'camp', 'deals'),
#  ('Adriatic Sea', 'yoga', 'camp', 'package'),
#  ('Adriatic Sea', 'yoga', 'camp', 'packages'),
#  ('Adriatic Sea', 'yoga', 'camp', 'resort'),
#  ('Adriatic Sea', 'yoga', 'camp', 'resorts'),
#  ('Adriatic Sea', 'yoga', 'camp', 'retreat'),
#  ('Adriatic Sea', 'yoga', 'camp', 'retreats'),
#  ('Adriatic Sea', 'yoga', 'camp', 'training'),
#  ('Adriatic Sea', 'yoga', 'camp', 'trainings'),
#  ('Adriatic Sea', 'yoga', 'camp', 'vacation'),
#  ('Adriatic Sea', 'yoga', 'camp', 'vacations'),
#  ('Adriatic Sea', 'yoga', 'camps'),
#  ('Adriatic Sea', 'yoga', 'camps', 'center'),
#  ('Adriatic Sea', 'yoga', 'camps', 'centers'),
#  ('Adriatic Sea', 'yoga', 'camps', 'centre'),
#  ('Adriatic Sea', 'yoga', 'camps', 'centres'),
#  ('Adriatic Sea', 'yoga', 'camps', 'deal'),
#  ('Adriatic Sea', 'yoga', 'camps', 'deals'),
#  ('Adriatic Sea', 'yoga', 'camps', 'package'),
#  ('Adriatic Sea', 'yoga', 'camps', 'packages'),
#  ('Adriatic Sea', 'yoga', 'camps', 'resort'),
#  ('Adriatic Sea', 'yoga', 'camps', 'resorts'),
#  ('Adriatic Sea', 'yoga', 'camps', 'retreat'),
#  ('Adriatic Sea', 'yoga', 'camps', 'retreats'),
#  ('Adriatic Sea', 'yoga', 'camps', 'training'),
#  ('Adriatic Sea', 'yoga', 'camps', 'trainings'),
#  ('Adriatic Sea', 'yoga', 'camps', 'vacation'),
#  ('Adriatic Sea', 'yoga', 'camps', 'vacations'),
#  ('Adriatic Sea', 'yoga', 'center'),
#  ('Adriatic Sea', 'yoga', 'center', 'camp'),
#  ('Adriatic Sea', 'yoga', 'center', 'camps'),
#  ('Adriatic Sea', 'yoga', 'center', 'centre'),
#  ('Adriatic Sea', 'yoga', 'center', 'centres'),
#  ('Adriatic Sea', 'yoga', 'center', 'deal'),
#  ('Adriatic Sea', 'yoga', 'center', 'deals'),
#  ('Adriatic Sea', 'yoga', 'center', 'package'),
#  ('Adriatic Sea', 'yoga', 'center', 'packages'),
#  ('Adriatic Sea', 'yoga', 'center', 'resort'),
#  ('Adriatic Sea', 'yoga', 'center', 'resorts'),
#  ('Adriatic Sea', 'yoga', 'center', 'retreat'),
#  ('Adriatic Sea', 'yoga', 'center', 'retreats'),
#  ('Adriatic Sea', 'yoga', 'center', 'training'),
#  ('Adriatic Sea', 'yoga', 'center', 'trainings'),
#  ('Adriatic Sea', 'yoga', 'center', 'vacation'),
#  ('Adriatic Sea', 'yoga', 'center', 'vacations'),
#  ('Adriatic Sea', 'yoga', 'centers'),
#  ('Adriatic Sea', 'yoga', 'centers', 'camp'),
#  ('Adriatic Sea', 'yoga', 'centers', 'camps'),
#  ('Adriatic Sea', 'yoga', 'centers', 'centre'),
#  ('Adriatic Sea', 'yoga', 'centers', 'centres'),
#  ('Adriatic Sea', 'yoga', 'centers', 'deal'),
#  ('Adriatic Sea', 'yoga', 'centers', 'deals'),
#  ('Adriatic Sea', 'yoga', 'centers', 'package'),
#  ('Adriatic Sea', 'yoga', 'centers', 'packages'),
#  ('Adriatic Sea', 'yoga', 'centers', 'resort'),
#  ('Adriatic Sea', 'yoga', 'centers', 'resorts'),
#  ('Adriatic Sea', 'yoga', 'centers', 'retreat'),
#  ('Adriatic Sea', 'yoga', 'centers', 'retreats'),
#  ('Adriatic Sea', 'yoga', 'centers', 'training'),
#  ('Adriatic Sea', 'yoga', 'centers', 'trainings'),
#  ('Adriatic Sea', 'yoga', 'centers', 'vacation'),
#  ('Adriatic Sea', 'yoga', 'centers', 'vacations'),
#  ('Adriatic Sea', 'yoga', 'centre'),
#  ('Adriatic Sea', 'yoga', 'centre', 'camp'),
#  ('Adriatic Sea', 'yoga', 'centre', 'camps'),
#  ('Adriatic Sea', 'yoga', 'centre', 'center'),
#  ('Adriatic Sea', 'yoga', 'centre', 'centers'),
#  ('Adriatic Sea', 'yoga', 'centre', 'deal'),
#  ('Adriatic Sea', 'yoga', 'centre', 'deals'),
#  ('Adriatic Sea', 'yoga', 'centre', 'package'),
#  ('Adriatic Sea', 'yoga', 'centre', 'packages'),
#  ('Adriatic Sea', 'yoga', 'centre', 'resort'),
#  ('Adriatic Sea', 'yoga', 'centre', 'resorts'),
#  ('Adriatic Sea', 'yoga', 'centre', 'retreat'),
#  ('Adriatic Sea', 'yoga', 'centre', 'retreats'),
#  ('Adriatic Sea', 'yoga', 'centre', 'training'),
#  ...]

# %%
back_starting_idx = int(len(all_comb) / 3)

# %%
for i in range(back_starting_idx):
    dest_camp.append(all_comb[i][0])

# %%
for i in range(int(len(all_comb))-back_starting_idx):
    dest_camp.append(all_comb[i][-1].replace('in ', ''))

# %%
#join strings within the list
results = []

for item in all_comb:
    results.append('['+(' '.join(item))+']')
    i+1

# %%
dest_camp
# Out:
# [' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  ' Matale District',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abel Tasman National Park',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Abruzzo',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  'Adriatic Sea',
#  ...]

# %%
keyword_state = 'enabled' * len(results)
match_type = ['Exact'] * len(results)
campaign_kw = ['Longtail %s %s']
