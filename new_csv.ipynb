# %%
done_urls = [
"www.bookyogaretreats.com/all/c/short/d/europe",
"www.bookyogaretreats.com/all/d/asia-and-oceania/philippines",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india/goa",
"www.bookyogaretreats.com/all/c/budget-retreats/d/asia-and-oceania",
"www.bookyogaretreats.com/all/d/europe/croatia",
"www.bookyogaretreats.com/all/c/budget-retreats/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/c/budget-retreats/d/europe/united-kingdom",
"www.bookyogateachertraining.com/all/s/yoga-vinyasa",
"www.bookyogaretreats.com/all/c/holidays/d/europe",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/hawaii",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/florida",
"www.bookyogaretreats.com/all/s/vinyasa-yoga",
"www.bookyogaretreats.com/all/c/yoga-detox-retreats",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/mexico",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean/usa/california",
"www.bookyogateachertraining.com/all/d/europe",
"www.bookyogaretreats.com/all/c/budget-retreats/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/?arrival_date=2017-02-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/indonesia",
"www.bookyogaretreats.com/all/c/yoga-meditation-retreats",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india",
"www.bookyogaretreats.com/?arrival_date=2017-03-15&flexible=15",
"www.bookyogaretreats.com/all/c/yoga-meditation-retreats/d/the-americas-and-caribbean/usa/florida",
"www.bookyogaretreats.com/all/c/budget-retreats/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/yoga-surf/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/?arrival_date=2016-05-15&flexible=15",
"www.bookyogateachertraining.com/all/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/c/short",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/s/bikram-hot-yoga",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india",
"www.bookyogaretreats.com/?arrival_date=2016-12-15&flexible=15",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india/goa",
"www.bookyogaretreats.com/all/c/budget-retreats/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/c/beach-retreats/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/yoga-surf",
"www.bookyogaretreats.com/all/c/budget-retreats",
"www.bookyogaretreats.com/all/d/asia-and-oceania/vietnam",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/c/holidays/d/europe/united-kingdom",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/usa/hawaii",
"www.bookyogaretreats.com/?arrival_date=2016-06-15&flexible=15",
"www.bookyogaretreats.com/all/d/europe/united-kingdom/england",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/d/europe/france",
"www.bookyogaretreats.com/all/c/holidays/d/europe/greece",
"www.bookyogaretreats.com/all/d/europe/greece",
"www.bookyogaretreats.com/?arrival_date=2016-07-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2016-10-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2016-09-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/africa-and-the-middle-east/morocco",
"www.bookyogaretreats.com/?arrival_date=2016-11-15&flexible=15",
"www.bookyogaretreats.com/?arrival_date=2017-01-15&flexible=15",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/asia-and-oceania/nepal",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa/california",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/india/kerala",
"www.bookyogaretreats.com/?arrival_date=2016-08-15&flexible=15",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/d/asia-and-oceania/cambodia",
"www.bookyogaretreats.com/all/d/europe/spain/ibiza",
"www.bookyogaretreats.com/all/c/short/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/europe/spain/mallorca",
"www.bookyogaretreats.com/all/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain/canary-islands",
"www.bookyogaretreats.com/all/c/yoga-surf/d/asia-and-oceania/indonesia/bali",
"www.bookyogaretreats.com/all/d/europe/spain",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain",
"www.bookyogaretreats.com/all/c/holidays/d/europe/portugal",
"www.bookyogaretreats.com/all/s/ashtanga-yoga",
"www.bookyogaretreats.com/all/d/asia-and-oceania/india/kerala",
"www.bookyogaretreats.com/all/d/europe/italy",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/vietnam",
"www.bookyogaretreats.com/all/d/asia-and-oceania/new-zealand",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/usa",
"www.bookyogaretreats.com/all/d/europe",
"www.bookyogaretreats.com/all/d/europe/spain/canary-islands",
"www.bookyogaretreats.com/all/c/holidays/d/europe/spain/ibiza",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/sri-lanka",
"www.bookyogaretreats.com/all/c/holidays/d/the-americas-and-caribbean/costa-rica",
"www.bookyogateachertraining.com/",
"www.bookyogaretreats.com/all/d/asia-and-oceania/australia",
"www.bookyogaretreats.com/?arrival_date=2016-04-15&flexible=15",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/USA",
"www.bookyogaretreats.com/all/d/europe/portugal",
"www.bookyogaretreats.com/all/d/asia-and-oceania/sri-lanka",
"www.bookyogaretreats.com",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/cambodia",
"www.bookyogateachertraining.com/all/d/the-americas-and-caribbean",
"www.bookyogaretreats.com/all/d/africa-and-the-middle-east/morocco",
"www.bookyogaretreats.com/all/d/africa-and-the-middle-east",
"www.bookyogaretreats.com/all/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/all/c/holidays/d/asia-and-oceania/australia",
"www.bookyogaretreats.com/all/d/asia-and-oceania/indonesia",
"www.bookyogateachertraining.com/all/d/the-americas-and-caribbean/costa-rica",
"www.bookyogaretreats.com/all/d/europe/united-kingdom",
"www.bookyogaretreats.com/all/d/asia-and-oceania/thailand",
"www.bookyogaretreats.com/all/d/asia-and-oceania"
]

# %%
import csv
import codecs

file_name = 'steph.csv'

basic_dict = {} #{destination id : destination name}
ready_dict = {} #{destinaiton name: [destination id, destination type, number of listings, url, country name]}

names = []
ready_names = []
ready_urls = []


#setup basic_dict (everything), names (everything), ready_urls (only ones without adgroups)

with codecs.open(file_name, 'r', encoding = 'utf-8', errors = 'ignore') as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        names.append(row['name'])
        basic_dict[int(row['destination_id'])] = row['name']
        if row['concat'] not in done_urls: #only for urls that do not have adgroups yet
            ready_urls.append(row['concat']) #add all urls

# %%
#setup ready_dict 

#ready_dict['key'][0] = destination id
#ready_dict['key'][1] = destination type
#ready_dict['key'][2] = number of listings
#ready_dict['key'][3] = URL (landing page)
#ready_dict['key'][4] = country name

with codecs.open(file_name, 'r', encoding = 'utf-8', errors = 'ignore') as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        if row['concat'] not in done_urls:
            ready_dict[row['name']] = [row['destination_id'], row['type1'], row['nr_listings'], row['concat'], basic_dict[int(row['parent_id1'])]]

# %%
for item in names:
    if item in ready_dict:
        ready_names.append(item)

# %%
headlines1 = []
headlines2 = []

descs11 = []
descs12 = []

descs21 = []
descs22 = []

for i in range(len(ready_names)):
    headlines1.append("%s Yoga Retreats in %s" %(ready_dict[ready_names[i]][2], ready_names[i]))
    headlines2.append("%s Yoga Retreats 2016" %ready_names[i])
    
    descs11.append('Top Rated & Best Price Guarantee!')
    descs12.append('Compare and Book the Best Deals')
    
    descs21.append('Compare and Book the Best Deals!')
    descs22.append('Reviews & Best Price Guarantee')

# %%
len(headlines1) == len(headlines2) == len(descs11) == len(descs12) == len(descs21) == len(descs22)
# Out:
# True

# %%
for i in range(len(headlines1)):
    if len(headlines1[i]) > 35: #if the headline is too long
        headlines1[i] = headlines1[i].replace(' in ', ' ') #get rid of the 'in'
        if len(headlines1[i]) > 35: #if the headline is still too long, 
            headlines1[i] = ''.join([i for i in headlines1[i] if not i.isdigit()]) #get rid of number of listings
            headlines1[i] = headlines1[i].replace(' Yoga', 'Yoga') #fix ' Yoga Retreats in England' -> 'Yoga Retreats in England'
            if len(headlines1[i]) > 35: #if the headline is still too long, 
                if 'area' in headlines1[i]: 
                    headlines1[i] = headlines1[i].replace(' area', '') #take out the 'area' e.g. 'Yoga Retreats Southern Mountain Area' -> 'Yoga Retreats Southern Mountain'
                    if len(headlines1[i]) > 35: #if the headline is still too long, 
                        headlines1[i].replace('Yoga Retreats', 'YogaRetreats') #make Yoga Retreats as one word
                        print(headlines1[i], len(headlines1[i]))

# %%
for item in headlines1:
    if len(item) > 35:
        print(item, len(item), 'too long')
# Out:
# Yoga Retreats Santa Cruz de Tenerife 36 too long
# Yoga Retreats Yorkshire and the Humber 38 too long
# Yoga Retreats Santa Maria del Focallo 37 too long
# Yoga Retreats Central Coast California 38 too long
# Yoga Retreats South Sinai Governorate 37 too long
# Yoga Retreats French Riviera-Cote d'Azur 40 too long
# Yoga Retreats Sierra Espuna Mountains 37 too long
# Yoga Retreats Marrakesh-Tensift-El Haouz 40 too long
# Yoga Retreats Alpes-de-Haute-Provence 37 too long
# Yoga Retreats Dubrovnik-Neretva County 38 too long
# Yoga Retreats Provence-Alpes-Cote d'Azur 40 too long
# Yoga Retreats Amphoe Mueang Chiang Rai 38 too long
# Yoga Retreats Abel Tasman National Park 39 too long
# Yoga Retreats Shivapuri Nagarjun National Park 46 too long
# Yoga Retreats Sainte-Colombe-sur-l'Hers 39 too long
# Yoga Retreats Costa Vicentina National Park 43 too long
# Yoga Retreats Sant Carles de Peralta 36 too long
# Yoga Retreats Sangre de Cristo Mountains 40 too long
# Yoga Retreats Mecklenburg-Vorpommern 36 too long

# %%
for item in headlines1:
    if len(item) > 35:
        item = item.replace(' in ', ' ')
        if len(item) > 35:
            item = ''.join([i for i in item if not i.isdigit()])
            item = item.replace(' Yoga', 'Yoga')
            if len(item) > 35:
                if 'area' in item:
                    item = item.replace(' area', '')
                    if len(item) > 35:
# Out:
# Yoga Retreats Santa Cruz de Tenerife 36
# Yoga Retreats Yorkshire and the Humber 38
# Yoga Retreats Santa Maria del Focallo 37
# Yoga Retreats Central Coast California 38
# Yoga Retreats South Sinai Governorate 37
# Yoga Retreats French Riviera-Cote d'Azur 40
# Yoga Retreats Sierra Espuna Mountains 37
# Yoga Retreats Marrakesh-Tensift-El Haouz 40
# Yoga Retreats Alpes-de-Haute-Provence 37
# Yoga Retreats Dubrovnik-Neretva County 38
# Yoga Retreats Provence-Alpes-Cote d'Azur 40
# Yoga Retreats Amphoe Mueang Chiang Rai 38
# Yoga Retreats Abel Tasman National Park 39
# Yoga Retreats Shivapuri Nagarjun National Park 46
# Yoga Retreats Sainte-Colombe-sur-l'Hers 39
# Yoga Retreats Costa Vicentina National Park 43
# Yoga Retreats Sant Carles de Peralta 36
# Yoga Retreats Sangre de Cristo Mountains 40
# Yoga Retreats Galgiriyawa Mountains 35
# Yoga Retreats Mecklenburg-Vorpommern 36

# %%
''.join([i for i in item if not i.isdigit()])
# Out:
# ' Yoga Retreats in Laem Sor Beach'

# %%
item.replace(' Y', 'Y')
# Out:
# '7Yoga Retreats in Laem Sor Beach'

# %%
len('Yoga Retreats Galgiriyawa Mountains')
# Out:
# 35

# %%
len('Yoga Retreats Mecklenburg-Vorpommern')
# Out:
# 36

# %%
item
# Out:
# '7 Yoga Retreats in Laem Sor Beach'

# %%
headlines1
# Out:
# ['3 Yoga Retreats in Coromandel',
#  '8 Yoga Retreats in Takaka',
#  '12 Yoga Retreats in Colares',
#  '4 Yoga Retreats in Skinnskatteberg',
#  '4 Yoga Retreats in Sabine Hills',
#  '3 Yoga Retreats in Wayanad',
#  '19 Yoga Retreats in Cabuya',
#  '3 Yoga Retreats in Antalya',
#  '4 Yoga Retreats in Grasse',
#  '13 Yoga Retreats in Bardez',
#  '4 Yoga Retreats in Andes',
#  '3 Yoga Retreats in Dalaman',
#  '13 Yoga Retreats in Arambol',
#  '3 Yoga Retreats in Allepey',
#  '12 Yoga Retreats in Badrinath',
#  '5 Yoga Retreats in Tyrrhenian Sea',
#  '85 Yoga Retreats in Puntarenas',
#  '3 Yoga Retreats in Mancora',
#  '4 Yoga Retreats in Split',
#  '3 Yoga Retreats in Carbonia-Iglesias',
#  '3 Yoga Retreats in Mediterranean Sea',
#  '7 Yoga Retreats in Ashwem',
#  '4 Yoga Retreats in Athens',
#  '9 Yoga Retreats in Pushkar',
#  '3 Yoga Retreats in Lamu Island',
#  '3 Yoga Retreats in Lamu Archipelago',
#  '3 Yoga Retreats in Shela',
#  '4 Yoga Retreats in Dead sea',
#  '29 Yoga Retreats in Dharamsala',
#  '7 Yoga Retreats in San Martin',
#  '5 Yoga Retreats in Hue',
#  '3 Yoga Retreats in Limatambo',
#  '8 Yoga Retreats in Southern France',
#  '4 Yoga Retreats in Santiago Atitlan',
#  '6 Yoga Retreats in Lincolnshire',
#  '14 Yoga Retreats in Rincon',
#  '3 Yoga Retreats in Jharkhand',
#  '4 Yoga Retreats in Anta',
#  '22 Yoga Retreats in Cascais',
#  '7 Yoga Retreats in Anjuna',
#  '7 Yoga Retreats in Aourir',
#  '7 Yoga Retreats in Vis',
#  '4 Yoga Retreats in Banana Beach',
#  '3 Yoga Retreats in Mysore',
#  '3 Yoga Retreats in Jammu and Kashmir',
#  '14 Yoga Retreats in Rajasthan',
#  '10 Yoga Retreats in Nelangmangala',
#  '10 Yoga Retreats in Agonda',
#  '3 Yoga Retreats in Palakkad',
#  '6 Yoga Retreats in Maharashtra',
#  '3 Yoga Retreats in Thessaloniki',
#  '3 Yoga Retreats in Khajuraho',
#  '7 Yoga Retreats in Palolem',
#  '3 Yoga Retreats in Smaland',
#  '7 Yoga Retreats in Chowara',
#  '5 Yoga Retreats in Basque Country',
#  '7 Yoga Retreats in Pondicherry',
#  '3 Yoga Retreats in Valais',
#  '4 Yoga Retreats in Western Cape',
#  '3 Yoga Retreats in Ezeiza',
#  '14 Yoga Retreats in Aegean',
#  '3 Yoga Retreats in Tarifa',
#  '7 Yoga Retreats in Sezzadio',
#  '3 Yoga Retreats in Caleta de Famara',
#  '4 Yoga Retreats in Faralya',
#  '6 Yoga Retreats in Assagao',
#  '3 Yoga Retreats in Buenos Aires',
#  '4 Yoga Retreats in Dol',
#  '5 Yoga Retreats in Garabito',
#  '4 Yoga Retreats in Swiss Alps',
#  '3 Yoga Retreats in Paradise Island',
#  '3 Yoga Retreats in Angra dos Reis',
#  '3 Yoga Retreats in Ilha Grande',
#  '6 Yoga Retreats in Medina',
#  '9 Yoga Retreats in Cape Town',
#  '59 Yoga Retreats in Nicoya Peninsula',
#  '3 Yoga Retreats in Boracay Island',
#  '4 Yoga Retreats in Whistler',
#  '12 Yoga Retreats in Bangalore',
#  '14 Yoga Retreats in Junas Waddo',
#  '12 Yoga Retreats in Siena',
#  '4 Yoga Retreats in Laurentides',
#  '23 Yoga Retreats in Nosara',
#  '3 Yoga Retreats in Limousin',
#  '8 Yoga Retreats in Kalutara',
#  '4 Yoga Retreats in North Malé Atoll',
#  '3 Yoga Retreats in Loja',
#  '4 Yoga Retreats in Vilcabamba',
#  '3 Yoga Retreats in Canton of Bern',
#  '3 Yoga Retreats in Montreal',
#  '3 Yoga Retreats in Hawi',
#  '5 Yoga Retreats in Charente',
#  '86 Yoga Retreats in California',
#  '4 Yoga Retreats in Havana',
#  '3 Yoga Retreats in Vancouver Island',
#  '8 Yoga Retreats in Alghero',
#  '8 Yoga Retreats in Playa Grande',
#  '5 Yoga Retreats in Kohala',
#  '3 Yoga Retreats in Koh Lanta',
#  '4 Yoga Retreats in San Diego',
#  '3 Yoga Retreats in Morzine',
#  '3 Yoga Retreats in Central Coast',
#  '4 Yoga Retreats in Castel Giorgio',
#  '3 Yoga Retreats in Malay',
#  '3 Yoga Retreats in Cabarete',
#  '10 Yoga Retreats in Golden Bay',
#  '5 Yoga Retreats in Bari',
#  '6 Yoga Retreats in Camiguin',
#  '8 Yoga Retreats in San Luis Obispo',
#  '4 Yoga Retreats in North Brabant',
#  '5 Yoga Retreats in Chirripó',
#  '4 Yoga Retreats in St. Isidoro',
#  '10 Yoga Retreats in Loule',
#  '13 Yoga Retreats in Ericeira',
#  '5 Yoga Retreats in Palhais',
#  '17 Yoga Retreats in Montezuma',
#  '4 Yoga Retreats in Galapagos',
#  '5 Yoga Retreats in Puerto Plata',
#  '4 Yoga Retreats in Panglao',
#  '6 Yoga Retreats in South West England',
#  '3 Yoga Retreats in Bahia',
#  '3 Yoga Retreats in Aklan',
#  '4 Yoga Retreats in Merzouga',
#  '3 Yoga Retreats in Praia da Luz',
#  '3 Yoga Retreats in Bay Islands',
#  '5 Yoga Retreats in Santa Cruz de Tenerife',
#  '12 Yoga Retreats in Pichincha',
#  '6 Yoga Retreats in Pavones',
#  '3 Yoga Retreats in Itria Valley',
#  "3 Yoga Retreats in Damnak Chang'aeur",
#  '6 Yoga Retreats in Osa Peninsula',
#  '20 Yoga Retreats in Byron Bay',
#  '3 Yoga Retreats in Braçal',
#  '9 Yoga Retreats in Quepos',
#  '4 Yoga Retreats in Guerrero',
#  '5 Yoga Retreats in Mazunte',
#  '4 Yoga Retreats in Aeolian Islands',
#  '10 Yoga Retreats in Oaxaca',
#  '3 Yoga Retreats in Saint Ann',
#  '4 Yoga Retreats in Palawan',
#  '10 Yoga Retreats in Puerto Vallarta',
#  '9 Yoga Retreats in Punta Banco',
#  '9 Yoga Retreats in Costa Smeralda',
#  '10 Yoga Retreats in Arundel',
#  '9 Yoga Retreats in Todos Santos',
#  '3 Yoga Retreats in Troncones',
#  '4 Yoga Retreats in Yorkshire and the Humber',
#  '10 Yoga Retreats in French Alps',
#  '5 Yoga Retreats in Styria',
#  '8 Yoga Retreats in Huesca',
#  '3 Yoga Retreats in Kent',
#  '4 Yoga Retreats in Payangan',
#  '4 Yoga Retreats in South West France',
#  '4 Yoga Retreats in Mengwi',
#  '13 Yoga Retreats in Sayalonga',
#  '4 Yoga Retreats in China',
#  '7 Yoga Retreats in Santa Maria del Focallo',
#  '6 Yoga Retreats in Puna',
#  '6 Yoga Retreats in Puerto Morelos',
#  '8 Yoga Retreats in Egypt',
#  '3 Yoga Retreats in Alachua',
#  '3 Yoga Retreats in Eastbourne',
#  '7 Yoga Retreats in North Yorkshire',
#  '3 Yoga Retreats in Puerto Princesa',
#  '5 Yoga Retreats in Bohol',
#  '4 Yoga Retreats in Alessandria',
#  '3 Yoga Retreats in Wexford',
#  '7 Yoga Retreats in Dalyan',
#  '3 Yoga Retreats in Leicester',
#  '16 Yoga Retreats in Belgium',
#  '3 Yoga Retreats in Brindisi',
#  '3 Yoga Retreats in Argyll',
#  '16 Yoga Retreats in Oleiros',
#  '3 Yoga Retreats in Forlì-Cesena',
#  '3 Yoga Retreats in Livorno',
#  '5 Yoga Retreats in Messina',
#  '3 Yoga Retreats in Nuoro',
#  '10 Yoga Retreats in Olbia-Tempio',
#  '4 Yoga Retreats in Ogliastra',
#  '5 Yoga Retreats in Pisa',
#  '3 Yoga Retreats in San Domino',
#  "3 Yoga Retreats in Sant'Antioco",
#  '4 Yoga Retreats in Sassari',
#  '3 Yoga Retreats in Stromboli',
#  '3 Yoga Retreats in Tremiti Islands',
#  '4 Yoga Retreats in Pacific Coast',
#  '7 Yoga Retreats in Galle',
#  '4 Yoga Retreats in Agios Georgios',
#  '5 Yoga Retreats in Mueang Krabi',
#  '4 Yoga Retreats in Paro',
#  '10 Yoga Retreats in Casablanca',
#  '7 Yoga Retreats in Koh Yao Archipelago',
#  '15 Yoga Retreats in Malta',
#  '4 Yoga Retreats in Bocas del Toro',
#  '3 Yoga Retreats in Punakha',
#  '9 Yoga Retreats in Rivas',
#  '29 Yoga Retreats in Siem Reap',
#  '4 Yoga Retreats in Thimphu',
#  '28 Yoga Retreats in Pahang',
#  '11 Yoga Retreats in Sihanoukville',
#  '28 Yoga Retreats in Bukit Tinggi',
#  '9 Yoga Retreats in Zanzibar',
#  '28 Yoga Retreats in Berjaya Hills',
#  '9 Yoga Retreats in Ragusa',
#  '3 Yoga Retreats in Other',
#  '8 Yoga Retreats in Paphos',
#  '3 Yoga Retreats in Darjeeling',
#  '3 Yoga Retreats in Minorca',
#  '27 Yoga Retreats in Playa Hermosa',
#  '5 Yoga Retreats in New Hampshire',
#  '4 Yoga Retreats in Hanimaadhoo',
#  '13 Yoga Retreats in Playa Chiquita',
#  '5 Yoga Retreats in Brac',
#  '12 Yoga Retreats in Riviera Maya',
#  '3 Yoga Retreats in Mimizan-Plage',
#  '6 Yoga Retreats in Landes',
#  '3 Yoga Retreats in Lenox',
#  '3 Yoga Retreats in Catskills',
#  '3 Yoga Retreats in Mimizan',
#  '5 Yoga Retreats in Gran Canaria',
#  '5 Yoga Retreats in Polis',
#  '4 Yoga Retreats in Santa Barbara',
#  '10 Yoga Retreats in Lanzarote',
#  '5 Yoga Retreats in La Gomera',
#  '3 Yoga Retreats in Playa del Carmen',
#  '4 Yoga Retreats in Var',
#  '3 Yoga Retreats in Los Santos',
#  '4 Yoga Retreats in Latchi',
#  '3 Yoga Retreats in Loire Valley',
#  '4 Yoga Retreats in Poitou-Charentes',
#  '5 Yoga Retreats in Palm Beach',
#  '4 Yoga Retreats in Boca Raton',
#  '22 Yoga Retreats in Sicily',
#  '60 Yoga Retreats in Canggu',
#  '9 Yoga Retreats in Maui',
#  '3 Yoga Retreats in Cambutal',
#  '3 Yoga Retreats in Bavaria',
#  '3 Yoga Retreats in Dorset',
#  '8 Yoga Retreats in San Pablo',
#  '6 Yoga Retreats in Kep',
#  '3 Yoga Retreats in Berkshire',
#  '4 Yoga Retreats in Sant Joan de Labritja',
#  '10 Yoga Retreats in Fiji',
#  '4 Yoga Retreats in Western Australia',
#  '17 Yoga Retreats in McLeod Ganj',
#  '11 Yoga Retreats in Devon',
#  '3 Yoga Retreats in Palmdale',
#  '4 Yoga Retreats in Uki',
#  '3 Yoga Retreats in Cortijo',
#  '3 Yoga Retreats in Essert-Romand',
#  '7 Yoga Retreats in Lajares',
#  '3 Yoga Retreats in Tel Aviv',
#  '3 Yoga Retreats in Euboea',
#  '3 Yoga Retreats in Roatan',
#  '13 Yoga Retreats in Ionian Islands',
#  '4 Yoga Retreats in West Greece',
#  '6 Yoga Retreats in Attica',
#  '10 Yoga Retreats in San Carlos',
#  '4 Yoga Retreats in Nobbys Creek',
#  '4 Yoga Retreats in Madhya Pradesh',
#  '10 Yoga Retreats in Spanish Pyrenees',
#  '6 Yoga Retreats in Peloponnese',
#  '3 Yoga Retreats in Kissamos',
#  '8 Yoga Retreats in Pengosekan',
#  '14 Yoga Retreats in Kuta',
#  '4 Yoga Retreats in Lanjarón',
#  '4 Yoga Retreats in Caceres',
#  '9 Yoga Retreats in South Aegean',
#  '3 Yoga Retreats in Emilia-Romagna',
#  '11 Yoga Retreats in Central Coast California',
#  '4 Yoga Retreats in Pererenan',
#  '6 Yoga Retreats in Gili Air',
#  '12 Yoga Retreats in Marbella',
#  '14 Yoga Retreats in Valencia',
#  '4 Yoga Retreats in Monda',
#  '5 Yoga Retreats in Styria',
#  '3 Yoga Retreats in Liscannor',
#  '3 Yoga Retreats in Central Macedonia',
#  '8 Yoga Retreats in Nusa Lembongan',
#  '4 Yoga Retreats in South Island',
#  '4 Yoga Retreats in Mambal',
#  '3 Yoga Retreats in North Holland',
#  '8 Yoga Retreats in Phato',
#  '15 Yoga Retreats in Big Island',
#  '50 Yoga Retreats in Koh Phangan',
#  '8 Yoga Retreats in Pak Song',
#  '5 Yoga Retreats in Savinja',
#  '4 Yoga Retreats in Lefkada',
#  '7 Yoga Retreats in Corfu',
#  '3 Yoga Retreats in Zakynthos',
#  '17 Yoga Retreats in Kata Beach',
#  '8 Yoga Retreats in Chumphon',
#  '4 Yoga Retreats in Amsterdam',
#  '5 Yoga Retreats in Kapaau',
#  '8 Yoga Retreats in Zeeland',
#  '6 Yoga Retreats in Gelderland',
#  '27 Yoga Retreats in Santa Teresa',
#  '3 Yoga Retreats in Cliffs of Moher',
#  '20 Yoga Retreats in Na Muang',
#  '11 Yoga Retreats in Sussex',
#  '5 Yoga Retreats in Lasko',
#  '5 Yoga Retreats in Hum',
#  '11 Yoga Retreats in Atlas Mountains',
#  '3 Yoga Retreats in Doi Saket',
#  '21 Yoga Retreats in Sintra',
#  '11 Yoga Retreats in Haute-Savoie',
#  '8 Yoga Retreats in Reykjavik',
#  '5 Yoga Retreats in Amazon',
#  '5 Yoga Retreats in Ao Nang',
#  '3 Yoga Retreats in Chengdu',
#  '24 Yoga Retreats in Karon',
#  '3 Yoga Retreats in Taling Ngam',
#  '7 Yoga Retreats in KwaZulu-Natal',
#  '8 Yoga Retreats in Silver Coast',
#  '3 Yoga Retreats in Paw Paw',
#  '3 Yoga Retreats in Korcula',
#  '3 Yoga Retreats in Mljet',
#  '5 Yoga Retreats in Martina Franca',
#  '22 Yoga Retreats in Seminyak',
#  '5 Yoga Retreats in Cakaudrove',
#  '3 Yoga Retreats in South Sinai Governorate',
#  '5 Yoga Retreats in Cavriglia',
#  '20 Yoga Retreats in Cadiz',
#  '6 Yoga Retreats in West Nusa Tenggara',
#  '4 Yoga Retreats in Garners Beach',
#  '5 Yoga Retreats in Mission Beach',
#  '6 Yoga Retreats in Seraya',
#  '4 Yoga Retreats in Sinai Peninsula',
#  '22 Yoga Retreats in Chiang Mai',
#  '9 Yoga Retreats in Dalmatia',
#  '5 Yoga Retreats in Mae Rim',
#  '10 Yoga Retreats in Victoria',
#  '4 Yoga Retreats in Aragon',
#  '9 Yoga Retreats in Corralejo',
#  '22 Yoga Retreats in Sri Thanu',
#  '19 Yoga Retreats in Nicoya',
#  '4 Yoga Retreats in Wisconsin',
#  '3 Yoga Retreats in Cannes',
#  '3 Yoga Retreats in Flemish Region',
#  '28 Yoga Retreats in Aljezur',
#  '4 Yoga Retreats in Coimbatore',
#  '11 Yoga Retreats in Florence',
#  '8 Yoga Retreats in Istria',
#  '7 Yoga Retreats in Buckingham',
#  '3 Yoga Retreats in Snowdonia',
#  '13 Yoga Retreats in Pahoa',
#  '3 Yoga Retreats in North Island',
#  '37 Yoga Retreats in Fuerteventura',
#  '8 Yoga Retreats in Heredia',
#  '6 Yoga Retreats in Kauai',
#  '3 Yoga Retreats in Vis, Split-Dalmatia',
#  '4 Yoga Retreats in Petra',
#  '4 Yoga Retreats in Nungwi',
#  '4 Yoga Retreats in La Libertad',
#  '4 Yoga Retreats in La Oliva',
#  '19 Yoga Retreats in Santorini',
#  '3 Yoga Retreats in Laganas',
#  '3 Yoga Retreats in North Western',
#  '7 Yoga Retreats in Wallonia',
#  '18 Yoga Retreats in Las Palmas',
#  '9 Yoga Retreats in Axarquía',
#  '14 Yoga Retreats in Talamanca',
#  '86 Yoga Retreats in Ubud',
#  '5 Yoga Retreats in Unguja',
#  "4 Yoga Retreats in French Riviera-Cote d'Azur",
#  '9 Yoga Retreats in Krabi',
#  '4 Yoga Retreats in Kaskazini A',
#  '4 Yoga Retreats in North Zanzibar',
#  '3 Yoga Retreats in Georgia',
#  '21 Yoga Retreats in Rawai',
#  '4 Yoga Retreats in Bophut',
#  '3 Yoga Retreats in Pai',
#  '10 Yoga Retreats in East Sussex',
#  '4 Yoga Retreats in Mambajao',
#  '3 Yoga Retreats in Nai Muang',
#  '22 Yoga Retreats in Palma',
#  '5 Yoga Retreats in Agoho',
#  '10 Yoga Retreats in Northern California',
#  '3 Yoga Retreats in Margaret River',
#  '11 Yoga Retreats in Tegalalang',
#  '4 Yoga Retreats in Surrey',
#  '7 Yoga Retreats in Rio de Janeiro',
#  '5 Yoga Retreats in Totana',
#  '3 Yoga Retreats in Puerto Jiménez',
#  '16 Yoga Retreats in Singaraja',
#  '3 Yoga Retreats in London',
#  '4 Yoga Retreats in Bhutan',
#  '11 Yoga Retreats in Tanzania',
#  '4 Yoga Retreats in Japan',
#  '10 Yoga Retreats in Pinhal Interior Sul',
#  '6 Yoga Retreats in Massachusetts',
#  '7 Yoga Retreats in Phang Nga Bay',
#  '11 Yoga Retreats in Sweden',
#  '10 Yoga Retreats in Abruzzo',
#  '3 Yoga Retreats in San Gimignano',
#  '12 Yoga Retreats in Sagres',
#  '10 Yoga Retreats in Sierra Espuna Mountains',
#  '5 Yoga Retreats in Odiaxere',
#  '18 Yoga Retreats in North Bali',
#  '4 Yoga Retreats in El Salvador',
#  '4 Yoga Retreats in Barbados',
#  '3 Yoga Retreats in Argentina',
#  '4 Yoga Retreats in Cereceda',
#  '4 Yoga Retreats in San Juanillo',
#  '4 Yoga Retreats in Suffolk Park',
#  '4 Yoga Retreats in Byron Shire',
#  '7 Yoga Retreats in Sonoma',
#  '5 Yoga Retreats in Pisac',
#  '3 Yoga Retreats in Amantani',
#  '10 Yoga Retreats in Uttar Pradesh',
#  '5 Yoga Retreats in Lake Titicaca',
#  '9 Yoga Retreats in Maine',
#  '5 Yoga Retreats in Burma',
#  '9 Yoga Retreats in Solola',
#  '6 Yoga Retreats in Jordan',
#  '4 Yoga Retreats in Leh',
#  '3 Yoga Retreats in Pucon',
#  '17 Yoga Retreats in Nicaragua',
#  '5 Yoga Retreats in Scotland',
#  '9 Yoga Retreats in Central Bali',
#  '5 Yoga Retreats in Sunshine Coast',
#  '4 Yoga Retreats in Colombia',
#  '4 Yoga Retreats in Ranong',
#  '8 Yoga Retreats in Tejakula',
#  '9 Yoga Retreats in Sierra Nevada',
#  '10 Yoga Retreats in Ontario',
#  '4 Yoga Retreats in Ischia',
#  '3 Yoga Retreats in Araucanía',
#  '4 Yoga Retreats in La Magdalena',
#  '16 Yoga Retreats in Alpujarras',
#  '4 Yoga Retreats in Washington',
#  '7 Yoga Retreats in Split-Dalmatia',
#  '6 Yoga Retreats in Slovenia',
#  '4 Yoga Retreats in Kandy',
#  '5 Yoga Retreats in Taranto',
#  '10 Yoga Retreats in Illinois',
#  '12 Yoga Retreats in Central Province',
#  '3 Yoga Retreats in Domburg',
#  '8 Yoga Retreats in Oxfordshire',
#  '3 Yoga Retreats in San Juan de la Rambla',
#  '9 Yoga Retreats in  Matale District',
#  '3 Yoga Retreats in Kandy District',
#  '13 Yoga Retreats in Varkala',
#  '8 Yoga Retreats in Israel',
#  '16 Yoga Retreats in Marrakesh-Tensift-El Haouz',
#  '3 Yoga Retreats in Dahab',
#  '12 Yoga Retreats in Guatemala',
#  '9 Yoga Retreats in Sahara',
#  '3 Yoga Retreats in Negev',
#  '5 Yoga Retreats in Hoi An',
#  '7 Yoga Retreats in Villamartin, Cadiz',
#  '4 Yoga Retreats in Ojai',
#  '8 Yoga Retreats in Vermont',
#  '12 Yoga Retreats in Castelo Branco',
#  '3 Yoga Retreats in Panama City',
#  '32 Yoga Retreats in Ram Jhula',
#  '27 Yoga Retreats in Kovalam',
#  '16 Yoga Retreats in Paros',
#  '8 Yoga Retreats in Tarapoto',
#  '4 Yoga Retreats in Pinhal Litoral',
#  '26 Yoga Retreats in Sardinia',
#  '7 Yoga Retreats in Chiang Rai',
#  '3 Yoga Retreats in Cook Islands',
#  '12 Yoga Retreats in Phang Nga',
#  '3 Yoga Retreats in Vanua Levu',
#  '7 Yoga Retreats in Oia',
#  '11 Yoga Retreats in Portland',
#  '7 Yoga Retreats in Alpujarra Mountains',
#  '13 Yoga Retreats in Ireland',
#  '7 Yoga Retreats in San Marcos La Laguna',
#  '50 Yoga Retreats in Lakshman Jhula',
#  '7 Yoga Retreats in Teulada',
#  '10 Yoga Retreats in Moraira',
#  '6 Yoga Retreats in Auroville',
#  '6 Yoga Retreats in Cabo San Lucas',
#  '3 Yoga Retreats in Nassau',
#  '3 Yoga Retreats in New Providence',
#  '8 Yoga Retreats in Tambon Maret',
#  '84 Yoga Retreats in Koh Samui',
#  '5 Yoga Retreats in Huerta de Murcia',
#  '3 Yoga Retreats in Westmoreland',
#  '6 Yoga Retreats in Peniche',
#  '4 Yoga Retreats in Baleal',
#  '8 Yoga Retreats in Oeste',
#  '10 Yoga Retreats in Essaouira',
#  '10 Yoga Retreats in Asturias',
#  '8 Yoga Retreats in Ispica',
#  '5 Yoga Retreats in Kathmandu Valley',
#  '7 Yoga Retreats in Catalonia',
#  '3 Yoga Retreats in Imi Ouaddar',
#  '12 Yoga Retreats in Kathmandu',
#  '12 Yoga Retreats in Thiruvananthapuram',
#  '9 Yoga Retreats in Gozo',
#  '3 Yoga Retreats in Montego Bay',
#  '4 Yoga Retreats in Cancun',
#  '3 Yoga Retreats in Graubunden',
#  '9 Yoga Retreats in New Mexico',
#  '5 Yoga Retreats in Cuba',
#  '21 Yoga Retreats in New York',
#  '19 Yoga Retreats in Murcia',
#  '7 Yoga Retreats in Poland',
#  '15 Yoga Retreats in Puerto Rico',
#  '5 Yoga Retreats in Phokara',
#  '4 Yoga Retreats in Kenya',
#  '6 Yoga Retreats in Columbeira',
#  '8 Yoga Retreats in Leiria',
#  '3 Yoga Retreats in Honduras',
#  '6 Yoga Retreats in Vio',
#  '7 Yoga Retreats in Terni',
#  '20 Yoga Retreats in Barcelona',
#  '14 Yoga Retreats in Patnem',
#  '3 Yoga Retreats in Hungary',
#  '3 Yoga Retreats in Orvieto',
#  '15 Yoga Retreats in Lovina',
#  '142 Yoga Retreats in Rishikesh',
#  '118 Yoga Retreats in Himalaya',
#  '4 Yoga Retreats in Chile',
#  '3 Yoga Retreats in Lentas',
#  '4 Yoga Retreats in Santa Ysabel',
#  '8 Yoga Retreats in Wales',
#  '3 Yoga Retreats in Venice',
#  '24 Yoga Retreats in Ecuador',
#  '57 Yoga Retreats in Phuket',
#  '15 Yoga Retreats in Karnataka',
#  '4 Yoga Retreats in Kerobokan',
#  '7 Yoga Retreats in Candidasa',
#  '11 Yoga Retreats in Sanur',
#  '17 Yoga Retreats in Tamil Nadu',
#  '22 Yoga Retreats in Cyclades',
#  '6 Yoga Retreats in Naousa',
#  '26 Yoga Retreats in Buleleng',
#  '3 Yoga Retreats in Santa Maria',
#  '18 Yoga Retreats in Switzerland',
#  '16 Yoga Retreats in Austria',
#  '35 Yoga Retreats in Trivandrum',
#  '8 Yoga Retreats in Tyrol',
#  '96 Yoga Retreats in Andalusia',
#  '30 Yoga Retreats in Germany',
#  '30 Yoga Retreats in Netherlands',
#  '13 Yoga Retreats in Estellencs',
#  '25 Yoga Retreats in Puerto Viejo',
#  '4 Yoga Retreats in Playa Guiones',
#  '5 Yoga Retreats in Oregon',
#  '14 Yoga Retreats in Brazil',
#  '43 Yoga Retreats in Marrakech',
#  '25 Yoga Retreats in Canacona',
#  '3 Yoga Retreats in Marche',
#  '4 Yoga Retreats in Malpais',
#  '47 Yoga Retreats in Tamraght',
#  '5 Yoga Retreats in Agadir Idawtanan',
#  '6 Yoga Retreats in Bowen Island',
#  '3 Yoga Retreats in Glastonbury',
#  '4 Yoga Retreats in Alajuela',
#  '13 Yoga Retreats in Vrindavan',
#  '11 Yoga Retreats in West Sussex',
#  '7 Yoga Retreats in East Midlands',
#  '19 Yoga Retreats in Delhi',
#  '14 Yoga Retreats in Agra',
#  '3 Yoga Retreats in Alpes-de-Haute-Provence',
#  '9 Yoga Retreats in Hvar',
#  '11 Yoga Retreats in San José',
#  '4 Yoga Retreats in Almeria',
#  '3 Yoga Retreats in Costa de la Luz',
#  '4 Yoga Retreats in Santa Catalina',
#  '21 Yoga Retreats in Souss-Massa-Draa',
#  '6 Yoga Retreats in Negril',
#  '12 Yoga Retreats in Jaco',
#  '3 Yoga Retreats in Regiao de Leiria',
#  '8 Yoga Retreats in Cornwall',
#  '10 Yoga Retreats in Tumbaco',
#  '6 Yoga Retreats in Sfakia',
#  '8 Yoga Retreats in Apulia',
#  '4 Yoga Retreats in Tauranga',
#  '3 Yoga Retreats in Hambantota District',
#  '3 Yoga Retreats in Munnar',
#  '6 Yoga Retreats in Lima',
#  '4 Yoga Retreats in Wallingford',
#  '32 Yoga Retreats in Tapovan',
#  '5 Yoga Retreats in Campania',
#  '4 Yoga Retreats in Amalfi Coast',
#  '23 Yoga Retreats in Cusco',
#  '12 Yoga Retreats in Bahamas',
#  '34 Yoga Retreats in Turkey',
#  '23 Yoga Retreats in Umbria',
#  '16 Yoga Retreats in Dehradun',
#  '5 Yoga Retreats in Odemira',
#  '58 Yoga Retreats in Agadir',
#  '3 Yoga Retreats in Krakow',
#  '29 Yoga Retreats in Quintana Roo',
#  '4 Yoga Retreats in Puno',
#  '10 Yoga Retreats in New England',
#  '6 Yoga Retreats in Alentejo',
#  '10 Yoga Retreats in Sedona',
#  '16 Yoga Retreats in Midi-Pyrenees',
#  '18 Yoga Retreats in Mugla',
#  '3 Yoga Retreats in Calistoga',
#  '27 Yoga Retreats in Queensland',
#  '33 Yoga Retreats in Costa Blanca',
#  '54 Yoga Retreats in Tuscany',
#  '5 Yoga Retreats in Sidemen',
#  '4 Yoga Retreats in Vancouver',
#  '18 Yoga Retreats in Costa del Sol',
#  '4 Yoga Retreats in Piedmont',
#  '28 Yoga Retreats in British Columbia',
#  '5 Yoga Retreats in Hua Hin',
#  '3 Yoga Retreats in Aegiali',
#  '29 Yoga Retreats in Aegean Islands',
#  '34 Yoga Retreats in Taghazout',
#  '52 Yoga Retreats in Alicante',
#  '3 Yoga Retreats in Other',
#  '24 Yoga Retreats in Centro',
#  '9 Yoga Retreats in Tamarindo',
#  '52 Yoga Retreats in New South Wales',
#  '29 Yoga Retreats in Lisbon',
#  '4 Yoga Retreats in Altea',
#  '3 Yoga Retreats in Manila',
#  '8 Yoga Retreats in Nayarit',
#  '8 Yoga Retreats in San Juan del Sur',
#  '6 Yoga Retreats in Long Bay',
#  '30 Yoga Retreats in Malaysia',
#  '14 Yoga Retreats in Seririt',
#  '5 Yoga Retreats in Rome',
#  '26 Yoga Retreats in Mandrem',
#  '30 Yoga Retreats in Limón',
#  '3 Yoga Retreats in South Australia',
#  '51 Yoga Retreats in Chumphon Archipelago',
#  '12 Yoga Retreats in Arizona',
#  '21 Yoga Retreats in Nevada, California',
#  '3 Yoga Retreats in Capri',
#  '3 Yoga Retreats in Hoya de Huesca',
#  '6 Yoga Retreats in Nevada',
#  '5 Yoga Retreats in Mykonos',
#  '4 Yoga Retreats in Kona',
#  '15 Yoga Retreats in Fethiye',
#  '3 Yoga Retreats in Santa Cruz',
#  '62 Yoga Retreats in Malaga',
#  '20 Yoga Retreats in Florida',
#  '3 Yoga Retreats in Seaford',
#  '117 Yoga Retreats in Balearic Islands',
#  '40 Yoga Retreats in Guanacaste',
#  '9 Yoga Retreats in Marina Alta',
#  '6 Yoga Retreats in Lucca',
#  '7 Yoga Retreats in Santa Margarita',
#  '18 Yoga Retreats in Panama',
#  '17 Yoga Retreats in South East England',
#  '20 Yoga Retreats in South Africa',
#  '3 Yoga Retreats in Hrvatska',
#  '4 Yoga Retreats in Soller',
#  '13 Yoga Retreats in Orgiva',
#  '5 Yoga Retreats in Heraklion',
#  '10 Yoga Retreats in Urubamba',
#  '7 Yoga Retreats in Tavira',
#  '18 Yoga Retreats in Karangasem',
#  '16 Yoga Retreats in Sacred Valley',
#  '10 Yoga Retreats in Southern California',
#  '5 Yoga Retreats in Denia',
#  "4 Yoga Retreats in Val d'Orcia",
#  '4 Yoga Retreats in Dubrovnik-Neretva County',
#  '3 Yoga Retreats in Santa Fe',
#  '4 Yoga Retreats in Ladakh',
#  '4 Yoga Retreats in Grosseto',
#  '6 Yoga Retreats in Sukawati',
#  '10 Yoga Retreats in West Bali',
#  '18 Yoga Retreats in San Lorenzo',
#  '5 Yoga Retreats in Amorgos',
#  '3 Yoga Retreats in Gili Trawangan',
#  '8 Yoga Retreats in Perugia',
#  '3 Yoga Retreats in Gubbio',
#  '7 Yoga Retreats in Lombok',
#  '19 Yoga Retreats in Faro',
#  '5 Yoga Retreats in Island Falls',
#  '4 Yoga Retreats in Assisi',
#  '7 Yoga Retreats in Virginia',
#  '12 Yoga Retreats in Adriatic Sea',
#  '21 Yoga Retreats in Jamaica',
#  '14 Yoga Retreats in Quebec',
#  '6 Yoga Retreats in Cahuita',
#  '3 Yoga Retreats in Tennessee',
#  '9 Yoga Retreats in Playa Negra',
#  '6 Yoga Retreats in Savusavu',
#  '97 Yoga Retreats in Algarve',
#  '3 Yoga Retreats in Bilbao',
#  '6 Yoga Retreats in Conil de la Frontera',
#  '13 Yoga Retreats in Jaipur',
#  '7 Yoga Retreats in Varanasi',
#  '9 Yoga Retreats in Tenerife',
#  '27 Yoga Retreats in Santa Eulalia del Rio',
#  '3 Yoga Retreats in Mindo',
#  '33 Yoga Retreats in Himachal Pradesh',
#  '6 Yoga Retreats in Languedoc-Roussillon',
#  '19 Yoga Retreats in Puglia',
#  '3 Yoga Retreats in Kachemak Bay',
#  '10 Yoga Retreats in Kochi',
#  '6 Yoga Retreats in Provence',
#  '9 Yoga Retreats in Atsitsa Bay',
#  '9 Yoga Retreats in Skyros',
#  '21 Yoga Retreats in Granada',
#  '6 Yoga Retreats in Seville',
#  '7 Yoga Retreats in Koh Yao Noi',
#  '14 Yoga Retreats in Cyprus',
#  '3 Yoga Retreats in Los Angeles',
#  '121 Yoga Retreats in Uttarakhand',
#  '3 Yoga Retreats in Jerez de la Frontera',
#  '10 Yoga Retreats in Baja California Sur',
#  '7 Yoga Retreats in Arezzo',
#  '24 Yoga Retreats in South Bali',
#  '4 Yoga Retreats in Gocek',
#  '3 Yoga Retreats in Laguna de Apoyo',
#  '5 Yoga Retreats in Cumbria',
#  '40 Yoga Retreats in Peru',
#  '14 Yoga Retreats in East Bali',
#  '7 Yoga Retreats in Playa del Albir',
#  '277 Yoga Retreats in USA',
#  '24 Yoga Retreats in Pernem',
#  '16 Yoga Retreats in Yucatan Peninsula',
#  '7 Yoga Retreats in Chianti',
#  '5 Yoga Retreats in Prachuap Khiri Khan',
#  '12 Yoga Retreats in Beira Baixa',
#  '15 Yoga Retreats in Kuta North',
#  '57 Yoga Retreats in Canada',
#  '21 Yoga Retreats in Mandrem Beach',
#  '15 Yoga Retreats in Quito',
#  '4 Yoga Retreats in Rhône-Alpes',
#  '3 Yoga Retreats in Ronda',
#  '3 Yoga Retreats in Lake District',
#  '9 Yoga Retreats in Dominican Republic',
#  '31 Yoga Retreats in Mueang Phuket',
#  '9 Yoga Retreats in Sayulita',
#  '22 Yoga Retreats in Tulum',
#  '42 Yoga Retreats in Gianyar',
#  '7 Yoga Retreats in Amieira',
#  '10 Yoga Retreats in Iceland',
#  '31 Yoga Retreats in Lagos',
#  '4 Yoga Retreats in Positano',
#  '9 Yoga Retreats in Jalisco',
#  '9 Yoga Retreats in Tabanan',
#  '5 Yoga Retreats in Texas',
#  '3 Yoga Retreats in Killington',
#  '120 Yoga Retreats in Surat Thani',
#  '10 Yoga Retreats in Mafra',
#  '5 Yoga Retreats in Sabina',
#  '5 Yoga Retreats in Greater Lisbon',
#  '33 Yoga Retreats in Badung',
#  "6 Yoga Retreats in Provence-Alpes-Cote d'Azur",
#  '3 Yoga Retreats in Rutland',
#  '8 Yoga Retreats in Manuel Antonio',
#  '11 Yoga Retreats in Maldives',
#  '12 Yoga Retreats in Machu Picchu',
#  '5 Yoga Retreats in Puerto Escondido',
#  '7 Yoga Retreats in Bulgaria',
#  '14 Yoga Retreats in Haridwar',
#  '10 Yoga Retreats in Aquitaine',
#  '10 Yoga Retreats in Lake Atitlan',
#  '6 Yoga Retreats in Dordogne',
#  '8 Yoga Retreats in Somerset',
#  '7 Yoga Retreats in Chania',
#  '27 Yoga Retreats in Crete',
#  '4 Yoga Retreats in Chiang Rai Province',
#  '5 Yoga Retreats in Amphoe Mueang Chiang Rai',
#  '3 Yoga Retreats in Sitges',
#  '5 Yoga Retreats in Eleuthera',
#  '7 Yoga Retreats in Dominical',
#  '33 Yoga Retreats in South Goa',
#  '6 Yoga Retreats in Aguas Calientes',
#  '3 Yoga Retreats in Taroudant',
#  '8 Yoga Retreats in Florida Keys',
#  '5 Yoga Retreats in Austrian Alps',
#  '4 Yoga Retreats in Veraguas',
#  '4 Yoga Retreats in Mae Nam',
#  '5 Yoga Retreats in Ollantaytambo',
#  '3 Yoga Retreats in Alozaina',
#  '4 Yoga Retreats in Big Pine Key',
#  '3 Yoga Retreats in Long Island',
#  '13 Yoga Retreats in Angkor Wat',
#  '3 Yoga Retreats in Psa Ney',
#  '3 Yoga Retreats in Kannur',
#  '4 Yoga Retreats in Lourinha',
#  '3 Yoga Retreats in Bagmati',
#  '9 Yoga Retreats in Kollam',
#  '4 Yoga Retreats in Gulf of Thailand',
#  '4 Yoga Retreats in Ipsden',
#  '3 Yoga Retreats in Western Ghats',
#  '25 Yoga Retreats in Ganges',
#  '6 Yoga Retreats in Berawa Beach',
#  '3 Yoga Retreats in Luzianes-Gare',
#  '6 Yoga Retreats in Batu Bolong Beach',
#  '3 Yoga Retreats in Nelayan Beach',
#  '4 Yoga Retreats in Dartmoor',
#  '4 Yoga Retreats in Jorox',
#  '9 Yoga Retreats in Villaverde',
#  '4 Yoga Retreats in Abel Tasman National Park',
#  '4 Yoga Retreats in Inle Lake',
#  '7 Yoga Retreats in Phnom Penh',
#  '3 Yoga Retreats in Phnom Kulen',
#  '10 Yoga Retreats in Ban Phang Ka',
#  '6 Yoga Retreats in Mulanthuruthy',
#  '4 Yoga Retreats in Karikode',
#  '4 Yoga Retreats in Bergerac',
#  '3 Yoga Retreats in La Punta',
#  '4 Yoga Retreats in Brisas de Zicatela',
#  '5 Yoga Retreats in Bagby',
#  '4 Yoga Retreats in Hambleton',
#  '4 Yoga Retreats in Thirsk',
#  '3 Yoga Retreats in Viluppuram district',
#  '4 Yoga Retreats in Echo Beach',
#  '3 Yoga Retreats in Cadzand',
#  '3 Yoga Retreats in Sluis',
#  '4 Yoga Retreats in Cobano',
#  '4 Yoga Retreats in Mala Lake',
#  '6 Yoga Retreats in Paravur',
#  '5 Yoga Retreats in Haad Chao Phao ',
#  '4 Yoga Retreats in Aude',
#  '3 Yoga Retreats in Nai Harn Beach',
#  '4 Yoga Retreats in Andes',
#  '5 Yoga Retreats in Lycian Coast',
#  '4 Yoga Retreats in Pilai Beach',
#  '4 Yoga Retreats in Khok Kloi',
#  '4 Yoga Retreats in Takua Thung',
#  '3 Yoga Retreats in Banjar Baturning',
#  '6 Yoga Retreats in Srithanu',
#  '3 Yoga Retreats in Baxedes Beach',
#  '7 Yoga Retreats in Goldhunga',
#  '8 Yoga Retreats in Shivapuri Nagarjun National Park',
#  '7 Yoga Retreats in Ashvem Beach',
#  '3 Yoga Retreats in Dhulikhel',
#  '3 Yoga Retreats in Frome',
#  "5 Yoga Retreats in Governor's Harbour",
#  '3 Yoga Retreats in Elafiti Islands',
#  '4 Yoga Retreats in Dubrovnik',
#  '8 Yoga Retreats in Patnem Beach',
#  '11 Yoga Retreats in Estoril',
#  '3 Yoga Retreats in Lang Co',
#  '5 Yoga Retreats in Palolem Beach',
#  '4 Yoga Retreats in Arambol Beach',
#  '5 Yoga Retreats in Madeira',
#  '13 Yoga Retreats in Vichit',
#  '4 Yoga Retreats in Durham',
#  '4 Yoga Retreats in Stafford County',
#  '3 Yoga Retreats in Bay of Fethiye',
#  '3 Yoga Retreats in Agios Pavlos',
#  '3 Yoga Retreats in Varca',
#  '12 Yoga Retreats in North Goa',
#  '3 Yoga Retreats in Coudures',
#  '3 Yoga Retreats in Cesenatico',
#  '3 Yoga Retreats in Morjim',
#  "3 Yoga Retreats in Sainte-Colombe-sur-l'Hers",
#  '3 Yoga Retreats in La Vegueta',
#  '6 Yoga Retreats in Wiang Chai',
#  '6 Yoga Retreats in Don Sila',
#  '6 Yoga Retreats in Ban Samanmit',
#  '6 Yoga Retreats in Costa Vicentina National Park',
#  '4 Yoga Retreats in Gwynedd',
#  '12 Yoga Retreats in Adriatic Sea',
#  '4 Yoga Retreats in Kvarner',
#  '9 Yoga Retreats in Paradise Valley',
#  '3 Yoga Retreats in Vélez-Málaga',
#  '6 Yoga Retreats in New Delhi',
#  '3 Yoga Retreats in Kabak',
#  '9 Yoga Retreats in Canggu Beach',
#  '5 Yoga Retreats in Maras',
#  '4 Yoga Retreats in Moray',
#  '3 Yoga Retreats in Cala San Vincente',
#  '4 Yoga Retreats in Uttarkashi',
#  '4 Yoga Retreats in Grass Valley',
#  '4 Yoga Retreats in Kangra',
#  '4 Yoga Retreats in La Paz',
#  '3 Yoga Retreats in Dalmatian Coast',
#  '3 Yoga Retreats in Sant Carles de Peralta',
#  '6 Yoga Retreats in Bhagsu Nag',
#  '3 Yoga Retreats in Sivota',
#  '3 Yoga Retreats in Thesprotia',
#  '3 Yoga Retreats in Pescosolido',
#  '3 Yoga Retreats in Cartagena',
#  '4 Yoga Retreats in Phnom Voar',
#  '3 Yoga Retreats in Tambor',
#  '15 Yoga Retreats in Aegean Sea area',
#  '4 Yoga Retreats in County Clare',
#  '3 Yoga Retreats in Huacas',
#  '5 Yoga Retreats in Avin',
#  '3 Yoga Retreats in Canning',
#  '3 Yoga Retreats in Sangre de Cristo Mountains area',
#  '3 Yoga Retreats in Central Coast',
#  '3 Yoga Retreats in Swellendam',
#  '3 Yoga Retreats in Tinajo',
#  '5 Yoga Retreats in Antiparos',
#  '4 Yoga Retreats in Independence Beach',
#  '3 Yoga Retreats in Cebu',
#  '3 Yoga Retreats in Picos de Europa area',
#  '4 Yoga Retreats in Tapoul Village',
#  '7 Yoga Retreats in Lempaut',
#  '3 Yoga Retreats in Limoges',
#  '5 Yoga Retreats in Port de Sóller',
#  '4 Yoga Retreats in Quelfes',
#  '5 Yoga Retreats in Luxembourg',
#  '3 Yoga Retreats in Granges',
#  '6 Yoga Retreats in Pellenberg',
#  '6 Yoga Retreats in Leuven',
#  '3 Yoga Retreats in Kalamos',
#  '5 Yoga Retreats in Sankt Peter-Ording',
#  '6 Yoga Retreats in Nordfriesland',
#  '6 Yoga Retreats in Schleswig-Holstein',
#  '4 Yoga Retreats in Saxony',
#  '3 Yoga Retreats in Flanders',
#  '4 Yoga Retreats in Hepburn Springs',
#  '4 Yoga Retreats in Morjim Beach',
#  '3 Yoga Retreats in Tarn',
#  '4 Yoga Retreats in Gili Islands',
#  '3 Yoga Retreats in Airlie Beach',
#  '4 Yoga Retreats in Millom',
#  '4 Yoga Retreats in Caledon',
#  '4 Yoga Retreats in Karteros Beach',
#  '8 Yoga Retreats in Dambulla',
#  '5 Yoga Retreats in Gatineau River area',
#  '5 Yoga Retreats in Ferme-Neuve',
#  '4 Yoga Retreats in Tibubeneng',
#  '3 Yoga Retreats in Mont-Laurier',
#  '4 Yoga Retreats in Andaman Sea area',
#  '8 Yoga Retreats in Galgiriyawa Mountains area',
#  '8 Yoga Retreats in Madawala Ulpotha',
#  '9 Yoga Retreats in Earlville',
#  '3 Yoga Retreats in Lovran',
#  '4 Yoga Retreats in San Teodoro',
#  '6 Yoga Retreats in Badualga',
#  '5 Yoga Retreats in Flemish Brabant',
#  '3 Yoga Retreats in Rügen',
#  '3 Yoga Retreats in List auf Sylt',
#  '3 Yoga Retreats in Upper Tapovan',
#  '3 Yoga Retreats in Mecklenburg-Vorpommern',
#  '7 Yoga Retreats in Laem Sor Beach']

# %%
for item in headlines1:
    if len(item) > 35:
        print(item, len(item))
# Out:
# 3 Yoga Retreats in Carbonia-Iglesias 36
# 3 Yoga Retreats in Mediterranean Sea 36
# 3 Yoga Retreats in Jammu and Kashmir 36
# 59 Yoga Retreats in Nicoya Peninsula 36
# 6 Yoga Retreats in South West England 37
# 5 Yoga Retreats in Santa Cruz de Tenerife 41
# 3 Yoga Retreats in Damnak Chang'aeur 36
# 4 Yoga Retreats in Yorkshire and the Humber 43
# 4 Yoga Retreats in South West France 36
# 7 Yoga Retreats in Santa Maria del Focallo 42
# 7 Yoga Retreats in Koh Yao Archipelago 38
# 4 Yoga Retreats in Sant Joan de Labritja 40
# 4 Yoga Retreats in Western Australia 36
# 10 Yoga Retreats in Spanish Pyrenees 36
# 11 Yoga Retreats in Central Coast California 44
# 3 Yoga Retreats in Central Macedonia 36
# 3 Yoga Retreats in South Sinai Governorate 42
# 6 Yoga Retreats in West Nusa Tenggara 37
# 3 Yoga Retreats in Vis, Split-Dalmatia 38
# 4 Yoga Retreats in French Riviera-Cote d'Azur 45
# 10 Yoga Retreats in Northern California 39
# 10 Yoga Retreats in Pinhal Interior Sul 39
# 10 Yoga Retreats in Sierra Espuna Mountains 43
# 12 Yoga Retreats in Central Province 36
# 3 Yoga Retreats in San Juan de la Rambla 40
# 16 Yoga Retreats in Marrakesh-Tensift-El Haouz 46
# 7 Yoga Retreats in Villamartin, Cadiz 37
# 7 Yoga Retreats in Alpujarra Mountains 38
# 7 Yoga Retreats in San Marcos La Laguna 39
# 12 Yoga Retreats in Thiruvananthapuram 38
# 3 Yoga Retreats in Alpes-de-Haute-Provence 42
# 21 Yoga Retreats in Souss-Massa-Draa 36
# 3 Yoga Retreats in Hambantota District 38
# 28 Yoga Retreats in British Columbia 36
# 51 Yoga Retreats in Chumphon Archipelago 40
# 21 Yoga Retreats in Nevada, California 38
# 117 Yoga Retreats in Balearic Islands 37
# 17 Yoga Retreats in South East England 38
# 10 Yoga Retreats in Southern California 39
# 4 Yoga Retreats in Dubrovnik-Neretva County 43
# 6 Yoga Retreats in Conil de la Frontera 39
# 27 Yoga Retreats in Santa Eulalia del Rio 41
# 33 Yoga Retreats in Himachal Pradesh 36
# 6 Yoga Retreats in Languedoc-Roussillon 39
# 3 Yoga Retreats in Jerez de la Frontera 39
# 10 Yoga Retreats in Baja California Sur 39
# 16 Yoga Retreats in Yucatan Peninsula 37
# 5 Yoga Retreats in Prachuap Khiri Khan 38
# 9 Yoga Retreats in Dominican Republic 37
# 6 Yoga Retreats in Provence-Alpes-Cote d'Azur 45
# 4 Yoga Retreats in Chiang Rai Province 38
# 5 Yoga Retreats in Amphoe Mueang Chiang Rai 43
# 6 Yoga Retreats in Batu Bolong Beach 36
# 4 Yoga Retreats in Abel Tasman National Park 44
# 4 Yoga Retreats in Brisas de Zicatela 37
# 3 Yoga Retreats in Viluppuram district 38
# 8 Yoga Retreats in Shivapuri Nagarjun National Park 51
# 5 Yoga Retreats in Governor's Harbour 37
# 3 Yoga Retreats in Sainte-Colombe-sur-l'Hers 44
# 6 Yoga Retreats in Costa Vicentina National Park 48
# 3 Yoga Retreats in Cala San Vincente 36
# 3 Yoga Retreats in Sant Carles de Peralta 41
# 3 Yoga Retreats in Sangre de Cristo Mountains area 50
# 4 Yoga Retreats in Independence Beach 37
# 3 Yoga Retreats in Picos de Europa area 39
# 5 Yoga Retreats in Sankt Peter-Ording 37
# 6 Yoga Retreats in Schleswig-Holstein 37
# 5 Yoga Retreats in Gatineau River area 38
# 8 Yoga Retreats in Galgiriyawa Mountains area 45
# 3 Yoga Retreats in Mecklenburg-Vorpommern 41
