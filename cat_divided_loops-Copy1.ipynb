# %%
#ask user to provide landing page url.
import urllib2
from BeautifulSoup import BeautifulSoup

print "Please type in the landing page url."
url = raw_input()

#extract the number of listings from landing page title
soup = BeautifulSoup(urllib2.urlopen(url))
page_title = str(soup.title.string)
count = page_title.split()[0]

import sys 

if count.isdigit() == False:
    print "[Alert] Cannot proceed further: the landing page has less than 3 listings. Please choose a different landing page with at least 3 listings."
    sys.exit()

#prepare keyword components
yoga = ['yoga']

holiday_word1 = [
'holiday',
'holidays', 
'retreat',  
'retreats', 
'vacation',
'vacations',
'resort',
'resorts',
'camp',
'camps',
'package',
'packages',
'center',
'centers',
'centre',
'centres',
'deal',
'deals']

holiday_word2 = [
'package',
'packages',
'resort',
'resorts',
'retreat',
'retreats',
'deal',
'deals',
'']

remove_list = [
'yoga',
'retreat',  
'retreats', 
'vacation',
'vacations',
'package',
'packages',
'resort',
'resorts',
'camp',
'camps',
'center',
'centers',
'centre',
'centres',
'and'
]

requires_and = [
'beach',
'horse riding',
'painting',
'cooking',
'cycling',
'dancing',
'detox',
'health',
'hiking',
'meditation',
'pilates',
'running',
'sailing',
'silent',
'ski',
'spa',
'spiritual',
'surf',
'surfing',
'walking',
'wellness',
'writing'
]

cat = ''
style = ''
destination = ''
destination1 = ''
destination2 = ''
destination_front = ''
destination_back = ''

cat_mrkr = '/c/'
style_mrkr = '/s/'
cont_mrkr = '/d/'
# Out:
# Please type in the landing page url.
# https://www.bookyogaretreats.com/all/c/short/s/vinyasa-yoga/d/the-americas-and-caribbean/usa

# %%
######################################################################################

#extract categories, styles and destination from the URL
#make combination lists
import itertools

cat_idx_front = url.find(cat_mrkr)+3

if (cont_mrkr not in url) and (style_mrkr not in url): #only categories
    
    cat_idx_back = len(url)
    
    #remove word(s) in category that is already mentioned in prep list
    #e.g. couples yoga retreat -> couples
    #e.g. budget retreats -> budget
    #except for 200/300/500 hour yoga teacher training
    cat = url[cat_idx_front:cat_idx_back].replace("-", " ")
    cat = ' '.join(i for i in cat.split() if i not in remove_list)
    cat = [cat] #listify

    destination_f = ''
    
######################################################################################

elif (cont_mrkr not in url) and (style_mrkr in url): #categories and style
    
    cat_idx_back = url.find(style_mrkr)

    style_idx_front = url.find(style_mrkr)+3
    style_idx_back = len(url)
    
    style = url[style_idx_front:style_idx_back].replace('-', " ")
    style = [style] #listify
    
    #remove word(s) in category that is already mentioned in prep list
    #e.g. yoga teacher training -> teacher training
    #e.g. budget retreats -> budget
    cat = url[cat_idx_front:cat_idx_back].replace("-", " ")
    cat = ' '.join(i for i in cat.split() if i not in remove_list)
    cat = [cat] #listify

    destination_f = ''

######################################################################################

elif (cont_mrkr in url) and (style_mrkr not in url): #categories and destination
    
    cat_idx_back = url.find(cont_mrkr)

    find = '/'
    cont_idx = max(pos for pos, char in enumerate(url) if char == find)+1 #index of the last slash. last slash is always followed by destination
    destination = url[cont_idx:].title().replace("-", " ").split() #destination has been listified

    #remove word(s) in category that is already mentioned in prep list
    #e.g. yoga teacher training -> teacher training
    #e.g. budget retreats -> budget
    cat = url[cat_idx_front:cat_idx_back].replace("-", " ")
    cat = ' '.join(i for i in cat.split() if i not in remove_list)
    cat = [cat] #listify
    
    
    #if there is more than one destination (e.g. Asia and Oceania)
    if 'And' in destination:
        cut = destination.index('And')
        destination1 = ' '.join(destination[:cut])
        destination2 = ' '.join(destination[cut+1:])
        destination_back = ['in '+destination1, destination1, 'in '+destination2, destination2]
        destination_front = [destination1, destination2]
            
        headline1 = count+' '+' '.join(page_title.split()[1:3] + destination_back[0].split())
        #headline2 = ' '.join(page_title.split()[1:3] + destination_back[1].split()) + ' 2016'
        #headline3 = count+' '+' '.join(page_title.split()[1:3] + destination_back[2].split())
        #headline4 = ' '.join(page_title.split()[1:3] + destination_back[3].split()) + ' 2016'

        #headlines = [headline1, headline2, headline3, headline4]
        destination_f = destination_front[:]
        
    #if there is only one destination (e.g. Germany)    
    else: 
        destination1 = ' '.join(destination)
        destination_back = ['in '+destination1, destination1]
        destination_front = [destination1]

        #headline1 = count+' '+ ' '.join(page_title.split()[1:3] + destination_back[0].split())
        #headline2 = ' '.join(page_title.split()[1:3] + destination_back[1].split()) + ' 2016'

        #headlines = [headline1, headline2]

        #print "[Checking] headlines:", headlines
        
        destination_f = destination_front[:]
        
        if destination_front[0] == 'United Arab Emirates':
            destination_front.append('UAE')
            destination_back.append('in UAE')
            destination_back.append('UAE')
        elif destination_front[0] == 'South Africa':
            destination_front.append('SA')
            destination_back.append('in SA')
            destination_back.append('SA')
        elif destination_front[0] == 'New Zealand':
            destination_front.append('NZ')
            destination_back.append('in NZ')
            destination_back.append('NZ')
        elif destination_front[0] == 'United Kingdom':
            destination_front.append('UK')
            destination_front.append('the UK')
            destination_back.append('in UK')
            destination_back.append('UK')
            destination_back.append('in the UK')
            destination_back.append('the UK')
        elif destination_front[0] == 'Massachusetts':
            destination_front.append('MA')
            destination_back.append('in MA')
            destination_back.append('MA')
        elif destination_front[0] == 'North Carolina':
            destination_front.append('NC')
            destination_back.append('in NC')
            destination_back.append('NC')
        elif destination_front[0] == 'South Carolina':
            destination_front.append('SC')
            destination_back.append('in SC')
            destination_back.append('SC')
        elif destination_front[0] == 'Western Australia':
            destination_front.append('WA')
            destination_back.append('in WA')
            destination_back.append('WA')
        elif destination_front[0] == 'Pennsylvania':
            destination_front.append('PA')
            destination_back.append('in PA')
            destination_back.append('PA')
        elif destination_front[0] == 'Usa':
            destination_front[0] = 'USA'
            destination_front.append('US')
            destination_front.append('the US')
            destination_front.append('United States')
            destination_back[0] = 'in USA'
            destination_back[1] = 'USA'
            destination_back.append('in US')
            destination_back.append('US')
            destination_back.append('in the US')
            destination_back.append('the US')
            destination_back.append('in United States')
            destination_back.append('United States')
        elif destination_front[0] == 'California':
            destination_front.append('CA')
            destination_back.append('in CA')
            destination_back.append('CA')
        elif destination_front[0] == 'Central Coast California':
            destination_front.append('Central Coast CA')
            destination_back.append('in Central Coast CA')
            destination_back.append('Central Coast CA')
        elif destination_front[0] == 'Nevada California':
            destination_front[0] = 'Nevada, California'
            destination_back[0] = 'in Nevada, California'
            destination_back[1] = 'Nevada, California'
            destination_front.append('Nevada, CA')
            destination_back.append('in Nevada, CA')
            destination_back.append('Nevada, CA')
        elif destination_front[0] == 'Northern California':
            destination_front.append('Northern CA')
            destination_back.append('in Northern CA')
            destination_back.append('Northern CA')
        elif destination_front[0] == 'Queensland':
            destination_front.append('qld')
            destination_back.append('in qld')
            destination_back.append('qld')
        elif destination_front[0] == 'New York':
            destination_front.append('NY')
            destination_back.append('in NY')
            destination_back.append('NY')
        elif destination_front[-1] == 'Caribbean':
            destination_front.append('the Caribbean')
            destination_back.append('in the Caribbean')
            destination_back.append('the Caribbeans')
            destination_front.append('South America')
            destination_back.append('in South America')
            destination_back.append('South America')
            destination_front.append('Central America')
            destination_back.append('in Central America')
            destination_back.append('Central America')
        elif destination_front[0] == 'New Jersey':
            destination_front.append('NJ')
            destination_back.append('in NJ')
            destination_back.append('NJ')
        elif destination_front[0] == 'Koh Samui':
            destination_front.append('Samui')
            destination_back.append('in Samui')
            destination_back.append('Samui')

######################################################################################

elif (cont_mrkr in url) and (style_mrkr in url): #categories, style and destination
    
    cat_idx_back = url.find(style_mrkr)

    style_idx_front = url.find(style_mrkr)+3
    style_idx_back = url.find(cont_mrkr)
    style = url[style_idx_front:style_idx_back]

    style = url[style_idx_front:style_idx_back].replace('-', " ")
    style = [style] #listify

    find = '/'
    cont_idx = max(pos for pos, char in enumerate(url) if char == find)+1 #index of the last slash. last slash is always followed by destination
    destination = url[cont_idx:].title().replace("-", " ").split() #destination has been listified
    
    destination_f = destination_front[:]
    
    #remove word(s) in category that is already mentioned in prep list
    #e.g. yoga teacher training -> teacher training
    #e.g. budget retreats -> budget
    cat = url[cat_idx_front:cat_idx_back].replace("-", " ")
    cat = ' '.join(i for i in cat.split() if i not in remove_list)
    cat = [cat] #listify
    
    #if there is more than one destination (e.g. Asia and Oceania)
    if 'And' in destination:
        cut = destination.index('And')
        destination1 = ' '.join(destination[:cut])
        destination2 = ' '.join(destination[cut+1:])
        destination_back = ['in '+destination1, destination1, 'in '+destination2, destination2]
        destination_front = [destination1, destination2]
            
        headline1 = count+' '+' '.join(page_title.split()[1:3] + destination_back[0].split())
        #headline2 = ' '.join(page_title.split()[1:3] + destination_back[1].split()) + ' 2016'
        #headline3 = count+' '+' '.join(page_title.split()[1:3] + destination_back[2].split())
        #headline4 = ' '.join(page_title.split()[1:3] + destination_back[3].split()) + ' 2016'

        #headlines = [headline1, headline2, headline3, headline4]

    #if there is only one destination (e.g. Germany)    
    else: 
        destination1 = ' '.join(destination)
        destination_back = ['in '+destination1, destination1]
        destination_front = [destination1]

        #headline1 = count+' '+ ' '.join(page_title.split()[1:3] + destination_back[0].split())
        #headline2 = ' '.join(page_title.split()[1:3] + destination_back[1].split()) + ' 2016'

        #headlines = [headline1, headline2]

        #print "[Checking] headlines:", headlines
        
        destination_f = destination_front[:]
        
        if destination_front[0] == 'United Arab Emirates':
            destination_front.append('UAE')
            destination_back.append('in UAE')
            destination_back.append('UAE')
        elif destination_front[0] == 'South Africa':
            destination_front.append('SA')
            destination_back.append('in SA')
            destination_back.append('SA')
        elif destination_front[0] == 'New Zealand':
            destination_front.append('NZ')
            destination_back.append('in NZ')
            destination_back.append('NZ')
        elif destination_front[0] == 'United Kingdom':
            destination_front.append('UK')
            destination_front.append('the UK')
            destination_back.append('in UK')
            destination_back.append('UK')
            destination_back.append('in the UK')
            destination_back.append('the UK')
        elif destination_front[0] == 'Massachusetts':
            destination_front.append('MA')
            destination_back.append('in MA')
            destination_back.append('MA')
        elif destination_front[0] == 'North Carolina':
            destination_front.append('NC')
            destination_back.append('in NC')
            destination_back.append('NC')
        elif destination_front[0] == 'South Carolina':
            destination_front.append('SC')
            destination_back.append('in SC')
            destination_back.append('SC')
        elif destination_front[0] == 'Western Australia':
            destination_front.append('WA')
            destination_back.append('in WA')
            destination_back.append('WA')
        elif destination_front[0] == 'Pennsylvania':
            destination_front.append('PA')
            destination_back.append('in PA')
            destination_back.append('PA')
        elif destination_front[0] == 'Usa':
            destination_front[0] = 'USA'
            destination_front.append('US')
            destination_front.append('the US')
            destination_front.append('United States')
            destination_back[0] = 'in USA'
            destination_back[1] = 'USA'
            destination_back.append('in US')
            destination_back.append('US')
            destination_back.append('in the US')
            destination_back.append('the US')
            destination_back.append('in United States')
            destination_back.append('United States')
        elif destination_front[0] == 'California':
            destination_front.append('CA')
            destination_back.append('in CA')
            destination_back.append('CA')
        elif destination_front[0] == 'Central Coast California':
            destination_front.append('Central Coast CA')
            destination_back.append('in Central Coast CA')
            destination_back.append('Central Coast CA')
        elif destination_front[0] == 'Nevada California':
            destination_front[0] = 'Nevada, California'
            destination_back[0] = 'in Nevada, California'
            destination_back[1] = 'Nevada, California'
            destination_front.append('Nevada, CA')
            destination_back.append('in Nevada, CA')
            destination_back.append('Nevada, CA')
        elif destination_front[0] == 'Northern California':
            destination_front.append('Northern CA')
            destination_back.append('in Northern CA')
            destination_back.append('Northern CA')
        elif destination_front[0] == 'Queensland':
            destination_front.append('qld')
            destination_back.append('in qld')
            destination_back.append('qld')
        elif destination_front[0] == 'New York':
            destination_front.append('NY')
            destination_back.append('in NY')
            destination_back.append('NY')
        elif destination_front[-1] == 'Caribbean':
            destination_front.append('the Caribbean')
            destination_back.append('in the Caribbean')
            destination_back.append('the Caribbeans')
            destination_front.append('South America')
            destination_back.append('in South America')
            destination_back.append('South America')
            destination_front.append('Central America')
            destination_back.append('in Central America')
            destination_back.append('Central America')
        elif destination_front[0] == 'New Jersey':
            destination_front.append('NJ')
            destination_back.append('in NJ')
            destination_back.append('NJ')
        elif destination_front[0] == 'Koh Samui':
            destination_front.append('Samui')
            destination_back.append('in Samui')
            destination_back.append('Samui')

######################################################################################        
        
#check variables
print "[Checking] category:", cat
print "[Checking] style:", style
print "[Checking] destination_back:", destination_back
print "[Checking] destination_front:", destination_front

#200/300/500 hour yoga teacher training exception
if 'hour' in cat[0]:
    cat[0] = cat[0].split()
    cat[0].insert(2, 'yoga')
    cat[0] = ' '.join(cat[0])
    yoga = [''] 

#yoga holidays exception
if 'holidays' in cat[0]:
    cat[0] = 'yoga holiday'
    cat.append('yoga holidays')
    yoga = ['']
    holiday_word1 = ['retreat',
                     'retreats',
                     'vacation',
                     'vacations',
                     'package',
                     'packages',
                     'resort',
                     'resorts',
                     'camp',
                     'camps'] 
    
#ashrams exception
if 'ashrams' in cat[0]:
    cat.append('ashram')

#beginner exception
if 'beginner' in cat[0]:
    cat.append('beginners')
    cat.append('for beginners')
    cat.append('for beginner')
    cat.append('for a beginner')

#couples exception
if 'couples' in cat[0]:
    cat.append('couple')
    cat.append('for a couple')
    cat.append('for couple')
    cat.append('for couples')

#family exception
if 'family' in cat[0]:
    cat.append('families')
    cat.append('for families')
    cat.append('for family')
    cat.append('for a family')

#women exception
if 'women' in cat[0]:
    cat.append('womens')
    cat.append("women\'s")
    cat.append('for women')
        
    cat.append('woman')
    cat.append('womans')
    cat.append("woman\'s")
    cat.append('for woman')
    cat.append('for a woman')

#surfing exception
if 'surf' in cat[0]:
    cat.append('surfing')

#singles exception
if 'singles' in cat[0]:
    cat.append('single')
    cat.append('for a single')
    cat.append('for single')
    cat.append('for singles')

if cat[0] == 'short':
    cat[0] = 'yoga weekend'
    cat.append('weekend yoga')
    cat.append('yoga weekends')
    cat.append('weekends yoga')
    cat.append('yoga break')
    cat.append('yoga breaks')
    cat.append('short yoga break')
    cat.append('short yoga breaks')
    cat.append('yoga short break')
    cat.append('yoga short breaks')
    yoga = ['']
    holiday_word2 = ['']

if 'budget' in cat[0]:
    cat.append('on a budget')
    cat.append('affordable')
    cat.append('cheap')
    cat.append('inexpensive')
# Out:
# [Checking] category: ['short']
# [Checking] style: ['vinyasa yoga']
# [Checking] destination_back: ['in USA', 'USA', 'in US', 'US', 'in the US', 'the US', 'in United States', 'United States']
# [Checking] destination_front: ['USA', 'US', 'the US', 'United States']

# %%
#generating keywords
if (cont_mrkr not in url) and (style_mrkr not in url): #only categories

    a1 = [cat, yoga, holiday_word1, holiday_word2]
    a2 = [yoga, cat, holiday_word1, holiday_word2]
    a3 = [cat, holiday_word1, yoga, holiday_word2]
    a4 = [yoga, holiday_word1, cat, holiday_word2]
    a5 = [cat, holiday_word1, holiday_word2, yoga]
    a6 = [yoga, holiday_word1, holiday_word2, cat]
    a7 = [cat, yoga]
    a8 = [yoga, cat]
    
    comb1 = list(set(itertools.product(*a1)))
    comb2 = list(set(itertools.product(*a2)))
    comb3 = list(set(itertools.product(*a3)))
    comb4 = list(set(itertools.product(*a4)))
    comb5 = list(set(itertools.product(*a5)))
    comb6 = list(set(itertools.product(*a6)))
    comb7 = list(set(itertools.product(*a7)))
    comb8 = list(set(itertools.product(*a8)))
    
    all_comb = comb1 + comb2 + comb3 + comb4 + comb5 + comb6 + comb7 +comb8
    
    str_destination = ''


elif (cont_mrkr not in url) and (style_mrkr in url): #categories and style
    
    a1 = [style, cat, holiday_word1, holiday_word2]
    a2 = [cat, style, holiday_word1, holiday_word2]
    a3 = [style, holiday_word1, cat, holiday_word2]
    a4 = [cat, holiday_word1, style, holiday_word2]
    a5 = [style, holiday_word1, holiday_word2, cat]
    a6 = [cat, holiday_word1, holiday_word2, style]
    a7 = [style, cat]
    a8 = [cat, style]

    comb1 = list(set(itertools.product(*a1)))
    comb2 = list(set(itertools.product(*a2)))
    comb3 = list(set(itertools.product(*a3)))
    comb4 = list(set(itertools.product(*a4)))
    comb5 = list(set(itertools.product(*a5)))
    comb6 = list(set(itertools.product(*a6)))
    comb7 = list(set(itertools.product(*a7)))
    comb8 = list(set(itertools.product(*a8)))
    
    all_comb = comb1 + comb2 + comb3 + comb4 + comb5 + comb6 + comb7 +comb8
    
    str_destination = ''
    
    
elif (cont_mrkr in url) and (style_mrkr not in url): #categories and destination
    
    a1 = [cat, yoga, holiday_word1, holiday_word2, destination_back]
    a2 = [destination_front, cat, yoga, holiday_word1, holiday_word2]
    
    a3 = [yoga, cat, holiday_word1, holiday_word2, destination_back]
    a4 = [destination_front, yoga, cat, holiday_word1, holiday_word2]
    
    a5 = [yoga, holiday_word1, holiday_word2, cat, destination_back]
    a6 = [destination_front, yoga, holiday_word1, holiday_word2, cat]
    
    a7 = [cat, holiday_word1, holiday_word2, yoga, destination_back]
    a8 = [destination_front, cat, holiday_word1, holiday_word2, yoga]
    
    a9 = [yoga, holiday_word1, cat, holiday_word2, destination_back]
    a10 = [destination_front, yoga, holiday_word1, cat, holiday_word2]
    
    a11 = [cat, holiday_word1, yoga, holiday_word2, destination_back]
    a12 = [destination_front, cat, holiday_word1, yoga, holiday_word2]
    
    a13 = [yoga, holiday_word1, holiday_word2, destination_back, cat]
    a14 = [destination_front, yoga, holiday_word1, holiday_word2, cat]
    
    a15 = [cat, holiday_word1, holiday_word2, destination_back, yoga]
    a16 = [destination_front, cat, holiday_word1, holiday_word2, yoga]
    
    a17 = [yoga, cat, destination_back]
    a18 = [destination_front, yoga, cat]
    
    a19 = [cat, yoga, destination_back]
    a20 = [destination_front, cat, yoga]
    
    comb1 = list(set(itertools.product(*a1)))
    comb2 = list(set(itertools.product(*a2))) 
    comb3 = list(set(itertools.product(*a3)))
    comb4 = list(set(itertools.product(*a4)))
    comb5 = list(set(itertools.product(*a5)))
    comb6 = list(set(itertools.product(*a6)))
    comb7 = list(set(itertools.product(*a7)))
    comb8 = list(set(itertools.product(*a8)))
    comb9 = list(set(itertools.product(*a9))) 
    comb10 = list(set(itertools.product(*a10))) 
    comb11 = list(set(itertools.product(*a11)))
    comb12 = list(set(itertools.product(*a12)))
    comb13 = list(set(itertools.product(*a13)))
    comb14 = list(set(itertools.product(*a14)))
    comb15 = list(set(itertools.product(*a15)))
    comb16 = list(set(itertools.product(*a16)))
    comb17 = list(set(itertools.product(*a17)))
    comb18 = list(set(itertools.product(*a18)))
    comb19 = list(set(itertools.product(*a19)))
    comb20 = list(set(itertools.product(*a20)))

    #join 
    all_comb = comb1 + comb2 + comb3 + comb4 + comb5 + comb6 + comb7 + comb8 + comb9 + comb10 + comb11 + comb12 + comb13 + comb14 + comb15 + comb16 + comb17 + comb18 + comb19 + comb20 

    str_style = ''
    str_destination = destination_front[:]

elif (cont_mrkr in url) and (style_mrkr in url): #categories, style and destination
    
    a1 = [style, cat, holiday_word1, holiday_word2, destination_back]
    a2 = [destination_front, style, cat, holiday_word1, holiday_word2]
    
    a3 = [cat, style, holiday_word1, holiday_word2, destination_back]
    a4 = [destination_front, cat, style, holiday_word1, holiday_word2]
    
    a5 = [style, holiday_word1, holiday_word2, destination_back, cat]
    a6 = [destination_front, style, holiday_word1, holiday_word2, cat]
    
    a9 = [style, cat, destination_back]
    a10 = [destination_front, style, cat]
    
    a11 = [cat, style, destination_back]
    a12 = [destination_front, cat, style]

    comb1 = list(set(itertools.product(*a1)))
    comb2 = list(set(itertools.product(*a2))) 
    comb3 = list(set(itertools.product(*a3)))
    comb4 = list(set(itertools.product(*a4)))
    comb5 = list(set(itertools.product(*a5)))
    comb6 = list(set(itertools.product(*a6)))
    
    comb9 = list(set(itertools.product(*a9)))
    comb10 = list(set(itertools.product(*a10)))
    comb11 = list(set(itertools.product(*a11)))
    comb12 = list(set(itertools.product(*a12)))
    
    #join
    all_comb = comb1 + comb2 + comb3 + comb4 +comb5 + comb6 + comb9 + comb10 + comb11 + comb12
    
    str_destination = destination_front[:]

# %%
#remove keywords like "UK (for women's) yoga retreat"
for i in range(len(all_comb)):
    if (all_comb[i][0] in destination_front) and ('for' in all_comb[i][1]):
        all_comb[i] = []

all_comb = [x for x in all_comb if x != []] #remove empty strings in all_comb

######################################################################################

#join then split again (eliminates double spaces)
results = []

for i in range(len(all_comb)):
    results.append(all_comb[i])
    
######################################################################################  

#remove adjacent duplicates
#e.g. retreat retreat
#e.g. retreat retreats
#e.g. retreats retreat
#e.g. yoga yoga
for i in range(len(results)):
    a = results[i]
    for x in range(len(a)-1):
        if ((a[x] == a[x+1]) or (a[x]+'s' == a[x+1]) or (a[x] == a[x+1]+'s')):
            results[i] = a[:x+1]+a[x+2:]
    
#sort the result in an alphabetical order 
results = sorted(set(results))

#count how many keywords have been created
how_many_kw = len(results)

#add 'and' between cat and yoga for certain categories
copy = list(results)

if cat[0] in requires_and: 
    for i in range(how_many_kw):
        for x in range(len(copy[i])-1):
            if (copy[i][x] in requires_and) and (copy[i][x+1] == 'yoga'):
                copy[i].insert(x+1, 'and')
            elif (copy[i][x] == 'yoga') and (copy[i][x+1] in requires_and): 
                copy[i].insert(x+1, 'and')
        
    #align the result in an alphabetical order  
    results = sorted(results + copy)
    
######################################################################################

#delete some keywords
for i in range(len(results)): #delete keywords with 'on a budget' in the very front of the keyword
    if results[i][0:12] == 'on a budget ':
        results[i] = []
    elif results[i][0:3] == 'for': #delete keywords with 'for women/singles/etc' in the very front of the keyword
        results[i] = []
    elif results[i][0]in holiday_word1: #if a holiday word is the very first word in the keyword
        results[i] = results[i].split()[1:]

results = [x for x in results if x != []] #remove empty strings in results

#remove duplicates, sort in alphabetical order
results = list(sorted(set(results)))

# %%
######################################################################################

#set max cpc bid for keyword and ad group here
max_cpc = '0.30'

#######################################################################################

#prepare csv file content for keywords
if len(destination_f) == 1: #when there is only 1 destination
    str_destination = destination_f[0]
    
if len(destination_f) > 1: #when there is more than 1 destination (e.g. The Americas and Carribean)
    str_destination = ' '.join(destination).replace('And', '&') #(e.g. The Americas and Carribean -> The Americas & Carribeans)

#######################################################################################
    
#prepare column titles for the csv file
kw_column_titles = ["Keyword state", 
                    "Keyword", 
                    "Match type",
                    "Campaign",
                    "Ad group",
                    "Keyword max CPC",
                    "Ad group max CPC"]

#######################################################################################

#for column 'campaign'


str_cat = cat[0].title()    

if str_destination == '': #when without destination 
    
    if style != '': #style and cat
        style[0].split()[0].title()
        camp = 'Longtail [Categories] [Style]'
        
    elif style == '': #cat only
        camp = 'Longtail [Categories]'

else: #cat and destination. cat, style and destination
    camp = 'Longtail %s' %str_destination
    
#######################################################################################

#for column 'ad_group'
adg = ''

if str_destination == '': #without destination 
    if style == '': #cat only
        print "cat only"
        adg = 'Longtail %s %s' %(str_cat)
        
    elif style != '': #style and cat
        print "style and cat"
        str_style = style[0].split()[0].title()
        adg = 'Longtail %s %s' %(str_cat, str_style)
        
else: #with destination
    if style == '': #cat and destination
        print "cat and dest"
        adg = 'Longtail %s %s' %(str_cat, str_destination)
        
    else: #cat, style and destination
        print "cat style and dest"
        str_style = style[0].split()[0].title()
        adg = 'Longtail %s %s %s' %(str_cat, str_style, str_destination)
        
#######################################################################################

#eliminate double spaces
adg = adg.split()
adg = ' '.join(adg)

#######################################################################################
# Out:
# cat style and dest

# %%
#prepare each column
keyword_state = ['enabled'] * len(results) #universal
match_type = ['Exact'] * len(results) #universal
campaign = [camp] * len(results)
ad_group = [adg] * len(results)
keyword_max_cpc = [max_cpc] * len(results) #universal
ad_group_max_cpc = [max_cpc] * len(results) #universal

######################################################################################

#ad group title fix -- group by cat word method

if len(results) > 5000:
    for i in range(len(results)):
        for x in range(len(results[i])):
            if results[i][x] in cat:
                ad_group[i] = 'Longtail %s %s %s' %(results[i][x].title(), str_style, str_destination)

# %%
for i in range(len(ad_group)):
    ad_group[i] = ad_group[i].split()
    for x in range(len(ad_group[i])):
        if ad_group[i][x] == "Woman\'S":
            ad_group[i][x] = "Woman\'s"
        elif ad_group[i][x] == "Women\'S":
            ad_group[i][x] = "Women\'s"
            
for i in range(len(ad_group)):
    ad_group[i] = ' '.join(ad_group[i])

# %%
for i in range(len(results)):
    results[i] = ' '.join(results[i])
    
#add '[' and ']' in the result (keywords)
for i in range(len(results)):
    results[i] = '[' + results[i] + ']'
    
#remove double spaces (split and join again)
for i in range(len(results)):
    results[i] = results[i].split()
    results[i] = ' '.join(results[i])

# %%
results
# Out:
# ['[US short yoga break vinyasa yoga]',
#  '[US short yoga break vinyasa yoga camp ]',
#  '[US short yoga break vinyasa yoga camps ]',
#  '[US short yoga break vinyasa yoga center ]',
#  '[US short yoga break vinyasa yoga centers ]',
#  '[US short yoga break vinyasa yoga centre ]',
#  '[US short yoga break vinyasa yoga centres ]',
#  '[US short yoga break vinyasa yoga deal ]',
#  '[US short yoga break vinyasa yoga deals ]',
#  '[US short yoga break vinyasa yoga holiday ]',
#  '[US short yoga break vinyasa yoga holidays ]',
#  '[US short yoga break vinyasa yoga package ]',
#  '[US short yoga break vinyasa yoga packages ]',
#  '[US short yoga break vinyasa yoga resort ]',
#  '[US short yoga break vinyasa yoga resorts ]',
#  '[US short yoga break vinyasa yoga retreat ]',
#  '[US short yoga break vinyasa yoga retreats ]',
#  '[US short yoga break vinyasa yoga vacation ]',
#  '[US short yoga break vinyasa yoga vacations ]',
#  '[US short yoga breaks vinyasa yoga]',
#  '[US short yoga breaks vinyasa yoga camp ]',
#  '[US short yoga breaks vinyasa yoga camps ]',
#  '[US short yoga breaks vinyasa yoga center ]',
#  '[US short yoga breaks vinyasa yoga centers ]',
#  '[US short yoga breaks vinyasa yoga centre ]',
#  '[US short yoga breaks vinyasa yoga centres ]',
#  '[US short yoga breaks vinyasa yoga deal ]',
#  '[US short yoga breaks vinyasa yoga deals ]',
#  '[US short yoga breaks vinyasa yoga holiday ]',
#  '[US short yoga breaks vinyasa yoga holidays ]',
#  '[US short yoga breaks vinyasa yoga package ]',
#  '[US short yoga breaks vinyasa yoga packages ]',
#  '[US short yoga breaks vinyasa yoga resort ]',
#  '[US short yoga breaks vinyasa yoga resorts ]',
#  '[US short yoga breaks vinyasa yoga retreat ]',
#  '[US short yoga breaks vinyasa yoga retreats ]',
#  '[US short yoga breaks vinyasa yoga vacation ]',
#  '[US short yoga breaks vinyasa yoga vacations ]',
#  '[US vinyasa yoga camp short yoga break]',
#  '[US vinyasa yoga camp short yoga breaks]',
#  '[US vinyasa yoga camp weekend yoga]',
#  '[US vinyasa yoga camp weekends yoga]',
#  '[US vinyasa yoga camp yoga break]',
#  '[US vinyasa yoga camp yoga breaks]',
#  '[US vinyasa yoga camp yoga short break]',
#  '[US vinyasa yoga camp yoga short breaks]',
#  '[US vinyasa yoga camp yoga weekend]',
#  '[US vinyasa yoga camp yoga weekends]',
#  '[US vinyasa yoga camps short yoga break]',
#  '[US vinyasa yoga camps short yoga breaks]',
#  '[US vinyasa yoga camps weekend yoga]',
#  '[US vinyasa yoga camps weekends yoga]',
#  '[US vinyasa yoga camps yoga break]',
#  '[US vinyasa yoga camps yoga breaks]',
#  '[US vinyasa yoga camps yoga short break]',
#  '[US vinyasa yoga camps yoga short breaks]',
#  '[US vinyasa yoga camps yoga weekend]',
#  '[US vinyasa yoga camps yoga weekends]',
#  '[US vinyasa yoga center short yoga break]',
#  '[US vinyasa yoga center short yoga breaks]',
#  '[US vinyasa yoga center weekend yoga]',
#  '[US vinyasa yoga center weekends yoga]',
#  '[US vinyasa yoga center yoga break]',
#  '[US vinyasa yoga center yoga breaks]',
#  '[US vinyasa yoga center yoga short break]',
#  '[US vinyasa yoga center yoga short breaks]',
#  '[US vinyasa yoga center yoga weekend]',
#  '[US vinyasa yoga center yoga weekends]',
#  '[US vinyasa yoga centers short yoga break]',
#  '[US vinyasa yoga centers short yoga breaks]',
#  '[US vinyasa yoga centers weekend yoga]',
#  '[US vinyasa yoga centers weekends yoga]',
#  '[US vinyasa yoga centers yoga break]',
#  '[US vinyasa yoga centers yoga breaks]',
#  '[US vinyasa yoga centers yoga short break]',
#  '[US vinyasa yoga centers yoga short breaks]',
#  '[US vinyasa yoga centers yoga weekend]',
#  '[US vinyasa yoga centers yoga weekends]',
#  '[US vinyasa yoga centre short yoga break]',
#  '[US vinyasa yoga centre short yoga breaks]',
#  '[US vinyasa yoga centre weekend yoga]',
#  '[US vinyasa yoga centre weekends yoga]',
#  '[US vinyasa yoga centre yoga break]',
#  '[US vinyasa yoga centre yoga breaks]',
#  '[US vinyasa yoga centre yoga short break]',
#  '[US vinyasa yoga centre yoga short breaks]',
#  '[US vinyasa yoga centre yoga weekend]',
#  '[US vinyasa yoga centre yoga weekends]',
#  '[US vinyasa yoga centres short yoga break]',
#  '[US vinyasa yoga centres short yoga breaks]',
#  '[US vinyasa yoga centres weekend yoga]',
#  '[US vinyasa yoga centres weekends yoga]',
#  '[US vinyasa yoga centres yoga break]',
#  '[US vinyasa yoga centres yoga breaks]',
#  '[US vinyasa yoga centres yoga short break]',
#  '[US vinyasa yoga centres yoga short breaks]',
#  '[US vinyasa yoga centres yoga weekend]',
#  '[US vinyasa yoga centres yoga weekends]',
#  '[US vinyasa yoga deal short yoga break]',
#  '[US vinyasa yoga deal short yoga breaks]',
#  '[US vinyasa yoga deal weekend yoga]',
#  '[US vinyasa yoga deal weekends yoga]',
#  '[US vinyasa yoga deal yoga break]',
#  '[US vinyasa yoga deal yoga breaks]',
#  '[US vinyasa yoga deal yoga short break]',
#  '[US vinyasa yoga deal yoga short breaks]',
#  '[US vinyasa yoga deal yoga weekend]',
#  '[US vinyasa yoga deal yoga weekends]',
#  '[US vinyasa yoga deals short yoga break]',
#  '[US vinyasa yoga deals short yoga breaks]',
#  '[US vinyasa yoga deals weekend yoga]',
#  '[US vinyasa yoga deals weekends yoga]',
#  '[US vinyasa yoga deals yoga break]',
#  '[US vinyasa yoga deals yoga breaks]',
#  '[US vinyasa yoga deals yoga short break]',
#  '[US vinyasa yoga deals yoga short breaks]',
#  '[US vinyasa yoga deals yoga weekend]',
#  '[US vinyasa yoga deals yoga weekends]',
#  '[US vinyasa yoga holiday short yoga break]',
#  '[US vinyasa yoga holiday short yoga breaks]',
#  '[US vinyasa yoga holiday weekend yoga]',
#  '[US vinyasa yoga holiday weekends yoga]',
#  '[US vinyasa yoga holiday yoga break]',
#  '[US vinyasa yoga holiday yoga breaks]',
#  '[US vinyasa yoga holiday yoga short break]',
#  '[US vinyasa yoga holiday yoga short breaks]',
#  '[US vinyasa yoga holiday yoga weekend]',
#  '[US vinyasa yoga holiday yoga weekends]',
#  '[US vinyasa yoga holidays short yoga break]',
#  '[US vinyasa yoga holidays short yoga breaks]',
#  '[US vinyasa yoga holidays weekend yoga]',
#  '[US vinyasa yoga holidays weekends yoga]',
#  '[US vinyasa yoga holidays yoga break]',
#  '[US vinyasa yoga holidays yoga breaks]',
#  '[US vinyasa yoga holidays yoga short break]',
#  '[US vinyasa yoga holidays yoga short breaks]',
#  '[US vinyasa yoga holidays yoga weekend]',
#  '[US vinyasa yoga holidays yoga weekends]',
#  '[US vinyasa yoga package short yoga break]',
#  '[US vinyasa yoga package short yoga breaks]',
#  '[US vinyasa yoga package weekend yoga]',
#  '[US vinyasa yoga package weekends yoga]',
#  '[US vinyasa yoga package yoga break]',
#  '[US vinyasa yoga package yoga breaks]',
#  '[US vinyasa yoga package yoga short break]',
#  '[US vinyasa yoga package yoga short breaks]',
#  '[US vinyasa yoga package yoga weekend]',
#  '[US vinyasa yoga package yoga weekends]',
#  '[US vinyasa yoga packages short yoga break]',
#  '[US vinyasa yoga packages short yoga breaks]',
#  '[US vinyasa yoga packages weekend yoga]',
#  '[US vinyasa yoga packages weekends yoga]',
#  '[US vinyasa yoga packages yoga break]',
#  '[US vinyasa yoga packages yoga breaks]',
#  '[US vinyasa yoga packages yoga short break]',
#  '[US vinyasa yoga packages yoga short breaks]',
#  '[US vinyasa yoga packages yoga weekend]',
#  '[US vinyasa yoga packages yoga weekends]',
#  '[US vinyasa yoga resort short yoga break]',
#  '[US vinyasa yoga resort short yoga breaks]',
#  '[US vinyasa yoga resort weekend yoga]',
#  '[US vinyasa yoga resort weekends yoga]',
#  '[US vinyasa yoga resort yoga break]',
#  '[US vinyasa yoga resort yoga breaks]',
#  '[US vinyasa yoga resort yoga short break]',
#  '[US vinyasa yoga resort yoga short breaks]',
#  '[US vinyasa yoga resort yoga weekend]',
#  '[US vinyasa yoga resort yoga weekends]',
#  '[US vinyasa yoga resorts short yoga break]',
#  '[US vinyasa yoga resorts short yoga breaks]',
#  '[US vinyasa yoga resorts weekend yoga]',
#  '[US vinyasa yoga resorts weekends yoga]',
#  '[US vinyasa yoga resorts yoga break]',
#  '[US vinyasa yoga resorts yoga breaks]',
#  '[US vinyasa yoga resorts yoga short break]',
#  '[US vinyasa yoga resorts yoga short breaks]',
#  '[US vinyasa yoga resorts yoga weekend]',
#  '[US vinyasa yoga resorts yoga weekends]',
#  '[US vinyasa yoga retreat short yoga break]',
#  '[US vinyasa yoga retreat short yoga breaks]',
#  '[US vinyasa yoga retreat weekend yoga]',
#  '[US vinyasa yoga retreat weekends yoga]',
#  '[US vinyasa yoga retreat yoga break]',
#  '[US vinyasa yoga retreat yoga breaks]',
#  '[US vinyasa yoga retreat yoga short break]',
#  '[US vinyasa yoga retreat yoga short breaks]',
#  '[US vinyasa yoga retreat yoga weekend]',
#  '[US vinyasa yoga retreat yoga weekends]',
#  '[US vinyasa yoga retreats short yoga break]',
#  '[US vinyasa yoga retreats short yoga breaks]',
#  '[US vinyasa yoga retreats weekend yoga]',
#  '[US vinyasa yoga retreats weekends yoga]',
#  '[US vinyasa yoga retreats yoga break]',
#  '[US vinyasa yoga retreats yoga breaks]',
#  '[US vinyasa yoga retreats yoga short break]',
#  '[US vinyasa yoga retreats yoga short breaks]',
#  '[US vinyasa yoga retreats yoga weekend]',
#  '[US vinyasa yoga retreats yoga weekends]',
#  '[US vinyasa yoga short yoga break]',
#  '[US vinyasa yoga short yoga break camp ]',
#  '[US vinyasa yoga short yoga break camps ]',
#  '[US vinyasa yoga short yoga break center ]',
#  '[US vinyasa yoga short yoga break centers ]',
#  '[US vinyasa yoga short yoga break centre ]',
#  '[US vinyasa yoga short yoga break centres ]',
#  '[US vinyasa yoga short yoga break deal ]',
#  '[US vinyasa yoga short yoga break deals ]',
#  '[US vinyasa yoga short yoga break holiday ]',
#  '[US vinyasa yoga short yoga break holidays ]',
#  '[US vinyasa yoga short yoga break package ]',
#  '[US vinyasa yoga short yoga break packages ]',
#  '[US vinyasa yoga short yoga break resort ]',
#  '[US vinyasa yoga short yoga break resorts ]',
#  '[US vinyasa yoga short yoga break retreat ]',
#  '[US vinyasa yoga short yoga break retreats ]',
#  '[US vinyasa yoga short yoga break vacation ]',
#  '[US vinyasa yoga short yoga break vacations ]',
#  '[US vinyasa yoga short yoga breaks]',
#  '[US vinyasa yoga short yoga breaks camp ]',
#  '[US vinyasa yoga short yoga breaks camps ]',
#  '[US vinyasa yoga short yoga breaks center ]',
#  '[US vinyasa yoga short yoga breaks centers ]',
#  '[US vinyasa yoga short yoga breaks centre ]',
#  '[US vinyasa yoga short yoga breaks centres ]',
#  '[US vinyasa yoga short yoga breaks deal ]',
#  '[US vinyasa yoga short yoga breaks deals ]',
#  '[US vinyasa yoga short yoga breaks holiday ]',
#  '[US vinyasa yoga short yoga breaks holidays ]',
#  '[US vinyasa yoga short yoga breaks package ]',
#  '[US vinyasa yoga short yoga breaks packages ]',
#  '[US vinyasa yoga short yoga breaks resort ]',
#  '[US vinyasa yoga short yoga breaks resorts ]',
#  '[US vinyasa yoga short yoga breaks retreat ]',
#  '[US vinyasa yoga short yoga breaks retreats ]',
#  '[US vinyasa yoga short yoga breaks vacation ]',
#  '[US vinyasa yoga short yoga breaks vacations ]',
#  '[US vinyasa yoga vacation short yoga break]',
#  '[US vinyasa yoga vacation short yoga breaks]',
#  '[US vinyasa yoga vacation weekend yoga]',
#  '[US vinyasa yoga vacation weekends yoga]',
#  '[US vinyasa yoga vacation yoga break]',
#  '[US vinyasa yoga vacation yoga breaks]',
#  '[US vinyasa yoga vacation yoga short break]',
#  '[US vinyasa yoga vacation yoga short breaks]',
#  '[US vinyasa yoga vacation yoga weekend]',
#  '[US vinyasa yoga vacation yoga weekends]',
#  '[US vinyasa yoga vacations short yoga break]',
#  '[US vinyasa yoga vacations short yoga breaks]',
#  '[US vinyasa yoga vacations weekend yoga]',
#  '[US vinyasa yoga vacations weekends yoga]',
#  '[US vinyasa yoga vacations yoga break]',
#  '[US vinyasa yoga vacations yoga breaks]',
#  '[US vinyasa yoga vacations yoga short break]',
#  '[US vinyasa yoga vacations yoga short breaks]',
#  '[US vinyasa yoga vacations yoga weekend]',
#  '[US vinyasa yoga vacations yoga weekends]',
#  '[US vinyasa yoga weekend yoga]',
#  '[US vinyasa yoga weekend yoga camp ]',
#  '[US vinyasa yoga weekend yoga camps ]',
#  '[US vinyasa yoga weekend yoga center ]',
#  '[US vinyasa yoga weekend yoga centers ]',
#  '[US vinyasa yoga weekend yoga centre ]',
#  '[US vinyasa yoga weekend yoga centres ]',
#  '[US vinyasa yoga weekend yoga deal ]',
#  '[US vinyasa yoga weekend yoga deals ]',
#  '[US vinyasa yoga weekend yoga holiday ]',
#  '[US vinyasa yoga weekend yoga holidays ]',
#  '[US vinyasa yoga weekend yoga package ]',
#  '[US vinyasa yoga weekend yoga packages ]',
#  '[US vinyasa yoga weekend yoga resort ]',
#  '[US vinyasa yoga weekend yoga resorts ]',
#  '[US vinyasa yoga weekend yoga retreat ]',
#  '[US vinyasa yoga weekend yoga retreats ]',
#  '[US vinyasa yoga weekend yoga vacation ]',
#  '[US vinyasa yoga weekend yoga vacations ]',
#  '[US vinyasa yoga weekends yoga]',
#  '[US vinyasa yoga weekends yoga camp ]',
#  '[US vinyasa yoga weekends yoga camps ]',
#  '[US vinyasa yoga weekends yoga center ]',
#  '[US vinyasa yoga weekends yoga centers ]',
#  '[US vinyasa yoga weekends yoga centre ]',
#  '[US vinyasa yoga weekends yoga centres ]',
#  '[US vinyasa yoga weekends yoga deal ]',
#  '[US vinyasa yoga weekends yoga deals ]',
#  '[US vinyasa yoga weekends yoga holiday ]',
#  '[US vinyasa yoga weekends yoga holidays ]',
#  '[US vinyasa yoga weekends yoga package ]',
#  '[US vinyasa yoga weekends yoga packages ]',
#  '[US vinyasa yoga weekends yoga resort ]',
#  '[US vinyasa yoga weekends yoga resorts ]',
#  '[US vinyasa yoga weekends yoga retreat ]',
#  '[US vinyasa yoga weekends yoga retreats ]',
#  '[US vinyasa yoga weekends yoga vacation ]',
#  '[US vinyasa yoga weekends yoga vacations ]',
#  '[US vinyasa yoga yoga break]',
#  '[US vinyasa yoga yoga break camp ]',
#  '[US vinyasa yoga yoga break camps ]',
#  '[US vinyasa yoga yoga break center ]',
#  '[US vinyasa yoga yoga break centers ]',
#  '[US vinyasa yoga yoga break centre ]',
#  '[US vinyasa yoga yoga break centres ]',
#  '[US vinyasa yoga yoga break deal ]',
#  '[US vinyasa yoga yoga break deals ]',
#  '[US vinyasa yoga yoga break holiday ]',
#  '[US vinyasa yoga yoga break holidays ]',
#  '[US vinyasa yoga yoga break package ]',
#  '[US vinyasa yoga yoga break packages ]',
#  '[US vinyasa yoga yoga break resort ]',
#  '[US vinyasa yoga yoga break resorts ]',
#  '[US vinyasa yoga yoga break retreat ]',
#  '[US vinyasa yoga yoga break retreats ]',
#  '[US vinyasa yoga yoga break vacation ]',
#  '[US vinyasa yoga yoga break vacations ]',
#  '[US vinyasa yoga yoga breaks]',
#  '[US vinyasa yoga yoga breaks camp ]',
#  '[US vinyasa yoga yoga breaks camps ]',
#  '[US vinyasa yoga yoga breaks center ]',
#  '[US vinyasa yoga yoga breaks centers ]',
#  '[US vinyasa yoga yoga breaks centre ]',
#  '[US vinyasa yoga yoga breaks centres ]',
#  '[US vinyasa yoga yoga breaks deal ]',
#  '[US vinyasa yoga yoga breaks deals ]',
#  '[US vinyasa yoga yoga breaks holiday ]',
#  '[US vinyasa yoga yoga breaks holidays ]',
#  '[US vinyasa yoga yoga breaks package ]',
#  '[US vinyasa yoga yoga breaks packages ]',
#  '[US vinyasa yoga yoga breaks resort ]',
#  '[US vinyasa yoga yoga breaks resorts ]',
#  '[US vinyasa yoga yoga breaks retreat ]',
#  '[US vinyasa yoga yoga breaks retreats ]',
#  '[US vinyasa yoga yoga breaks vacation ]',
#  '[US vinyasa yoga yoga breaks vacations ]',
#  '[US vinyasa yoga yoga short break]',
#  '[US vinyasa yoga yoga short break camp ]',
#  '[US vinyasa yoga yoga short break camps ]',
#  '[US vinyasa yoga yoga short break center ]',
#  '[US vinyasa yoga yoga short break centers ]',
#  '[US vinyasa yoga yoga short break centre ]',
#  '[US vinyasa yoga yoga short break centres ]',
#  '[US vinyasa yoga yoga short break deal ]',
#  '[US vinyasa yoga yoga short break deals ]',
#  '[US vinyasa yoga yoga short break holiday ]',
#  '[US vinyasa yoga yoga short break holidays ]',
#  '[US vinyasa yoga yoga short break package ]',
#  '[US vinyasa yoga yoga short break packages ]',
#  '[US vinyasa yoga yoga short break resort ]',
#  '[US vinyasa yoga yoga short break resorts ]',
#  '[US vinyasa yoga yoga short break retreat ]',
#  '[US vinyasa yoga yoga short break retreats ]',
#  '[US vinyasa yoga yoga short break vacation ]',
#  '[US vinyasa yoga yoga short break vacations ]',
#  '[US vinyasa yoga yoga short breaks]',
#  '[US vinyasa yoga yoga short breaks camp ]',
#  '[US vinyasa yoga yoga short breaks camps ]',
#  '[US vinyasa yoga yoga short breaks center ]',
#  '[US vinyasa yoga yoga short breaks centers ]',
#  '[US vinyasa yoga yoga short breaks centre ]',
#  '[US vinyasa yoga yoga short breaks centres ]',
#  '[US vinyasa yoga yoga short breaks deal ]',
#  '[US vinyasa yoga yoga short breaks deals ]',
#  '[US vinyasa yoga yoga short breaks holiday ]',
#  '[US vinyasa yoga yoga short breaks holidays ]',
#  '[US vinyasa yoga yoga short breaks package ]',
#  '[US vinyasa yoga yoga short breaks packages ]',
#  '[US vinyasa yoga yoga short breaks resort ]',
#  '[US vinyasa yoga yoga short breaks resorts ]',
#  '[US vinyasa yoga yoga short breaks retreat ]',
#  '[US vinyasa yoga yoga short breaks retreats ]',
#  '[US vinyasa yoga yoga short breaks vacation ]',
#  '[US vinyasa yoga yoga short breaks vacations ]',
#  '[US vinyasa yoga yoga weekend]',
#  '[US vinyasa yoga yoga weekend camp ]',
#  '[US vinyasa yoga yoga weekend camps ]',
#  '[US vinyasa yoga yoga weekend center ]',
#  '[US vinyasa yoga yoga weekend centers ]',
#  '[US vinyasa yoga yoga weekend centre ]',
#  '[US vinyasa yoga yoga weekend centres ]',
#  '[US vinyasa yoga yoga weekend deal ]',
#  '[US vinyasa yoga yoga weekend deals ]',
#  '[US vinyasa yoga yoga weekend holiday ]',
#  '[US vinyasa yoga yoga weekend holidays ]',
#  '[US vinyasa yoga yoga weekend package ]',
#  '[US vinyasa yoga yoga weekend packages ]',
#  '[US vinyasa yoga yoga weekend resort ]',
#  '[US vinyasa yoga yoga weekend resorts ]',
#  '[US vinyasa yoga yoga weekend retreat ]',
#  '[US vinyasa yoga yoga weekend retreats ]',
#  '[US vinyasa yoga yoga weekend vacation ]',
#  '[US vinyasa yoga yoga weekend vacations ]',
#  '[US vinyasa yoga yoga weekends]',
#  '[US vinyasa yoga yoga weekends camp ]',
#  '[US vinyasa yoga yoga weekends camps ]',
#  '[US vinyasa yoga yoga weekends center ]',
#  '[US vinyasa yoga yoga weekends centers ]',
#  '[US vinyasa yoga yoga weekends centre ]',
#  '[US vinyasa yoga yoga weekends centres ]',
#  '[US vinyasa yoga yoga weekends deal ]',
#  '[US vinyasa yoga yoga weekends deals ]',
#  '[US vinyasa yoga yoga weekends holiday ]',
#  '[US vinyasa yoga yoga weekends holidays ]',
#  '[US vinyasa yoga yoga weekends package ]',
#  '[US vinyasa yoga yoga weekends packages ]',
#  '[US vinyasa yoga yoga weekends resort ]',
#  '[US vinyasa yoga yoga weekends resorts ]',
#  '[US vinyasa yoga yoga weekends retreat ]',
#  '[US vinyasa yoga yoga weekends retreats ]',
#  '[US vinyasa yoga yoga weekends vacation ]',
#  '[US vinyasa yoga yoga weekends vacations ]',
#  '[US weekend yoga vinyasa yoga]',
#  '[US weekend yoga vinyasa yoga camp ]',
#  '[US weekend yoga vinyasa yoga camps ]',
#  '[US weekend yoga vinyasa yoga center ]',
#  '[US weekend yoga vinyasa yoga centers ]',
#  '[US weekend yoga vinyasa yoga centre ]',
#  '[US weekend yoga vinyasa yoga centres ]',
#  '[US weekend yoga vinyasa yoga deal ]',
#  '[US weekend yoga vinyasa yoga deals ]',
#  '[US weekend yoga vinyasa yoga holiday ]',
#  '[US weekend yoga vinyasa yoga holidays ]',
#  '[US weekend yoga vinyasa yoga package ]',
#  '[US weekend yoga vinyasa yoga packages ]',
#  '[US weekend yoga vinyasa yoga resort ]',
#  '[US weekend yoga vinyasa yoga resorts ]',
#  '[US weekend yoga vinyasa yoga retreat ]',
#  '[US weekend yoga vinyasa yoga retreats ]',
#  '[US weekend yoga vinyasa yoga vacation ]',
#  '[US weekend yoga vinyasa yoga vacations ]',
#  '[US weekends yoga vinyasa yoga]',
#  '[US weekends yoga vinyasa yoga camp ]',
#  '[US weekends yoga vinyasa yoga camps ]',
#  '[US weekends yoga vinyasa yoga center ]',
#  '[US weekends yoga vinyasa yoga centers ]',
#  '[US weekends yoga vinyasa yoga centre ]',
#  '[US weekends yoga vinyasa yoga centres ]',
#  '[US weekends yoga vinyasa yoga deal ]',
#  '[US weekends yoga vinyasa yoga deals ]',
#  '[US weekends yoga vinyasa yoga holiday ]',
#  '[US weekends yoga vinyasa yoga holidays ]',
#  '[US weekends yoga vinyasa yoga package ]',
#  '[US weekends yoga vinyasa yoga packages ]',
#  '[US weekends yoga vinyasa yoga resort ]',
#  '[US weekends yoga vinyasa yoga resorts ]',
#  '[US weekends yoga vinyasa yoga retreat ]',
#  '[US weekends yoga vinyasa yoga retreats ]',
#  '[US weekends yoga vinyasa yoga vacation ]',
#  '[US weekends yoga vinyasa yoga vacations ]',
#  '[US yoga break vinyasa yoga]',
#  '[US yoga break vinyasa yoga camp ]',
#  '[US yoga break vinyasa yoga camps ]',
#  '[US yoga break vinyasa yoga center ]',
#  '[US yoga break vinyasa yoga centers ]',
#  '[US yoga break vinyasa yoga centre ]',
#  '[US yoga break vinyasa yoga centres ]',
#  '[US yoga break vinyasa yoga deal ]',
#  '[US yoga break vinyasa yoga deals ]',
#  '[US yoga break vinyasa yoga holiday ]',
#  '[US yoga break vinyasa yoga holidays ]',
#  '[US yoga break vinyasa yoga package ]',
#  '[US yoga break vinyasa yoga packages ]',
#  '[US yoga break vinyasa yoga resort ]',
#  '[US yoga break vinyasa yoga resorts ]',
#  '[US yoga break vinyasa yoga retreat ]',
#  '[US yoga break vinyasa yoga retreats ]',
#  '[US yoga break vinyasa yoga vacation ]',
#  '[US yoga break vinyasa yoga vacations ]',
#  '[US yoga breaks vinyasa yoga]',
#  '[US yoga breaks vinyasa yoga camp ]',
#  '[US yoga breaks vinyasa yoga camps ]',
#  '[US yoga breaks vinyasa yoga center ]',
#  '[US yoga breaks vinyasa yoga centers ]',
#  '[US yoga breaks vinyasa yoga centre ]',
#  '[US yoga breaks vinyasa yoga centres ]',
#  '[US yoga breaks vinyasa yoga deal ]',
#  '[US yoga breaks vinyasa yoga deals ]',
#  '[US yoga breaks vinyasa yoga holiday ]',
#  '[US yoga breaks vinyasa yoga holidays ]',
#  '[US yoga breaks vinyasa yoga package ]',
#  '[US yoga breaks vinyasa yoga packages ]',
#  '[US yoga breaks vinyasa yoga resort ]',
#  '[US yoga breaks vinyasa yoga resorts ]',
#  '[US yoga breaks vinyasa yoga retreat ]',
#  '[US yoga breaks vinyasa yoga retreats ]',
#  '[US yoga breaks vinyasa yoga vacation ]',
#  '[US yoga breaks vinyasa yoga vacations ]',
#  '[US yoga short break vinyasa yoga]',
#  '[US yoga short break vinyasa yoga camp ]',
#  '[US yoga short break vinyasa yoga camps ]',
#  '[US yoga short break vinyasa yoga center ]',
#  '[US yoga short break vinyasa yoga centers ]',
#  '[US yoga short break vinyasa yoga centre ]',
#  '[US yoga short break vinyasa yoga centres ]',
#  '[US yoga short break vinyasa yoga deal ]',
#  '[US yoga short break vinyasa yoga deals ]',
#  '[US yoga short break vinyasa yoga holiday ]',
#  '[US yoga short break vinyasa yoga holidays ]',
#  '[US yoga short break vinyasa yoga package ]',
#  '[US yoga short break vinyasa yoga packages ]',
#  '[US yoga short break vinyasa yoga resort ]',
#  '[US yoga short break vinyasa yoga resorts ]',
#  '[US yoga short break vinyasa yoga retreat ]',
#  '[US yoga short break vinyasa yoga retreats ]',
#  '[US yoga short break vinyasa yoga vacation ]',
#  '[US yoga short break vinyasa yoga vacations ]',
#  '[US yoga short breaks vinyasa yoga]',
#  '[US yoga short breaks vinyasa yoga camp ]',
#  '[US yoga short breaks vinyasa yoga camps ]',
#  '[US yoga short breaks vinyasa yoga center ]',
#  '[US yoga short breaks vinyasa yoga centers ]',
#  '[US yoga short breaks vinyasa yoga centre ]',
#  '[US yoga short breaks vinyasa yoga centres ]',
#  '[US yoga short breaks vinyasa yoga deal ]',
#  '[US yoga short breaks vinyasa yoga deals ]',
#  '[US yoga short breaks vinyasa yoga holiday ]',
#  '[US yoga short breaks vinyasa yoga holidays ]',
#  '[US yoga short breaks vinyasa yoga package ]',
#  '[US yoga short breaks vinyasa yoga packages ]',
#  '[US yoga short breaks vinyasa yoga resort ]',
#  '[US yoga short breaks vinyasa yoga resorts ]',
#  '[US yoga short breaks vinyasa yoga retreat ]',
#  '[US yoga short breaks vinyasa yoga retreats ]',
#  '[US yoga short breaks vinyasa yoga vacation ]',
#  '[US yoga short breaks vinyasa yoga vacations ]',
#  '[US yoga weekend vinyasa yoga]',
#  '[US yoga weekend vinyasa yoga camp ]',
#  '[US yoga weekend vinyasa yoga camps ]',
#  '[US yoga weekend vinyasa yoga center ]',
#  '[US yoga weekend vinyasa yoga centers ]',
#  '[US yoga weekend vinyasa yoga centre ]',
#  '[US yoga weekend vinyasa yoga centres ]',
#  '[US yoga weekend vinyasa yoga deal ]',
#  '[US yoga weekend vinyasa yoga deals ]',
#  '[US yoga weekend vinyasa yoga holiday ]',
#  '[US yoga weekend vinyasa yoga holidays ]',
#  '[US yoga weekend vinyasa yoga package ]',
#  '[US yoga weekend vinyasa yoga packages ]',
#  '[US yoga weekend vinyasa yoga resort ]',
#  '[US yoga weekend vinyasa yoga resorts ]',
#  '[US yoga weekend vinyasa yoga retreat ]',
#  '[US yoga weekend vinyasa yoga retreats ]',
#  '[US yoga weekend vinyasa yoga vacation ]',
#  '[US yoga weekend vinyasa yoga vacations ]',
#  '[US yoga weekends vinyasa yoga]',
#  '[US yoga weekends vinyasa yoga camp ]',
#  '[US yoga weekends vinyasa yoga camps ]',
#  '[US yoga weekends vinyasa yoga center ]',
#  '[US yoga weekends vinyasa yoga centers ]',
#  '[US yoga weekends vinyasa yoga centre ]',
#  '[US yoga weekends vinyasa yoga centres ]',
#  '[US yoga weekends vinyasa yoga deal ]',
#  '[US yoga weekends vinyasa yoga deals ]',
#  '[US yoga weekends vinyasa yoga holiday ]',
#  '[US yoga weekends vinyasa yoga holidays ]',
#  '[US yoga weekends vinyasa yoga package ]',
#  '[US yoga weekends vinyasa yoga packages ]',
#  '[US yoga weekends vinyasa yoga resort ]',
#  '[US yoga weekends vinyasa yoga resorts ]',
#  '[US yoga weekends vinyasa yoga retreat ]',
#  '[US yoga weekends vinyasa yoga retreats ]',
#  '[US yoga weekends vinyasa yoga vacation ]',
#  '[US yoga weekends vinyasa yoga vacations ]',
#  '[USA short yoga break vinyasa yoga]',
#  '[USA short yoga break vinyasa yoga camp ]',
#  '[USA short yoga break vinyasa yoga camps ]',
#  '[USA short yoga break vinyasa yoga center ]',
#  '[USA short yoga break vinyasa yoga centers ]',
#  '[USA short yoga break vinyasa yoga centre ]',
#  '[USA short yoga break vinyasa yoga centres ]',
#  '[USA short yoga break vinyasa yoga deal ]',
#  '[USA short yoga break vinyasa yoga deals ]',
#  '[USA short yoga break vinyasa yoga holiday ]',
#  '[USA short yoga break vinyasa yoga holidays ]',
#  '[USA short yoga break vinyasa yoga package ]',
#  '[USA short yoga break vinyasa yoga packages ]',
#  '[USA short yoga break vinyasa yoga resort ]',
#  '[USA short yoga break vinyasa yoga resorts ]',
#  '[USA short yoga break vinyasa yoga retreat ]',
#  '[USA short yoga break vinyasa yoga retreats ]',
#  '[USA short yoga break vinyasa yoga vacation ]',
#  '[USA short yoga break vinyasa yoga vacations ]',
#  '[USA short yoga breaks vinyasa yoga]',
#  '[USA short yoga breaks vinyasa yoga camp ]',
#  '[USA short yoga breaks vinyasa yoga camps ]',
#  '[USA short yoga breaks vinyasa yoga center ]',
#  '[USA short yoga breaks vinyasa yoga centers ]',
#  '[USA short yoga breaks vinyasa yoga centre ]',
#  '[USA short yoga breaks vinyasa yoga centres ]',
#  '[USA short yoga breaks vinyasa yoga deal ]',
#  '[USA short yoga breaks vinyasa yoga deals ]',
#  '[USA short yoga breaks vinyasa yoga holiday ]',
#  '[USA short yoga breaks vinyasa yoga holidays ]',
#  '[USA short yoga breaks vinyasa yoga package ]',
#  '[USA short yoga breaks vinyasa yoga packages ]',
#  '[USA short yoga breaks vinyasa yoga resort ]',
#  '[USA short yoga breaks vinyasa yoga resorts ]',
#  '[USA short yoga breaks vinyasa yoga retreat ]',
#  '[USA short yoga breaks vinyasa yoga retreats ]',
#  '[USA short yoga breaks vinyasa yoga vacation ]',
#  '[USA short yoga breaks vinyasa yoga vacations ]',
#  '[USA vinyasa yoga camp short yoga break]',
#  '[USA vinyasa yoga camp short yoga breaks]',
#  '[USA vinyasa yoga camp weekend yoga]',
#  '[USA vinyasa yoga camp weekends yoga]',
#  '[USA vinyasa yoga camp yoga break]',
#  '[USA vinyasa yoga camp yoga breaks]',
#  '[USA vinyasa yoga camp yoga short break]',
#  '[USA vinyasa yoga camp yoga short breaks]',
#  '[USA vinyasa yoga camp yoga weekend]',
#  '[USA vinyasa yoga camp yoga weekends]',
#  '[USA vinyasa yoga camps short yoga break]',
#  '[USA vinyasa yoga camps short yoga breaks]',
#  '[USA vinyasa yoga camps weekend yoga]',
#  '[USA vinyasa yoga camps weekends yoga]',
#  '[USA vinyasa yoga camps yoga break]',
#  '[USA vinyasa yoga camps yoga breaks]',
#  '[USA vinyasa yoga camps yoga short break]',
#  '[USA vinyasa yoga camps yoga short breaks]',
#  '[USA vinyasa yoga camps yoga weekend]',
#  '[USA vinyasa yoga camps yoga weekends]',
#  '[USA vinyasa yoga center short yoga break]',
#  '[USA vinyasa yoga center short yoga breaks]',
#  '[USA vinyasa yoga center weekend yoga]',
#  '[USA vinyasa yoga center weekends yoga]',
#  '[USA vinyasa yoga center yoga break]',
#  '[USA vinyasa yoga center yoga breaks]',
#  '[USA vinyasa yoga center yoga short break]',
#  '[USA vinyasa yoga center yoga short breaks]',
#  '[USA vinyasa yoga center yoga weekend]',
#  '[USA vinyasa yoga center yoga weekends]',
#  '[USA vinyasa yoga centers short yoga break]',
#  '[USA vinyasa yoga centers short yoga breaks]',
#  '[USA vinyasa yoga centers weekend yoga]',
#  '[USA vinyasa yoga centers weekends yoga]',
#  '[USA vinyasa yoga centers yoga break]',
#  '[USA vinyasa yoga centers yoga breaks]',
#  '[USA vinyasa yoga centers yoga short break]',
#  '[USA vinyasa yoga centers yoga short breaks]',
#  '[USA vinyasa yoga centers yoga weekend]',
#  '[USA vinyasa yoga centers yoga weekends]',
#  '[USA vinyasa yoga centre short yoga break]',
#  '[USA vinyasa yoga centre short yoga breaks]',
#  '[USA vinyasa yoga centre weekend yoga]',
#  '[USA vinyasa yoga centre weekends yoga]',
#  '[USA vinyasa yoga centre yoga break]',
#  '[USA vinyasa yoga centre yoga breaks]',
#  '[USA vinyasa yoga centre yoga short break]',
#  '[USA vinyasa yoga centre yoga short breaks]',
#  '[USA vinyasa yoga centre yoga weekend]',
#  '[USA vinyasa yoga centre yoga weekends]',
#  '[USA vinyasa yoga centres short yoga break]',
#  '[USA vinyasa yoga centres short yoga breaks]',
#  '[USA vinyasa yoga centres weekend yoga]',
#  '[USA vinyasa yoga centres weekends yoga]',
#  '[USA vinyasa yoga centres yoga break]',
#  '[USA vinyasa yoga centres yoga breaks]',
#  '[USA vinyasa yoga centres yoga short break]',
#  '[USA vinyasa yoga centres yoga short breaks]',
#  '[USA vinyasa yoga centres yoga weekend]',
#  '[USA vinyasa yoga centres yoga weekends]',
#  '[USA vinyasa yoga deal short yoga break]',
#  '[USA vinyasa yoga deal short yoga breaks]',
#  '[USA vinyasa yoga deal weekend yoga]',
#  '[USA vinyasa yoga deal weekends yoga]',
#  '[USA vinyasa yoga deal yoga break]',
#  '[USA vinyasa yoga deal yoga breaks]',
#  '[USA vinyasa yoga deal yoga short break]',
#  '[USA vinyasa yoga deal yoga short breaks]',
#  '[USA vinyasa yoga deal yoga weekend]',
#  '[USA vinyasa yoga deal yoga weekends]',
#  '[USA vinyasa yoga deals short yoga break]',
#  '[USA vinyasa yoga deals short yoga breaks]',
#  '[USA vinyasa yoga deals weekend yoga]',
#  '[USA vinyasa yoga deals weekends yoga]',
#  '[USA vinyasa yoga deals yoga break]',
#  '[USA vinyasa yoga deals yoga breaks]',
#  '[USA vinyasa yoga deals yoga short break]',
#  '[USA vinyasa yoga deals yoga short breaks]',
#  '[USA vinyasa yoga deals yoga weekend]',
#  '[USA vinyasa yoga deals yoga weekends]',
#  '[USA vinyasa yoga holiday short yoga break]',
#  '[USA vinyasa yoga holiday short yoga breaks]',
#  '[USA vinyasa yoga holiday weekend yoga]',
#  '[USA vinyasa yoga holiday weekends yoga]',
#  '[USA vinyasa yoga holiday yoga break]',
#  '[USA vinyasa yoga holiday yoga breaks]',
#  '[USA vinyasa yoga holiday yoga short break]',
#  '[USA vinyasa yoga holiday yoga short breaks]',
#  '[USA vinyasa yoga holiday yoga weekend]',
#  '[USA vinyasa yoga holiday yoga weekends]',
#  '[USA vinyasa yoga holidays short yoga break]',
#  '[USA vinyasa yoga holidays short yoga breaks]',
#  '[USA vinyasa yoga holidays weekend yoga]',
#  '[USA vinyasa yoga holidays weekends yoga]',
#  '[USA vinyasa yoga holidays yoga break]',
#  '[USA vinyasa yoga holidays yoga breaks]',
#  '[USA vinyasa yoga holidays yoga short break]',
#  '[USA vinyasa yoga holidays yoga short breaks]',
#  '[USA vinyasa yoga holidays yoga weekend]',
#  '[USA vinyasa yoga holidays yoga weekends]',
#  '[USA vinyasa yoga package short yoga break]',
#  '[USA vinyasa yoga package short yoga breaks]',
#  '[USA vinyasa yoga package weekend yoga]',
#  '[USA vinyasa yoga package weekends yoga]',
#  '[USA vinyasa yoga package yoga break]',
#  '[USA vinyasa yoga package yoga breaks]',
#  '[USA vinyasa yoga package yoga short break]',
#  '[USA vinyasa yoga package yoga short breaks]',
#  '[USA vinyasa yoga package yoga weekend]',
#  '[USA vinyasa yoga package yoga weekends]',
#  '[USA vinyasa yoga packages short yoga break]',
#  '[USA vinyasa yoga packages short yoga breaks]',
#  '[USA vinyasa yoga packages weekend yoga]',
#  '[USA vinyasa yoga packages weekends yoga]',
#  '[USA vinyasa yoga packages yoga break]',
#  '[USA vinyasa yoga packages yoga breaks]',
#  '[USA vinyasa yoga packages yoga short break]',
#  '[USA vinyasa yoga packages yoga short breaks]',
#  '[USA vinyasa yoga packages yoga weekend]',
#  '[USA vinyasa yoga packages yoga weekends]',
#  '[USA vinyasa yoga resort short yoga break]',
#  '[USA vinyasa yoga resort short yoga breaks]',
#  '[USA vinyasa yoga resort weekend yoga]',
#  '[USA vinyasa yoga resort weekends yoga]',
#  '[USA vinyasa yoga resort yoga break]',
#  '[USA vinyasa yoga resort yoga breaks]',
#  '[USA vinyasa yoga resort yoga short break]',
#  '[USA vinyasa yoga resort yoga short breaks]',
#  '[USA vinyasa yoga resort yoga weekend]',
#  '[USA vinyasa yoga resort yoga weekends]',
#  '[USA vinyasa yoga resorts short yoga break]',
#  '[USA vinyasa yoga resorts short yoga breaks]',
#  '[USA vinyasa yoga resorts weekend yoga]',
#  '[USA vinyasa yoga resorts weekends yoga]',
#  '[USA vinyasa yoga resorts yoga break]',
#  '[USA vinyasa yoga resorts yoga breaks]',
#  '[USA vinyasa yoga resorts yoga short break]',
#  '[USA vinyasa yoga resorts yoga short breaks]',
#  '[USA vinyasa yoga resorts yoga weekend]',
#  '[USA vinyasa yoga resorts yoga weekends]',
#  '[USA vinyasa yoga retreat short yoga break]',
#  '[USA vinyasa yoga retreat short yoga breaks]',
#  '[USA vinyasa yoga retreat weekend yoga]',
#  '[USA vinyasa yoga retreat weekends yoga]',
#  '[USA vinyasa yoga retreat yoga break]',
#  '[USA vinyasa yoga retreat yoga breaks]',
#  '[USA vinyasa yoga retreat yoga short break]',
#  '[USA vinyasa yoga retreat yoga short breaks]',
#  '[USA vinyasa yoga retreat yoga weekend]',
#  '[USA vinyasa yoga retreat yoga weekends]',
#  '[USA vinyasa yoga retreats short yoga break]',
#  '[USA vinyasa yoga retreats short yoga breaks]',
#  '[USA vinyasa yoga retreats weekend yoga]',
#  '[USA vinyasa yoga retreats weekends yoga]',
#  '[USA vinyasa yoga retreats yoga break]',
#  '[USA vinyasa yoga retreats yoga breaks]',
#  '[USA vinyasa yoga retreats yoga short break]',
#  '[USA vinyasa yoga retreats yoga short breaks]',
#  '[USA vinyasa yoga retreats yoga weekend]',
#  '[USA vinyasa yoga retreats yoga weekends]',
#  '[USA vinyasa yoga short yoga break]',
#  '[USA vinyasa yoga short yoga break camp ]',
#  '[USA vinyasa yoga short yoga break camps ]',
#  '[USA vinyasa yoga short yoga break center ]',
#  '[USA vinyasa yoga short yoga break centers ]',
#  '[USA vinyasa yoga short yoga break centre ]',
#  '[USA vinyasa yoga short yoga break centres ]',
#  '[USA vinyasa yoga short yoga break deal ]',
#  '[USA vinyasa yoga short yoga break deals ]',
#  '[USA vinyasa yoga short yoga break holiday ]',
#  '[USA vinyasa yoga short yoga break holidays ]',
#  '[USA vinyasa yoga short yoga break package ]',
#  '[USA vinyasa yoga short yoga break packages ]',
#  '[USA vinyasa yoga short yoga break resort ]',
#  '[USA vinyasa yoga short yoga break resorts ]',
#  '[USA vinyasa yoga short yoga break retreat ]',
#  '[USA vinyasa yoga short yoga break retreats ]',
#  '[USA vinyasa yoga short yoga break vacation ]',
#  '[USA vinyasa yoga short yoga break vacations ]',
#  '[USA vinyasa yoga short yoga breaks]',
#  '[USA vinyasa yoga short yoga breaks camp ]',
#  '[USA vinyasa yoga short yoga breaks camps ]',
#  '[USA vinyasa yoga short yoga breaks center ]',
#  '[USA vinyasa yoga short yoga breaks centers ]',
#  '[USA vinyasa yoga short yoga breaks centre ]',
#  '[USA vinyasa yoga short yoga breaks centres ]',
#  '[USA vinyasa yoga short yoga breaks deal ]',
#  '[USA vinyasa yoga short yoga breaks deals ]',
#  '[USA vinyasa yoga short yoga breaks holiday ]',
#  '[USA vinyasa yoga short yoga breaks holidays ]',
#  '[USA vinyasa yoga short yoga breaks package ]',
#  '[USA vinyasa yoga short yoga breaks packages ]',
#  '[USA vinyasa yoga short yoga breaks resort ]',
#  '[USA vinyasa yoga short yoga breaks resorts ]',
#  '[USA vinyasa yoga short yoga breaks retreat ]',
#  '[USA vinyasa yoga short yoga breaks retreats ]',
#  '[USA vinyasa yoga short yoga breaks vacation ]',
#  '[USA vinyasa yoga short yoga breaks vacations ]',
#  '[USA vinyasa yoga vacation short yoga break]',
#  '[USA vinyasa yoga vacation short yoga breaks]',
#  '[USA vinyasa yoga vacation weekend yoga]',
#  '[USA vinyasa yoga vacation weekends yoga]',
#  '[USA vinyasa yoga vacation yoga break]',
#  '[USA vinyasa yoga vacation yoga breaks]',
#  '[USA vinyasa yoga vacation yoga short break]',
#  '[USA vinyasa yoga vacation yoga short breaks]',
#  '[USA vinyasa yoga vacation yoga weekend]',
#  '[USA vinyasa yoga vacation yoga weekends]',
#  '[USA vinyasa yoga vacations short yoga break]',
#  '[USA vinyasa yoga vacations short yoga breaks]',
#  '[USA vinyasa yoga vacations weekend yoga]',
#  '[USA vinyasa yoga vacations weekends yoga]',
#  '[USA vinyasa yoga vacations yoga break]',
#  '[USA vinyasa yoga vacations yoga breaks]',
#  '[USA vinyasa yoga vacations yoga short break]',
#  '[USA vinyasa yoga vacations yoga short breaks]',
#  '[USA vinyasa yoga vacations yoga weekend]',
#  '[USA vinyasa yoga vacations yoga weekends]',
#  '[USA vinyasa yoga weekend yoga]',
#  '[USA vinyasa yoga weekend yoga camp ]',
#  '[USA vinyasa yoga weekend yoga camps ]',
#  '[USA vinyasa yoga weekend yoga center ]',
#  '[USA vinyasa yoga weekend yoga centers ]',
#  '[USA vinyasa yoga weekend yoga centre ]',
#  '[USA vinyasa yoga weekend yoga centres ]',
#  '[USA vinyasa yoga weekend yoga deal ]',
#  '[USA vinyasa yoga weekend yoga deals ]',
#  '[USA vinyasa yoga weekend yoga holiday ]',
#  '[USA vinyasa yoga weekend yoga holidays ]',
#  '[USA vinyasa yoga weekend yoga package ]',
#  '[USA vinyasa yoga weekend yoga packages ]',
#  '[USA vinyasa yoga weekend yoga resort ]',
#  '[USA vinyasa yoga weekend yoga resorts ]',
#  '[USA vinyasa yoga weekend yoga retreat ]',
#  '[USA vinyasa yoga weekend yoga retreats ]',
#  '[USA vinyasa yoga weekend yoga vacation ]',
#  '[USA vinyasa yoga weekend yoga vacations ]',
#  '[USA vinyasa yoga weekends yoga]',
#  '[USA vinyasa yoga weekends yoga camp ]',
#  '[USA vinyasa yoga weekends yoga camps ]',
#  '[USA vinyasa yoga weekends yoga center ]',
#  '[USA vinyasa yoga weekends yoga centers ]',
#  '[USA vinyasa yoga weekends yoga centre ]',
#  '[USA vinyasa yoga weekends yoga centres ]',
#  '[USA vinyasa yoga weekends yoga deal ]',
#  '[USA vinyasa yoga weekends yoga deals ]',
#  '[USA vinyasa yoga weekends yoga holiday ]',
#  '[USA vinyasa yoga weekends yoga holidays ]',
#  '[USA vinyasa yoga weekends yoga package ]',
#  '[USA vinyasa yoga weekends yoga packages ]',
#  '[USA vinyasa yoga weekends yoga resort ]',
#  '[USA vinyasa yoga weekends yoga resorts ]',
#  '[USA vinyasa yoga weekends yoga retreat ]',
#  '[USA vinyasa yoga weekends yoga retreats ]',
#  '[USA vinyasa yoga weekends yoga vacation ]',
#  '[USA vinyasa yoga weekends yoga vacations ]',
#  '[USA vinyasa yoga yoga break]',
#  '[USA vinyasa yoga yoga break camp ]',
#  '[USA vinyasa yoga yoga break camps ]',
#  '[USA vinyasa yoga yoga break center ]',
#  '[USA vinyasa yoga yoga break centers ]',
#  '[USA vinyasa yoga yoga break centre ]',
#  '[USA vinyasa yoga yoga break centres ]',
#  '[USA vinyasa yoga yoga break deal ]',
#  '[USA vinyasa yoga yoga break deals ]',
#  '[USA vinyasa yoga yoga break holiday ]',
#  '[USA vinyasa yoga yoga break holidays ]',
#  '[USA vinyasa yoga yoga break package ]',
#  '[USA vinyasa yoga yoga break packages ]',
#  '[USA vinyasa yoga yoga break resort ]',
#  '[USA vinyasa yoga yoga break resorts ]',
#  '[USA vinyasa yoga yoga break retreat ]',
#  '[USA vinyasa yoga yoga break retreats ]',
#  '[USA vinyasa yoga yoga break vacation ]',
#  '[USA vinyasa yoga yoga break vacations ]',
#  '[USA vinyasa yoga yoga breaks]',
#  '[USA vinyasa yoga yoga breaks camp ]',
#  '[USA vinyasa yoga yoga breaks camps ]',
#  '[USA vinyasa yoga yoga breaks center ]',
#  '[USA vinyasa yoga yoga breaks centers ]',
#  '[USA vinyasa yoga yoga breaks centre ]',
#  '[USA vinyasa yoga yoga breaks centres ]',
#  '[USA vinyasa yoga yoga breaks deal ]',
#  '[USA vinyasa yoga yoga breaks deals ]',
#  '[USA vinyasa yoga yoga breaks holiday ]',
#  '[USA vinyasa yoga yoga breaks holidays ]',
#  '[USA vinyasa yoga yoga breaks package ]',
#  '[USA vinyasa yoga yoga breaks packages ]',
#  '[USA vinyasa yoga yoga breaks resort ]',
#  '[USA vinyasa yoga yoga breaks resorts ]',
#  '[USA vinyasa yoga yoga breaks retreat ]',
#  '[USA vinyasa yoga yoga breaks retreats ]',
#  '[USA vinyasa yoga yoga breaks vacation ]',
#  '[USA vinyasa yoga yoga breaks vacations ]',
#  '[USA vinyasa yoga yoga short break]',
#  '[USA vinyasa yoga yoga short break camp ]',
#  '[USA vinyasa yoga yoga short break camps ]',
#  '[USA vinyasa yoga yoga short break center ]',
#  '[USA vinyasa yoga yoga short break centers ]',
#  '[USA vinyasa yoga yoga short break centre ]',
#  '[USA vinyasa yoga yoga short break centres ]',
#  '[USA vinyasa yoga yoga short break deal ]',
#  '[USA vinyasa yoga yoga short break deals ]',
#  '[USA vinyasa yoga yoga short break holiday ]',
#  '[USA vinyasa yoga yoga short break holidays ]',
#  '[USA vinyasa yoga yoga short break package ]',
#  '[USA vinyasa yoga yoga short break packages ]',
#  '[USA vinyasa yoga yoga short break resort ]',
#  '[USA vinyasa yoga yoga short break resorts ]',
#  '[USA vinyasa yoga yoga short break retreat ]',
#  '[USA vinyasa yoga yoga short break retreats ]',
#  '[USA vinyasa yoga yoga short break vacation ]',
#  '[USA vinyasa yoga yoga short break vacations ]',
#  '[USA vinyasa yoga yoga short breaks]',
#  '[USA vinyasa yoga yoga short breaks camp ]',
#  '[USA vinyasa yoga yoga short breaks camps ]',
#  '[USA vinyasa yoga yoga short breaks center ]',
#  '[USA vinyasa yoga yoga short breaks centers ]',
#  '[USA vinyasa yoga yoga short breaks centre ]',
#  '[USA vinyasa yoga yoga short breaks centres ]',
#  '[USA vinyasa yoga yoga short breaks deal ]',
#  '[USA vinyasa yoga yoga short breaks deals ]',
#  '[USA vinyasa yoga yoga short breaks holiday ]',
#  '[USA vinyasa yoga yoga short breaks holidays ]',
#  '[USA vinyasa yoga yoga short breaks package ]',
#  '[USA vinyasa yoga yoga short breaks packages ]',
#  '[USA vinyasa yoga yoga short breaks resort ]',
#  '[USA vinyasa yoga yoga short breaks resorts ]',
#  '[USA vinyasa yoga yoga short breaks retreat ]',
#  '[USA vinyasa yoga yoga short breaks retreats ]',
#  '[USA vinyasa yoga yoga short breaks vacation ]',
#  '[USA vinyasa yoga yoga short breaks vacations ]',
#  '[USA vinyasa yoga yoga weekend]',
#  '[USA vinyasa yoga yoga weekend camp ]',
#  '[USA vinyasa yoga yoga weekend camps ]',
#  '[USA vinyasa yoga yoga weekend center ]',
#  '[USA vinyasa yoga yoga weekend centers ]',
#  '[USA vinyasa yoga yoga weekend centre ]',
#  '[USA vinyasa yoga yoga weekend centres ]',
#  '[USA vinyasa yoga yoga weekend deal ]',
#  '[USA vinyasa yoga yoga weekend deals ]',
#  '[USA vinyasa yoga yoga weekend holiday ]',
#  '[USA vinyasa yoga yoga weekend holidays ]',
#  '[USA vinyasa yoga yoga weekend package ]',
#  '[USA vinyasa yoga yoga weekend packages ]',
#  '[USA vinyasa yoga yoga weekend resort ]',
#  '[USA vinyasa yoga yoga weekend resorts ]',
#  '[USA vinyasa yoga yoga weekend retreat ]',
#  '[USA vinyasa yoga yoga weekend retreats ]',
#  '[USA vinyasa yoga yoga weekend vacation ]',
#  '[USA vinyasa yoga yoga weekend vacations ]',
#  '[USA vinyasa yoga yoga weekends]',
#  '[USA vinyasa yoga yoga weekends camp ]',
#  '[USA vinyasa yoga yoga weekends camps ]',
#  '[USA vinyasa yoga yoga weekends center ]',
#  '[USA vinyasa yoga yoga weekends centers ]',
#  '[USA vinyasa yoga yoga weekends centre ]',
#  '[USA vinyasa yoga yoga weekends centres ]',
#  '[USA vinyasa yoga yoga weekends deal ]',
#  '[USA vinyasa yoga yoga weekends deals ]',
#  '[USA vinyasa yoga yoga weekends holiday ]',
#  '[USA vinyasa yoga yoga weekends holidays ]',
#  '[USA vinyasa yoga yoga weekends package ]',
#  '[USA vinyasa yoga yoga weekends packages ]',
#  '[USA vinyasa yoga yoga weekends resort ]',
#  '[USA vinyasa yoga yoga weekends resorts ]',
#  '[USA vinyasa yoga yoga weekends retreat ]',
#  '[USA vinyasa yoga yoga weekends retreats ]',
#  '[USA vinyasa yoga yoga weekends vacation ]',
#  '[USA vinyasa yoga yoga weekends vacations ]',
#  '[USA weekend yoga vinyasa yoga]',
#  '[USA weekend yoga vinyasa yoga camp ]',
#  '[USA weekend yoga vinyasa yoga camps ]',
#  '[USA weekend yoga vinyasa yoga center ]',
#  '[USA weekend yoga vinyasa yoga centers ]',
#  '[USA weekend yoga vinyasa yoga centre ]',
#  '[USA weekend yoga vinyasa yoga centres ]',
#  '[USA weekend yoga vinyasa yoga deal ]',
#  '[USA weekend yoga vinyasa yoga deals ]',
#  '[USA weekend yoga vinyasa yoga holiday ]',
#  '[USA weekend yoga vinyasa yoga holidays ]',
#  '[USA weekend yoga vinyasa yoga package ]',
#  '[USA weekend yoga vinyasa yoga packages ]',
#  '[USA weekend yoga vinyasa yoga resort ]',
#  '[USA weekend yoga vinyasa yoga resorts ]',
#  '[USA weekend yoga vinyasa yoga retreat ]',
#  '[USA weekend yoga vinyasa yoga retreats ]',
#  '[USA weekend yoga vinyasa yoga vacation ]',
#  '[USA weekend yoga vinyasa yoga vacations ]',
#  '[USA weekends yoga vinyasa yoga]',
#  '[USA weekends yoga vinyasa yoga camp ]',
#  '[USA weekends yoga vinyasa yoga camps ]',
#  '[USA weekends yoga vinyasa yoga center ]',
#  '[USA weekends yoga vinyasa yoga centers ]',
#  '[USA weekends yoga vinyasa yoga centre ]',
#  '[USA weekends yoga vinyasa yoga centres ]',
#  '[USA weekends yoga vinyasa yoga deal ]',
#  '[USA weekends yoga vinyasa yoga deals ]',
#  '[USA weekends yoga vinyasa yoga holiday ]',
#  '[USA weekends yoga vinyasa yoga holidays ]',
#  '[USA weekends yoga vinyasa yoga package ]',
#  '[USA weekends yoga vinyasa yoga packages ]',
#  ...]

# %%
#zip each columns

rows = []
for i in range(len(results)):
    rows.append([keyword_state[i],
                 results[i],
                 match_type[i],
                 campaign[i],
                 ad_group[i],
                 keyword_max_cpc[i],
                 ad_group_max_cpc[i]])
        
######################################################################################

#export longtail keywords in a csv file
import csv

file_name = "%s %s %s keywords.csv" %(cat[:5], style, destination_front)
new_csv = open(file_name, 'wb')
open_file_object = csv.writer(new_csv)

#write rows
open_file_object.writerow(kw_column_titles)

#write columns
for row in rows:
    open_file_object.writerow(row)

new_csv.close()

print """[Notification] %i longtail keywords for %s %s %s are generated successfully. 
Please check your current directory for the stored result in a csv file. """ %(len(results), cat, style, destination_front)
# Out:
# [Notification] 6720 longtail keywords for ['yoga weekend', 'weekend yoga', 'yoga weekends', 'weekends yoga', 'yoga break', 'yoga breaks', 'short yoga break', 'short yoga breaks', 'yoga short break', 'yoga short breaks'] ['vinyasa yoga'] ['USA', 'US', 'the US', 'United States'] are generated successfully.
# Please check your current directory for the stored result in a csv file.

# %%
#prepare csv file content for ads
how_many_ads = len(destination_front) * 4

#prepare column titles
ac_column_titles = ["Ad state",
                    "Ad",
                    "Description line 1",
                    "Description line 2",
                    "Display URL",
                    "Final URL",
                    "Device preference type",
                    "Campaign",
                    "Ad group",
                    "Ad type"]

#prepare each column
ad_state = ['enabled'] * how_many_ads
ad = headlines * 2
d1 = ([desc11] * 2 + [desc21] * 2) * len(destination_front)
d2 = ([desc12] + [desc22]) * 2 * len(destination_front)
display_url = ['www.bookyogaretreats.com/%s'%url[cat_idx_front:cat_idx_back].title().replace('-','')] * how_many_ads
final_url = [url] * how_many_ads
device = ['All'] * len(destination_front) * 2 + ['Mobile'] * len(destination_front) * 2
campaign = ['Longtail %s'%str_destination] * how_many_ads
ad_group = ['Longtail %s %s'%(str_destination, page_title.split()[2])] * how_many_ads
ad_type = ['Text ad'] * how_many_ads

#zip column
i=0
ac_rows1 =[]
for i in range(how_many_ads):
    ac_rows1.append([ad_state[i],
                    ad[i],
                    d1[i],
                    d2[i],
                    display_url[i],
                    final_url[i],
                    device[i],
                    campaign[i],
                    ad_group[i],
                    ad_type[i]])

#seperate ads for "[destination] yoga holidays"
i=0
ac_rows2=[]
for i in range(how_many_ads):
    ac_rows2.append([ad_state[i],
                    ad[i],
                    d1[i],
                    d2[i],
                    display_url[i],
                    final_url[i],
                    device[i],
                    campaign[i],
                    ad_group[i],
                    ad_type[i]])


ac_rows_all = ac_rows1 + ac_rows2

######################################################################################

#export ads into a csv file
file_name = "%s ads.csv" %destination_front
new_csv = open(file_name, 'wb')
open_file_object = csv.writer(new_csv)

#rows
open_file_object.writerow(ac_column_titles)

#columns
open_file_object.writerows(ac_rows_all)
new_csv.close()

print """[Notification] All %s ads for %s are generated successfully. 
Please check your current directory for the stored result in a csv file. """ %(len(ac_rows_all), destination_front)

######################################################################################
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-21b266c7016c> in <module>()
#      16 #prepare each column
#      17 ad_state = ['enabled'] * how_many_ads
# ---> 18 ad = headlines * 2
#      19 d1 = ([desc11] * 2 + [desc21] * 2) * len(destination_front)
#      20 d2 = ([desc12] + [desc22]) * 2 * len(destination_front)
#
# NameError: name 'headlines' is not defined
